# %%
import numpy as np
import pandas as pd
import gc
import time
import csv
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU, Concatenate, Input, ReLU, MultiHeadAttention, Layer
import keras

from tensorflow.keras.losses import Loss
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from keras import backend as K

import matplotlib.pyplot as plt
import keras.backend as K

from sklearn.model_selection import KFold
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
import joblib
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import re
from scipy.stats import rankdata, norm
from scipy.sparse import load_npz
import gc
import csv
import pickle
import glob
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import roc_auc_score
import numpy as np
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#utility code

# Prepares a tsv file for submission from model output
class PredictionPreparation:
    def __init__(self, test_pred, Y_labels, protein_labels):
        self.test_pred = test_pred
        self.Y_labels = Y_labels
        self.protein_labels = protein_labels

    def prepare_submission(self, filename="submission.tsv", top_percent=1, dropweights=False, dropzeros=True):
        # prepare dataframe for submission
        df_finalSubmission_MF = pd.DataFrame(columns = ['Protein Id', 'GO Term Id','Prediction'])
        l = []
        for k in list(self.protein_labels):
            l += [k] * self.test_pred.shape[1]
        df_finalSubmission_MF['Protein Id'] = l
        df_finalSubmission_MF['GO Term Id'] = list(self.Y_labels) * self.test_pred.shape[0]
        df_finalSubmission_MF['Prediction'] = self.test_pred.ravel()

        # Calculate the number of rows that represent the top n%
        top_rows = int(top_percent * df_finalSubmission_MF.shape[0])

        # Select the top 5% rows based on 'Prediction'
        df_finalSubmission_MF = df_finalSubmission_MF.nlargest(top_rows, 'Prediction')

        if dropzeros:
            # Drop rows where 'Prediction' is equal or less than zero
            print('zeros dropped for', len(df_finalSubmission_MF[df_finalSubmission_MF['Prediction'] <= 0.0001]), 'rows')
            df_finalSubmission_MF = df_finalSubmission_MF[df_finalSubmission_MF['Prediction'] > 0.0001]


        # round to 3 decimals
        df_finalSubmission_MF['Prediction'] = df_finalSubmission_MF['Prediction'].round(3)

        if dropweights:
            # Drop the right most column (weights)
            df_finalSubmission_MF = df_finalSubmission_MF.iloc[:, :-1]
            print(df_finalSubmission_MF.head())
            print('matrix shape:', df_finalSubmission_MF.shape)

        else:
            # take a quick look at the data
            summary_stats = df_finalSubmission_MF['Prediction'].describe()
            print(df_finalSubmission_MF.head())
            print(summary_stats)

        # Save to file
        df_finalSubmission_MF.to_csv(filename, header=False, index=False, sep="\t")

# prepares training data depending on which ontology is being looked at
class TrainingDataPreparation:
    def __init__(self, ontology):
        self.ontology = ontology

    def load_Y_data(self):
        if self.ontology == 'BPO':
            Y = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_BP_1500.npy', allow_pickle=True)
            Y_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_BP_labels_1500.npy', allow_pickle=True)
            df = pd.read_csv('/content/drive/MyDrive/CAFA5 2023/Train_data/BPO_1500_freq_weights.csv')
            weights_raw = df['IA_weight'].values.tolist()
            weights = {i: weights_raw[i] for i in range(len(weights_raw))}

        elif self.ontology == 'CCO':
            Y = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_CC_800.npy', allow_pickle=True)
            Y_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_CC_labels_800.npy', allow_pickle=True)
            df = pd.read_csv('/content/drive/MyDrive/CAFA5 2023/Train_data/CCO_800_freq_weights.csv')
            weights_raw = df['IA_weight'].values.tolist()
            weights = {i: weights_raw[i] for i in range(len(weights_raw))}

        elif self.ontology == 'MFO':
            Y = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_MF_800.npy', allow_pickle=True)
            Y_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_MF_labels_800.npy', allow_pickle=True)
            df = pd.read_csv('/content/drive/MyDrive/CAFA5 2023/Train_data/MFO_800_freq_weights.csv')
            weights_raw = df['IA_weight'].values.tolist()
            weights = {i: weights_raw[i] for i in range(len(weights_raw))}

        else:
            print('Error: ontology not recognized')
            return None, None, None
        print(f'Loaded {self.ontology} ontology')

        return Y, Y_labels, weights, df

    def load_t5_data(self):
        train_data1 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/t5_data_sorted_f32.npy', mmap_mode='r')
        test_data1 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/t5_data_sorted.npy', mmap_mode='r')

        print(f'T5 train data shape: {train_data1.shape}')
        print(f'T5 test data shape: {test_data1.shape}')

        return train_data1, test_data1

    def load_esm2_s_data(self):
        train_data2 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/ems_data_sorted.npy', mmap_mode='r')
        test_data2 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/ems_data_sorted.npy', mmap_mode='r')

        print(f'ESM2 small train data shape: {train_data2.shape}')
        print(f'ESM2 small test data shape: {test_data2.shape}')

        return train_data2, test_data2

    def load_esm2_l_data(self):
        train_data3 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/ESM2_3B_train_embeddings_sorted.npy', mmap_mode='r')
        test_data3 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/ESM2_3B_test_embeddings_sorted.npy', mmap_mode='r')

        print(f'ESM2 3B train data shape: {train_data3.shape}')
        print(f'ESM2 3B data shape: {test_data3.shape}')

        return train_data3, test_data3

    def load_pb_data(self):
        train_data4 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/pb_data_sorted_f32.npy', mmap_mode='r')
        test_data4 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/pb_data_sorted.npy', mmap_mode='r')

        print(f'PB train data shape: {train_data4.shape}')
        print(f'PB data shape: {test_data4.shape}')

        return train_data4, test_data4

    def load_ankh_data(self):
        train_data5 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Ankh_train_embeddings_sorted.npy', mmap_mode='r')
        test_data5 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/Ankh_test_embeddings_sorted.npy', mmap_mode='r')

        print(f'Ankh train data shape: {train_data5.shape}')
        print(f'Ankh data shape: {test_data5.shape}')

        return train_data5, test_data5

    def load_taxa_data(self):
        train_data6 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/protein_taxa_matrix_train.npy', mmap_mode='r')
        test_data6 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/protein_taxa_matrix_test.npy', mmap_mode='r')

        print(f'Taxa train data shape: {train_data6.shape}')
        print(f'Taxa data shape: {test_data6.shape}')

        return train_data6, test_data6

    def load_text_embed(self):

        train_data7 = np.load('/content/drive/MyDrive/CAFA5 2023/Absrtract_embeds_modified/abstract_embeds_train_sorted_all.npy', mmap_mode='r')
        test_data7 = np.load('/content/drive/MyDrive/CAFA5 2023/Absrtract_embeds_modified/abstract_embeds_test_sorted_all.npy', mmap_mode='r')

        print(f'Text abstract data shape: {train_data7.shape}')
        print(f'Text abstract shape: {test_data7.shape}')

        return train_data7, test_data7

class PredictionPreparation:
    def __init__(self, test_pred, Y_labels, protein_labels):
        self.test_pred = test_pred
        self.Y_labels = Y_labels
        self.protein_labels = protein_labels

    def prepare_submission(self, filename="submission.tsv", top_percent=1, dropweights=False, dropzeros=True):
        # prepare dataframe for submission
        df_finalSubmission_MF = pd.DataFrame(columns = ['Protein Id', 'GO Term Id','Prediction'])
        l = []
        for k in list(self.protein_labels):
            l += [k] * self.test_pred.shape[1]
        df_finalSubmission_MF['Protein Id'] = l
        df_finalSubmission_MF['GO Term Id'] = list(self.Y_labels) * self.test_pred.shape[0]
        df_finalSubmission_MF['Prediction'] = self.test_pred.ravel()

        # Calculate the number of rows that represent the top n%
        top_rows = int(top_percent * df_finalSubmission_MF.shape[0])

        # Select the top 5% rows based on 'Prediction'
        df_finalSubmission_MF = df_finalSubmission_MF.nlargest(top_rows, 'Prediction')

        if dropzeros:
            # Drop rows where 'Prediction' is equal or less than zero
            print('zeros dropped for', len(df_finalSubmission_MF[df_finalSubmission_MF['Prediction'] <= 0.0001]), 'rows')
            df_finalSubmission_MF = df_finalSubmission_MF[df_finalSubmission_MF['Prediction'] > 0.0001]


        # round to 3 decimals
        df_finalSubmission_MF['Prediction'] = df_finalSubmission_MF['Prediction'].round(3)

        if dropweights:
            # Drop the right most column (weights)
            df_finalSubmission_MF = df_finalSubmission_MF.iloc[:, :-1]
            print(df_finalSubmission_MF.head())
            print('matrix shape:', df_finalSubmission_MF.shape)

        else:
            # take a quick look at the data
            summary_stats = df_finalSubmission_MF['Prediction'].describe()
            print(df_finalSubmission_MF.head())
            print(summary_stats)

        # Save to file
        df_finalSubmission_MF.to_csv(filename, header=False, index=False, sep="\t")

class ProteinPredictions:
    # Initialize an empty dictionary to store the predictions
    def __init__(self):
        self.predictions = {}

    # Add a prediction to the storage, with optional bonus
    # Arguments:
    #   - protein: Identifier for the protein
    #   - go_term: GO term that is being predicted
    #   - score: Confidence score of the prediction
    #   - branch: Branch of the Gene Ontology (e.g., 'CCO', 'MFO', 'BPO')
    #   - bonus: Optional bonus to be added to the score
    def add_prediction(self, protein, go_term, score, branch, bonus=1, adjustment=1):
        # If the protein is not already in the storage, initialize its structure
        if protein not in self.predictions:
            self.predictions[protein] = {'CCO': {}, 'MFO': {}, 'BPO': {}}

        # Convert the score to a float for comparison and calculation
        score = float(score)

        # If this GO term has already been predicted for this protein and branch,
        # add the bonus to the score. Keep the highest score.
        if go_term in self.predictions[protein][branch]:
            self.predictions[protein][branch][go_term] *= 1+(score**3)*bonus
            self.predictions[protein][branch][go_term] += score*adjustment

        # If this GO term has not been predicted yet, store it with the score
        else:
            self.predictions[protein][branch][go_term] = max(score*adjustment, 0)

        # Ensure that the score does not exceed 1
        if self.predictions[protein][branch][go_term] > 1:
            self.predictions[protein][branch][go_term] = 1

    # Get a list of all scores in the predictions
    def get_scores(self):
        scores = []
        for protein, branches in self.predictions.items():
            for branch, go_terms in branches.items():
                scores.extend(go_terms.values())
        return scores

    def plot_predictions(self):
        scores = self.get_scores()
        plt.hist(scores, bins=30, edgecolor='black')
        plt.title('Distribution of Prediction Scores')
        plt.xlabel('Score')
        plt.ylabel('Frequency')
        plt.show()

    # Export the stored predictions to a file
    # Arguments:
    #   - output_file: File name for the exported predictions
    #   - top: Number of top predictions to export for each protein and branch
    def get_predictions(self, output_file='submission.tsv', top=60):
        # Open the output file
        with open(output_file, 'w') as f:
            # Iterate through each protein and its branches
            for protein, branches in self.predictions.items():
                # For each branch, sort the GO terms by score in descending order and select the top ones
                for branch, go_terms in branches.items():
                    # Sort go_terms by score in descending order and take the top ones
                    top_go_terms = sorted(go_terms.items(), key=lambda x: x[1], reverse=True)[:top]
                    # Write each of the top predictions to the file
                    for go_term, score in top_go_terms:
                        f.write(f"{protein}\t{go_term}\t{score:.3f}\n")


def extract_go_terms_and_branches(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
        # Match each stanza with [Term] in the OBO file
        stanzas = re.findall(r'\[Term\][\s\S]*?(?=\n\[|$)', content)

    go_terms_dict = {}
    for stanza in stanzas:
        # Extract the GO term ID
        go_id = re.search(r'^id: (GO:\d+)', stanza, re.MULTILINE)
        if go_id:
            go_id = go_id.group(1)

        # Extract the namespace (branch)
        namespace = re.search(r'^namespace: (\w+)', stanza, re.MULTILINE)
        if namespace:
            namespace = namespace.group(1)

        if go_id and namespace:
            # Map the branch abbreviation to the corresponding BPO, CCO, or MFO
            branch_abbr = {'biological_process': 'BPO', 'cellular_component': 'CCO', 'molecular_function': 'MFO'}
            go_terms_dict[go_id] = branch_abbr[namespace]

    return go_terms_dict

def get_constr_out(x, R):
    """ Given the output of the neural network x returns the output of MCM given the hierarchy constraint expressed in the matrix R """
    c_out = tf.cast(x, tf.float32)
    print('c_out1', c_out.shape)
    c_out = tf.expand_dims(c_out, 1)
    print('c_out2', c_out.shape)
    c_out = tf.tile(c_out, [1, tf.shape(R)[1], 1])
    print('c_out3', c_out.shape)
    # c_out = tf.expand_dims(c_out, -2)  # Expand the last dimension of c_out
    # print('c_out2', c_out.shape)
    # c_out = tf.tile(c_out, [1, tf.shape(R)[1]], 1)  # Make c_out match the shape of R
    # print('c_out3', c_out.shape)
    R = tf.cast(R, tf.float32)
    print('R', R.shape)
    R = tf.expand_dims(R, axis=0)  # make R 3D by adding an extra dimension
    print('R', R.shape)
    R_batch = tf.tile(R, [tf.shape(x)[0], 1, 1])  # replicate R along the batch dimension
    print('R_batch', R_batch.shape)
    print(R_batch[0][50][0:50])
    print(c_out[0][0][:50])
    final_out = tf.reduce_max(R_batch * c_out, axis=2)
    print('final_out', final_out.shape)
    return final_out

class CustomMCM(Loss):
    def __init__(self, R, name="custom_mcm"):
        super().__init__(name=name)
        self.R = tf.cast(R, tf.float32)

    def call(self, y_true, y_pred):
        constr_output = get_constr_out(y_pred, self.R)
        y_true = tf.cast(y_true, tf.float32)
        print('yt, yp, c_out', y_true.shape, y_pred.shape, constr_output.shape)
        train_output = y_true*y_pred
        print('train_output1', train_output.shape)
        train_output = get_constr_out(train_output, self.R)
        print('train_output2', train_output.shape)
        train_output = (1-y_true)*constr_output + y_true*train_output
        print('train_output3', train_output.shape)
        # return binary cross entropy loss
        #return K.mean(K.binary_crossentropy(y_true, train_output), axis=-1) #this does not make things better -1 -> -2
        return tf.keras.losses.binary_crossentropy(y_true, train_output)


file_path = '/content/drive/MyDrive/CAFA5 2023/Train_data/go-basic.obo'
go_terms_dict = extract_go_terms_and_branches(file_path)

# %%
ontology = 'MFO'
data_prep = TrainingDataPreparation(ontology)
Y, Y_labels, weights, df = data_prep.load_Y_data()
t5_train, t5_test = data_prep.load_t5_data()
esm1_train, esm1_test = data_prep.load_esm2_s_data()
esm2_train, esm2_test = data_prep.load_esm2_l_data()
pb_train, pb_test = data_prep.load_pb_data()
ankh_train, ankh_test = data_prep.load_ankh_data()
taxa_train, taxa_test = data_prep.load_taxa_data()
txt1_train, txt1_test = data_prep.load_text_embed()

if ontology == 'CCO':
    R = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/CCO_800_DAG_matrix.npy')
    output_split = [4, 11, 24, 59, 199]

elif ontology == 'MFO':
    R = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/MFO_800_DAG_matrix.npy')
    output_split = [4,14,28,69,176]

elif ontology == 'BPO':
    R = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/BPO_1500_DAG_matrix.npy')
    output_split = [13,45,102,213,465]


print (f'R shape is {R.shape}')
print('datasets loaded')
# Out:
# Loaded MFO ontology
# T5 train data shape: (142246, 1024)
# T5 test data shape: (141864, 1024)
# ESM2 small train data shape: (142246, 1280)
# ESM2 small test data shape: (141864, 1280)
# ESM2 3B train data shape: (142246, 2560)
# ESM2 3B data shape: (141864, 2560)
# PB train data shape: (142246, 1024)
# PB data shape: (141864, 1024)
# Ankh train data shape: (142246, 1536)
# Ankh data shape: (141864, 1536)
# Taxa train data shape: (142246, 70)
# Taxa data shape: (141864, 70)
# Text abstract data shape: (142246, 10279)
# Text abstract shape: (141864, 10279)
# R shape is (800, 800)
# datasets loaded

# %%
print(f'Number of proteins with no {ontology} terms = {np.sum(np.all(Y == 0, axis=1))} out of {Y.shape[0]}')

valid_rows = ~np.all(Y == 0, axis=1)   #~ inverts np all
# Filter out rows in Y
Y = Y[valid_rows]

# Filter out rows in other input arrays
t5_train = t5_train[valid_rows]
esm1_train = esm1_train[valid_rows]
esm2_train = esm2_train[valid_rows]
pb_train = pb_train[valid_rows]
ankh_train = ankh_train[valid_rows]
taxa_train = taxa_train[valid_rows]
txt1_train = txt1_train[valid_rows]

print(f'we retained {np.sum(valid_rows)} proteins from training set where {ontology} terms are present')
# Out:
# Number of proteins with no MFO terms = 63114 out of 142246
# we retained 79132 proteins from training set where MFO terms are present

# %%
# Setup vars
n_epochs = 20
n_epochs_ft = 10
dropout_rate = 0.5
l1_dim = 600
l2_dim = 300
final_dim = 800

txt_dim1 = 200
txt_dim2 = 200

#loss without removing any training data (proteins with no BPO...) = 0.0310

#txt dim tests with BPO loss numbers
#no text input = 0.04613
#600/300 = 0.04313
#400/200 = 0.04302
#300/150 = 0.04295
#200/200 = 0.04280
  #final_dim 800 -> 400 = 0.04343
  #final dense layer removed completely -> 0.04286
#200/100 = 0.04302
#140/140 = 0.04306

#modifying the l1_dim 600 -> 300 = 0.04297
#l2_dim 300->450 = 0.04281
#longer training txt dim 100/100 = 0.04309

# %%
rand_state_no = 1
#output_split = [10,20,30,40,50]
output_split = [5,10,20,40,80]

# Define 5-fold cross validation
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=rand_state_no)

fold_ct = 1
# Iterate over each fold
for train_index, val_index in kf.split(t5_train):

    # Skip other folds for testing
    # if fold_ct>1:
    #   continue

    # Define save name
    save_name = '/content/drive/MyDrive/CAFA5 2023/1.30/'+f"{ontology}_fc{fold_ct}_r{rand_state_no}_1.30.4"

    x_tr_1, x_val_1 = t5_train[train_index], t5_train[val_index]
    x_tr_2, x_val_2 = esm1_train[train_index], esm1_train[val_index]
    x_tr_3, x_val_3 = esm2_train[train_index], esm2_train[val_index]
    x_tr_4, x_val_4 = pb_train[train_index], pb_train[val_index]
    x_tr_5, x_val_5 = ankh_train[train_index], ankh_train[val_index]
    x_tr_6, x_val_6 = taxa_train[train_index], taxa_train[val_index]
    x_tr_7, x_val_7 = txt1_train[train_index], txt1_train[val_index]
    # x_tr_8, x_val_8 = txt2_train[train_index], txt2_train[val_index]
    # x_tr_9, x_val_9 = txt3_train[train_index], txt3_train[val_index]

    y_tr_1, y_val_1 = Y[train_index,:output_split[0]], Y[val_index,:output_split[0]]
    y_tr_2, y_val_2 = Y[train_index,output_split[0]:output_split[1]], Y[val_index,output_split[0]:output_split[1]]
    y_tr_3, y_val_3 = Y[train_index,output_split[1]:output_split[2]], Y[val_index,output_split[1]:output_split[2]]
    y_tr_4, y_val_4 = Y[train_index,output_split[2]:output_split[3]], Y[val_index,output_split[2]:output_split[3]]
    y_tr_5, y_val_5 = Y[train_index,output_split[3]:output_split[4]], Y[val_index,output_split[3]:output_split[4]]
    y_tr_6, y_val_6 = Y[train_index,output_split[4]:], Y[val_index,output_split[4]:]

    # Define the inputs
    t5_in = Input(shape=(t5_train.shape[1],))
    esm1_in = Input(shape=(esm1_train.shape[1],))
    mlpr_in = Input(shape=(esm2_train.shape[1],))
    knn_in = Input(shape=(pb_train.shape[1],))
    lr_in = Input(shape=(ankh_train.shape[1],))
    taxa_in = Input(shape=(taxa_train.shape[1],))
    txt1_in = Input(shape=(txt1_train.shape[1],))
    # txt2_in = Input(shape=(txt2_train.shape[1],))
    # txt3_in = Input(shape=(txt3_train.shape[1],))

    network_1 = Dense(l1_dim, name='t5_dense_1')(t5_in)
    network_1 = BatchNormalization(name='t5_batchnorm_1')(network_1)
    network_1 = LeakyReLU(alpha=0.1, name='t5_leakyrelu_1')(network_1)
    network_1 = Dropout(dropout_rate, name='t5_dropout_1')(network_1)
    network_1 = Dense(l2_dim, name='t5_dense_2')(network_1)

    network_2 = Dense(l1_dim, name='esm1_dense_1')(esm1_in)
    network_2 = BatchNormalization(name='esm1_batchnorm_1')(network_2)
    network_2 = LeakyReLU(alpha=0.1, name='esm1_leakyrelu_1')(network_2)
    network_2 = Dropout(dropout_rate, name='esm1_dropout_1')(network_2)
    network_2 = Dense(l2_dim, name='esm1_dense_2')(network_2)

    network_3 = Dense(l1_dim, name='mlpr_dense_1')(mlpr_in)
    network_3 = BatchNormalization(name='mlpr_batchnorm_1')(network_3)
    network_3 = LeakyReLU(alpha=0.1, name='mlpr_leakyrelu_1')(network_3)
    network_3 = Dropout(dropout_rate, name='mlpr_dropout_1')(network_3)
    network_3 = Dense(l2_dim, name='mlpr_dense_2')(network_3)

    network_4 = Dense(l1_dim, name='knn_dense_1')(knn_in)
    network_4 = BatchNormalization(name='knn_batchnorm_1')(network_4)
    network_4 = LeakyReLU(alpha=0.1, name='knn_leakyrelu_1')(network_4)
    network_4 = Dropout(dropout_rate, name='knn_dropout_1')(network_4)
    network_4 = Dense(l2_dim, name='knn_dense_2')(network_4)

    network_5 = Dense(l1_dim, name='lr_dense_1')(lr_in)
    network_5 = BatchNormalization(name='lr_batchnorm_1')(network_5)
    network_5 = LeakyReLU(alpha=0.1, name='lr_leakyrelu_1')(network_5)
    network_5 = Dropout(dropout_rate, name='lr_dropout_1')(network_5)
    network_5 = Dense(l2_dim, name='lr_dense_2')(network_5)

    network_6 = Dense(128, name='taxa_dense_1')(taxa_in)
    network_6 = BatchNormalization(name='taxa_batchnorm_1')(network_6)
    network_6 = LeakyReLU(alpha=0.1, name='taxa_leakyrelu_1')(network_6)
    network_6 = Dropout(dropout_rate, name='taxa_dropout_1')(network_6)
    network_6 = Dense(64, name='taxa_dense_2')(network_6)

    network_7 = Dense(txt_dim1, name='txt1_dense_1')(txt1_in)
    network_7 = BatchNormalization(name='txt1_batchnorm_1')(network_7)
    network_7 = LeakyReLU(alpha=0.1, name='txt1_leakyrelu_1')(network_7)
    network_7 = Dropout(dropout_rate, name='txt1_dropout_1')(network_7)
    network_7 = Dense(txt_dim2, name='txt1_dense_2')(network_7)

    # Concatenate the networks
    combined = Concatenate()([network_1, network_2, network_3, network_4, network_5, network_6, network_7])
    #combined = LeakyReLU(alpha=0.1, name='combined_leakyrelu_1')(combined)
    combined = BatchNormalization(name = 'combined_batchnorm_1')(combined)
    combined = Dense(final_dim, name='combined_dense_1', activation='relu')(combined)

    # First level output
    output_1 = Dense(output_split[0], activation='sigmoid', name='final_output_1_112')(combined)

    # Second level output, connected to first level
    combined_2 = Concatenate()([combined, output_1])
    output_2 = Dense(output_split[1]-output_split[0], activation='sigmoid', name='final_output_2_112')(combined_2)

    # Third level output, connected to second level
    combined_3 = Concatenate()([combined, output_1, output_2])
    output_3 = Dense(output_split[2]-output_split[1], activation='sigmoid', name='final_output_3_112')(combined_3)

    # Fourth level output, connected to third level
    combined_4 = Concatenate()([combined, output_1, output_2, output_3])
    output_4 = Dense(output_split[3]-output_split[2], activation='sigmoid', name='final_output_4_112')(combined_4)

    # Fifth level output, connected to fourth level
    combined_5 = Concatenate()([combined, output_1, output_2, output_3, output_4])
    output_5 = Dense(output_split[4]-output_split[3], activation='sigmoid', name='final_output_5_112')(combined_5)

    combined_6 = Concatenate()([combined, output_1, output_2, output_3, output_4, output_5])
    output_6 = Dense(Y.shape[1]-output_split[4], activation='sigmoid', name='final_output_6_112')(combined_6)

    # Create the model
    model = Model(inputs=[t5_in, esm1_in, mlpr_in, knn_in, lr_in, taxa_in, txt1_in],
                  outputs=[output_1, output_2, output_3, output_4, output_5, output_6])

    #lr scheduling
    def lr_schedule(epoch, lr):
        if epoch > 0 and epoch % 7 == 0:
            lr = lr * 0.5
        return lr

    # Define callbacks
    checkpoint_loss = ModelCheckpoint(f'{save_name}.hdf5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='min')
    csv_logger = CSVLogger(f'{save_name}.csv')
    lr_callback = LearningRateScheduler(lr_schedule, verbose=1)
    weights_list = df['IA_weight'].values.tolist()

    #Add weights from IA
    weights_1 = weights_list[:output_split[0]]
    weights_2 = weights_list[output_split[0]:output_split[1]]
    weights_3 = weights_list[output_split[1]:output_split[2]]
    weights_4 = weights_list[output_split[2]:output_split[3]]
    weights_5 = weights_list[output_split[3]:output_split[4]]
    weights_6 = weights_list[output_split[4]:]

    # Compile model
    model.compile(optimizer=Adam(learning_rate=0.0003),
    loss={'final_output_1_112': 'binary_crossentropy',
          'final_output_2_112': 'binary_crossentropy',
          'final_output_3_112': 'binary_crossentropy',
          'final_output_4_112': 'binary_crossentropy',
          'final_output_5_112': 'binary_crossentropy',
          'final_output_6_112': 'binary_crossentropy'},
    loss_weights={'final_output_1_112': weights_1,
          'final_output_2_112': weights_2,
          'final_output_3_112': weights_3,
          'final_output_4_112': weights_4,
          'final_output_5_112': weights_5,
          'final_output_6_112': weights_6},
    metrics=['binary_accuracy', tf.keras.metrics.AUC()])

    # Train model
    history = model.fit([x_tr_1, x_tr_2, x_tr_3, x_tr_4, x_tr_5, x_tr_6, x_tr_7], [y_tr_1, y_tr_2, y_tr_3, y_tr_4, y_tr_5, y_tr_6],
              validation_data=([x_val_1, x_val_2, x_val_3, x_val_4, x_val_5, x_val_6, x_val_7], [y_val_1, y_val_2, y_val_3, y_val_4, y_val_5, y_val_6]),
              epochs=n_epochs, batch_size=256,
              callbacks=[lr_callback, checkpoint_loss, csv_logger])

    # Code helth
    K.clear_session()
    gc.collect()

    fold_ct +=1
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 1/20
# 248/248 [==============================] - ETA: 0s - loss: 1.9243 - final_output_1_112_loss: 0.2927 - final_output_2_112_loss: 0.1947 - final_output_3_112_loss: 0.2023 - final_output_4_112_loss: 0.1249 - final_output_5_112_loss: 0.0876 - final_output_6_112_loss: 0.0513 - final_output_1_112_binary_accuracy: 0.8781 - final_output_1_112_auc: 0.9341 - final_output_2_112_binary_accuracy: 0.9362 - final_output_2_112_auc: 0.8022 - final_output_3_112_binary_accuracy: 0.9212 - final_output_3_112_auc: 0.9229 - final_output_4_112_binary_accuracy: 0.9633 - final_output_4_112_auc: 0.7693 - final_output_5_112_binary_accuracy: 0.9713 - final_output_5_112_auc: 0.8673 - final_output_6_112_binary_accuracy: 0.9847 - final_output_6_112_auc: 0.6872
# Epoch 1: val_loss improved from inf to 2.10678, saving model to /content/drive/MyDrive/CAFA5 2023/1.30/MFO_fc1_r1_1.30.4.hdf5
# 248/248 [==============================] - 29s 46ms/step - loss: 1.9243 - final_output_1_112_loss: 0.2927 - final_output_2_112_loss: 0.1947 - final_output_3_112_loss: 0.2023 - final_output_4_112_loss: 0.1249 - final_output_5_112_loss: 0.0876 - final_output_6_112_loss: 0.0513 - final_output_1_112_binary_accuracy: 0.8781 - final_output_1_112_auc: 0.9341 - final_output_2_112_binary_accuracy: 0.9362 - final_output_2_112_auc: 0.8022 - final_output_3_112_binary_accuracy: 0.9212 - final_output_3_112_auc: 0.9229 - final_output_4_112_binary_accuracy: 0.9633 - final_output_4_112_auc: 0.7693 - final_output_5_112_binary_accuracy: 0.9713 - final_output_5_112_auc: 0.8673 - final_output_6_112_binary_accuracy: 0.9847 - final_output_6_112_auc: 0.6872 - val_loss: 2.1068 - val_final_output_1_112_loss: 0.3705 - val_final_output_2_112_loss: 0.2008 - val_final_output_3_112_loss: 0.2273 - val_final_output_4_112_loss: 0.1285 - val_final_output_5_112_loss: 0.0897 - val_final_output_6_112_loss: 0.0447 - val_final_output_1_112_binary_accuracy: 0.8575 - val_final_output_1_112_auc: 0.9052 - val_final_output_2_112_binary_accuracy: 0.9415 - val_final_output_2_112_auc: 0.7827 - val_final_output_3_112_binary_accuracy: 0.9216 - val_final_output_3_112_auc: 0.9167 - val_final_output_4_112_binary_accuracy: 0.9739 - val_final_output_4_112_auc: 0.8176 - val_final_output_5_112_binary_accuracy: 0.9808 - val_final_output_5_112_auc: 0.8889 - val_final_output_6_112_binary_accuracy: 0.9972 - val_final_output_6_112_auc: 0.8100 - lr: 3.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 2/20
# 248/248 [==============================] - ETA: 0s - loss: 1.2378 - final_output_1_112_loss: 0.2195 - final_output_2_112_loss: 0.1510 - final_output_3_112_loss: 0.1358 - final_output_4_112_loss: 0.0789 - final_output_5_112_loss: 0.0435 - final_output_6_112_loss: 0.0135 - final_output_1_112_binary_accuracy: 0.9104 - final_output_1_112_auc: 0.9635 - final_output_2_112_binary_accuracy: 0.9480 - final_output_2_112_auc: 0.8902 - final_output_3_112_binary_accuracy: 0.9493 - final_output_3_112_auc: 0.9656 - final_output_4_112_binary_accuracy: 0.9775 - final_output_4_112_auc: 0.8954 - final_output_5_112_binary_accuracy: 0.9861 - final_output_5_112_auc: 0.9578 - final_output_6_112_binary_accuracy: 0.9974 - final_output_6_112_auc: 0.8339
# Epoch 2: val_loss improved from 2.10678 to 1.39502, saving model to /content/drive/MyDrive/CAFA5 2023/1.30/MFO_fc1_r1_1.30.4.hdf5
# 248/248 [==============================] - 7s 29ms/step - loss: 1.2378 - final_output_1_112_loss: 0.2195 - final_output_2_112_loss: 0.1510 - final_output_3_112_loss: 0.1358 - final_output_4_112_loss: 0.0789 - final_output_5_112_loss: 0.0435 - final_output_6_112_loss: 0.0135 - final_output_1_112_binary_accuracy: 0.9104 - final_output_1_112_auc: 0.9635 - final_output_2_112_binary_accuracy: 0.9480 - final_output_2_112_auc: 0.8902 - final_output_3_112_binary_accuracy: 0.9493 - final_output_3_112_auc: 0.9656 - final_output_4_112_binary_accuracy: 0.9775 - final_output_4_112_auc: 0.8954 - final_output_5_112_binary_accuracy: 0.9861 - final_output_5_112_auc: 0.9578 - final_output_6_112_binary_accuracy: 0.9974 - final_output_6_112_auc: 0.8339 - val_loss: 1.3950 - val_final_output_1_112_loss: 0.2509 - val_final_output_2_112_loss: 0.1617 - val_final_output_3_112_loss: 0.1526 - val_final_output_4_112_loss: 0.0837 - val_final_output_5_112_loss: 0.0507 - val_final_output_6_112_loss: 0.0179 - val_final_output_1_112_binary_accuracy: 0.9004 - val_final_output_1_112_auc: 0.9565 - val_final_output_2_112_binary_accuracy: 0.9465 - val_final_output_2_112_auc: 0.8711 - val_final_output_3_112_binary_accuracy: 0.9457 - val_final_output_3_112_auc: 0.9597 - val_final_output_4_112_binary_accuracy: 0.9765 - val_final_output_4_112_auc: 0.9098 - val_final_output_5_112_binary_accuracy: 0.9837 - val_final_output_5_112_auc: 0.9619 - val_final_output_6_112_binary_accuracy: 0.9974 - val_final_output_6_112_auc: 0.8980 - lr: 3.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 3/20
# 248/248 [==============================] - ETA: 0s - loss: 1.0849 - final_output_1_112_loss: 0.1921 - final_output_2_112_loss: 0.1339 - final_output_3_112_loss: 0.1187 - final_output_4_112_loss: 0.0710 - final_output_5_112_loss: 0.0375 - final_output_6_112_loss: 0.0117 - final_output_1_112_binary_accuracy: 0.9217 - final_output_1_112_auc: 0.9720 - final_output_2_112_binary_accuracy: 0.9524 - final_output_2_112_auc: 0.9185 - final_output_3_112_binary_accuracy: 0.9551 - final_output_3_112_auc: 0.9741 - final_output_4_112_binary_accuracy: 0.9788 - final_output_4_112_auc: 0.9190 - final_output_5_112_binary_accuracy: 0.9877 - final_output_5_112_auc: 0.9695 - final_output_6_112_binary_accuracy: 0.9975 - final_output_6_112_auc: 0.8760
# Epoch 3: val_loss improved from 1.39502 to 1.18183, saving model to /content/drive/MyDrive/CAFA5 2023/1.30/MFO_fc1_r1_1.30.4.hdf5
# 248/248 [==============================] - 7s 29ms/step - loss: 1.0849 - final_output_1_112_loss: 0.1921 - final_output_2_112_loss: 0.1339 - final_output_3_112_loss: 0.1187 - final_output_4_112_loss: 0.0710 - final_output_5_112_loss: 0.0375 - final_output_6_112_loss: 0.0117 - final_output_1_112_binary_accuracy: 0.9217 - final_output_1_112_auc: 0.9720 - final_output_2_112_binary_accuracy: 0.9524 - final_output_2_112_auc: 0.9185 - final_output_3_112_binary_accuracy: 0.9551 - final_output_3_112_auc: 0.9741 - final_output_4_112_binary_accuracy: 0.9788 - final_output_4_112_auc: 0.9190 - final_output_5_112_binary_accuracy: 0.9877 - final_output_5_112_auc: 0.9695 - final_output_6_112_binary_accuracy: 0.9975 - final_output_6_112_auc: 0.8760 - val_loss: 1.1818 - val_final_output_1_112_loss: 0.2170 - val_final_output_2_112_loss: 0.1492 - val_final_output_3_112_loss: 0.1262 - val_final_output_4_112_loss: 0.0701 - val_final_output_5_112_loss: 0.0391 - val_final_output_6_112_loss: 0.0120 - val_final_output_1_112_binary_accuracy: 0.9110 - val_final_output_1_112_auc: 0.9640 - val_final_output_2_112_binary_accuracy: 0.9492 - val_final_output_2_112_auc: 0.8925 - val_final_output_3_112_binary_accuracy: 0.9534 - val_final_output_3_112_auc: 0.9709 - val_final_output_4_112_binary_accuracy: 0.9793 - val_final_output_4_112_auc: 0.9292 - val_final_output_5_112_binary_accuracy: 0.9873 - val_final_output_5_112_auc: 0.9687 - val_final_output_6_112_binary_accuracy: 0.9976 - val_final_output_6_112_auc: 0.9134 - lr: 3.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 4/20
# 247/248 [============================>.] - ETA: 0s - loss: 0.9749 - final_output_1_112_loss: 0.1714 - final_output_2_112_loss: 0.1203 - final_output_3_112_loss: 0.1074 - final_output_4_112_loss: 0.0657 - final_output_5_112_loss: 0.0336 - final_output_6_112_loss: 0.0105 - final_output_1_112_binary_accuracy: 0.9301 - final_output_1_112_auc: 0.9776 - final_output_2_112_binary_accuracy: 0.9558 - final_output_2_112_auc: 0.9372 - final_output_3_112_binary_accuracy: 0.9590 - final_output_3_112_auc: 0.9789 - final_output_4_112_binary_accuracy: 0.9800 - final_output_4_112_auc: 0.9326 - final_output_5_112_binary_accuracy: 0.9886 - final_output_5_112_auc: 0.9758 - final_output_6_112_binary_accuracy: 0.9976 - final_output_6_112_auc: 0.9003
# Epoch 4: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 26ms/step - loss: 0.9748 - final_output_1_112_loss: 0.1714 - final_output_2_112_loss: 0.1204 - final_output_3_112_loss: 0.1074 - final_output_4_112_loss: 0.0657 - final_output_5_112_loss: 0.0336 - final_output_6_112_loss: 0.0105 - final_output_1_112_binary_accuracy: 0.9301 - final_output_1_112_auc: 0.9776 - final_output_2_112_binary_accuracy: 0.9558 - final_output_2_112_auc: 0.9372 - final_output_3_112_binary_accuracy: 0.9590 - final_output_3_112_auc: 0.9789 - final_output_4_112_binary_accuracy: 0.9800 - final_output_4_112_auc: 0.9327 - final_output_5_112_binary_accuracy: 0.9886 - final_output_5_112_auc: 0.9758 - final_output_6_112_binary_accuracy: 0.9976 - final_output_6_112_auc: 0.9003 - val_loss: 1.1866 - val_final_output_1_112_loss: 0.2233 - val_final_output_2_112_loss: 0.1499 - val_final_output_3_112_loss: 0.1268 - val_final_output_4_112_loss: 0.0680 - val_final_output_5_112_loss: 0.0383 - val_final_output_6_112_loss: 0.0108 - val_final_output_1_112_binary_accuracy: 0.9092 - val_final_output_1_112_auc: 0.9637 - val_final_output_2_112_binary_accuracy: 0.9488 - val_final_output_2_112_auc: 0.8947 - val_final_output_3_112_binary_accuracy: 0.9527 - val_final_output_3_112_auc: 0.9715 - val_final_output_4_112_binary_accuracy: 0.9789 - val_final_output_4_112_auc: 0.9359 - val_final_output_5_112_binary_accuracy: 0.9873 - val_final_output_5_112_auc: 0.9705 - val_final_output_6_112_binary_accuracy: 0.9976 - val_final_output_6_112_auc: 0.9254 - lr: 3.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 5/20
# 247/248 [============================>.] - ETA: 0s - loss: 0.8889 - final_output_1_112_loss: 0.1542 - final_output_2_112_loss: 0.1097 - final_output_3_112_loss: 0.0987 - final_output_4_112_loss: 0.0617 - final_output_5_112_loss: 0.0308 - final_output_6_112_loss: 0.0096 - final_output_1_112_binary_accuracy: 0.9379 - final_output_1_112_auc: 0.9819 - final_output_2_112_binary_accuracy: 0.9593 - final_output_2_112_auc: 0.9491 - final_output_3_112_binary_accuracy: 0.9623 - final_output_3_112_auc: 0.9824 - final_output_4_112_binary_accuracy: 0.9809 - final_output_4_112_auc: 0.9420 - final_output_5_112_binary_accuracy: 0.9895 - final_output_5_112_auc: 0.9793 - final_output_6_112_binary_accuracy: 0.9977 - final_output_6_112_auc: 0.9180
# Epoch 5: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 26ms/step - loss: 0.8890 - final_output_1_112_loss: 0.1543 - final_output_2_112_loss: 0.1097 - final_output_3_112_loss: 0.0987 - final_output_4_112_loss: 0.0617 - final_output_5_112_loss: 0.0308 - final_output_6_112_loss: 0.0096 - final_output_1_112_binary_accuracy: 0.9379 - final_output_1_112_auc: 0.9819 - final_output_2_112_binary_accuracy: 0.9593 - final_output_2_112_auc: 0.9492 - final_output_3_112_binary_accuracy: 0.9623 - final_output_3_112_auc: 0.9824 - final_output_4_112_binary_accuracy: 0.9809 - final_output_4_112_auc: 0.9420 - final_output_5_112_binary_accuracy: 0.9895 - final_output_5_112_auc: 0.9793 - final_output_6_112_binary_accuracy: 0.9977 - final_output_6_112_auc: 0.9180 - val_loss: 1.1830 - val_final_output_1_112_loss: 0.2251 - val_final_output_2_112_loss: 0.1517 - val_final_output_3_112_loss: 0.1253 - val_final_output_4_112_loss: 0.0652 - val_final_output_5_112_loss: 0.0374 - val_final_output_6_112_loss: 0.0101 - val_final_output_1_112_binary_accuracy: 0.9112 - val_final_output_1_112_auc: 0.9628 - val_final_output_2_112_binary_accuracy: 0.9490 - val_final_output_2_112_auc: 0.8927 - val_final_output_3_112_binary_accuracy: 0.9536 - val_final_output_3_112_auc: 0.9709 - val_final_output_4_112_binary_accuracy: 0.9802 - val_final_output_4_112_auc: 0.9366 - val_final_output_5_112_binary_accuracy: 0.9878 - val_final_output_5_112_auc: 0.9703 - val_final_output_6_112_binary_accuracy: 0.9977 - val_final_output_6_112_auc: 0.9357 - lr: 3.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 6/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.8134 - final_output_1_112_loss: 0.1389 - final_output_2_112_loss: 0.1002 - final_output_3_112_loss: 0.0912 - final_output_4_112_loss: 0.0586 - final_output_5_112_loss: 0.0284 - final_output_6_112_loss: 0.0089 - final_output_1_112_binary_accuracy: 0.9440 - final_output_1_112_auc: 0.9852 - final_output_2_112_binary_accuracy: 0.9624 - final_output_2_112_auc: 0.9586 - final_output_3_112_binary_accuracy: 0.9652 - final_output_3_112_auc: 0.9849 - final_output_4_112_binary_accuracy: 0.9817 - final_output_4_112_auc: 0.9475 - final_output_5_112_binary_accuracy: 0.9902 - final_output_5_112_auc: 0.9822 - final_output_6_112_binary_accuracy: 0.9978 - final_output_6_112_auc: 0.9308
# Epoch 6: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 26ms/step - loss: 0.8137 - final_output_1_112_loss: 0.1390 - final_output_2_112_loss: 0.1002 - final_output_3_112_loss: 0.0912 - final_output_4_112_loss: 0.0586 - final_output_5_112_loss: 0.0284 - final_output_6_112_loss: 0.0089 - final_output_1_112_binary_accuracy: 0.9440 - final_output_1_112_auc: 0.9852 - final_output_2_112_binary_accuracy: 0.9624 - final_output_2_112_auc: 0.9586 - final_output_3_112_binary_accuracy: 0.9652 - final_output_3_112_auc: 0.9849 - final_output_4_112_binary_accuracy: 0.9817 - final_output_4_112_auc: 0.9474 - final_output_5_112_binary_accuracy: 0.9902 - final_output_5_112_auc: 0.9822 - final_output_6_112_binary_accuracy: 0.9978 - final_output_6_112_auc: 0.9308 - val_loss: 1.1929 - val_final_output_1_112_loss: 0.2325 - val_final_output_2_112_loss: 0.1530 - val_final_output_3_112_loss: 0.1248 - val_final_output_4_112_loss: 0.0646 - val_final_output_5_112_loss: 0.0371 - val_final_output_6_112_loss: 0.0095 - val_final_output_1_112_binary_accuracy: 0.9129 - val_final_output_1_112_auc: 0.9636 - val_final_output_2_112_binary_accuracy: 0.9490 - val_final_output_2_112_auc: 0.8914 - val_final_output_3_112_binary_accuracy: 0.9547 - val_final_output_3_112_auc: 0.9710 - val_final_output_4_112_binary_accuracy: 0.9803 - val_final_output_4_112_auc: 0.9384 - val_final_output_5_112_binary_accuracy: 0.9878 - val_final_output_5_112_auc: 0.9680 - val_final_output_6_112_binary_accuracy: 0.9977 - val_final_output_6_112_auc: 0.9384 - lr: 3.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 7/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.7514 - final_output_1_112_loss: 0.1276 - final_output_2_112_loss: 0.0915 - final_output_3_112_loss: 0.0847 - final_output_4_112_loss: 0.0558 - final_output_5_112_loss: 0.0265 - final_output_6_112_loss: 0.0084 - final_output_1_112_binary_accuracy: 0.9489 - final_output_1_112_auc: 0.9875 - final_output_2_112_binary_accuracy: 0.9650 - final_output_2_112_auc: 0.9664 - final_output_3_112_binary_accuracy: 0.9674 - final_output_3_112_auc: 0.9873 - final_output_4_112_binary_accuracy: 0.9825 - final_output_4_112_auc: 0.9530 - final_output_5_112_binary_accuracy: 0.9907 - final_output_5_112_auc: 0.9843 - final_output_6_112_binary_accuracy: 0.9979 - final_output_6_112_auc: 0.9399
# Epoch 7: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 26ms/step - loss: 0.7518 - final_output_1_112_loss: 0.1277 - final_output_2_112_loss: 0.0915 - final_output_3_112_loss: 0.0848 - final_output_4_112_loss: 0.0559 - final_output_5_112_loss: 0.0265 - final_output_6_112_loss: 0.0084 - final_output_1_112_binary_accuracy: 0.9489 - final_output_1_112_auc: 0.9875 - final_output_2_112_binary_accuracy: 0.9650 - final_output_2_112_auc: 0.9664 - final_output_3_112_binary_accuracy: 0.9674 - final_output_3_112_auc: 0.9872 - final_output_4_112_binary_accuracy: 0.9824 - final_output_4_112_auc: 0.9529 - final_output_5_112_binary_accuracy: 0.9907 - final_output_5_112_auc: 0.9843 - final_output_6_112_binary_accuracy: 0.9979 - final_output_6_112_auc: 0.9399 - val_loss: 1.2236 - val_final_output_1_112_loss: 0.2383 - val_final_output_2_112_loss: 0.1595 - val_final_output_3_112_loss: 0.1285 - val_final_output_4_112_loss: 0.0638 - val_final_output_5_112_loss: 0.0370 - val_final_output_6_112_loss: 0.0094 - val_final_output_1_112_binary_accuracy: 0.9119 - val_final_output_1_112_auc: 0.9619 - val_final_output_2_112_binary_accuracy: 0.9464 - val_final_output_2_112_auc: 0.8888 - val_final_output_3_112_binary_accuracy: 0.9543 - val_final_output_3_112_auc: 0.9698 - val_final_output_4_112_binary_accuracy: 0.9806 - val_final_output_4_112_auc: 0.9384 - val_final_output_5_112_binary_accuracy: 0.9880 - val_final_output_5_112_auc: 0.9673 - val_final_output_6_112_binary_accuracy: 0.9977 - val_final_output_6_112_auc: 0.9446 - lr: 3.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 8/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.6470 - final_output_1_112_loss: 0.1048 - final_output_2_112_loss: 0.0776 - final_output_3_112_loss: 0.0744 - final_output_4_112_loss: 0.0528 - final_output_5_112_loss: 0.0237 - final_output_6_112_loss: 0.0078 - final_output_1_112_binary_accuracy: 0.9581 - final_output_1_112_auc: 0.9917 - final_output_2_112_binary_accuracy: 0.9704 - final_output_2_112_auc: 0.9774 - final_output_3_112_binary_accuracy: 0.9712 - final_output_3_112_auc: 0.9902 - final_output_4_112_binary_accuracy: 0.9833 - final_output_4_112_auc: 0.9576 - final_output_5_112_binary_accuracy: 0.9916 - final_output_5_112_auc: 0.9884 - final_output_6_112_binary_accuracy: 0.9979 - final_output_6_112_auc: 0.9480
# Epoch 8: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 26ms/step - loss: 0.6467 - final_output_1_112_loss: 0.1048 - final_output_2_112_loss: 0.0775 - final_output_3_112_loss: 0.0744 - final_output_4_112_loss: 0.0527 - final_output_5_112_loss: 0.0237 - final_output_6_112_loss: 0.0078 - final_output_1_112_binary_accuracy: 0.9580 - final_output_1_112_auc: 0.9917 - final_output_2_112_binary_accuracy: 0.9704 - final_output_2_112_auc: 0.9774 - final_output_3_112_binary_accuracy: 0.9712 - final_output_3_112_auc: 0.9902 - final_output_4_112_binary_accuracy: 0.9834 - final_output_4_112_auc: 0.9576 - final_output_5_112_binary_accuracy: 0.9916 - final_output_5_112_auc: 0.9883 - final_output_6_112_binary_accuracy: 0.9979 - final_output_6_112_auc: 0.9480 - val_loss: 1.2322 - val_final_output_1_112_loss: 0.2442 - val_final_output_2_112_loss: 0.1623 - val_final_output_3_112_loss: 0.1269 - val_final_output_4_112_loss: 0.0630 - val_final_output_5_112_loss: 0.0365 - val_final_output_6_112_loss: 0.0089 - val_final_output_1_112_binary_accuracy: 0.9143 - val_final_output_1_112_auc: 0.9620 - val_final_output_2_112_binary_accuracy: 0.9487 - val_final_output_2_112_auc: 0.8830 - val_final_output_3_112_binary_accuracy: 0.9555 - val_final_output_3_112_auc: 0.9697 - val_final_output_4_112_binary_accuracy: 0.9810 - val_final_output_4_112_auc: 0.9372 - val_final_output_5_112_binary_accuracy: 0.9883 - val_final_output_5_112_auc: 0.9635 - val_final_output_6_112_binary_accuracy: 0.9978 - val_final_output_6_112_auc: 0.9432 - lr: 1.5000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 9/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.5941 - final_output_1_112_loss: 0.0937 - final_output_2_112_loss: 0.0707 - final_output_3_112_loss: 0.0690 - final_output_4_112_loss: 0.0508 - final_output_5_112_loss: 0.0222 - final_output_6_112_loss: 0.0075 - final_output_1_112_binary_accuracy: 0.9632 - final_output_1_112_auc: 0.9932 - final_output_2_112_binary_accuracy: 0.9728 - final_output_2_112_auc: 0.9815 - final_output_3_112_binary_accuracy: 0.9732 - final_output_3_112_auc: 0.9917 - final_output_4_112_binary_accuracy: 0.9839 - final_output_4_112_auc: 0.9609 - final_output_5_112_binary_accuracy: 0.9922 - final_output_5_112_auc: 0.9895 - final_output_6_112_binary_accuracy: 0.9980 - final_output_6_112_auc: 0.9521
# Epoch 9: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 26ms/step - loss: 0.5940 - final_output_1_112_loss: 0.0937 - final_output_2_112_loss: 0.0707 - final_output_3_112_loss: 0.0690 - final_output_4_112_loss: 0.0508 - final_output_5_112_loss: 0.0222 - final_output_6_112_loss: 0.0075 - final_output_1_112_binary_accuracy: 0.9632 - final_output_1_112_auc: 0.9932 - final_output_2_112_binary_accuracy: 0.9728 - final_output_2_112_auc: 0.9814 - final_output_3_112_binary_accuracy: 0.9732 - final_output_3_112_auc: 0.9917 - final_output_4_112_binary_accuracy: 0.9839 - final_output_4_112_auc: 0.9609 - final_output_5_112_binary_accuracy: 0.9922 - final_output_5_112_auc: 0.9895 - final_output_6_112_binary_accuracy: 0.9980 - final_output_6_112_auc: 0.9522 - val_loss: 1.2621 - val_final_output_1_112_loss: 0.2546 - val_final_output_2_112_loss: 0.1657 - val_final_output_3_112_loss: 0.1287 - val_final_output_4_112_loss: 0.0636 - val_final_output_5_112_loss: 0.0370 - val_final_output_6_112_loss: 0.0088 - val_final_output_1_112_binary_accuracy: 0.9145 - val_final_output_1_112_auc: 0.9613 - val_final_output_2_112_binary_accuracy: 0.9483 - val_final_output_2_112_auc: 0.8822 - val_final_output_3_112_binary_accuracy: 0.9556 - val_final_output_3_112_auc: 0.9689 - val_final_output_4_112_binary_accuracy: 0.9808 - val_final_output_4_112_auc: 0.9369 - val_final_output_5_112_binary_accuracy: 0.9882 - val_final_output_5_112_auc: 0.9625 - val_final_output_6_112_binary_accuracy: 0.9978 - val_final_output_6_112_auc: 0.9438 - lr: 1.5000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 10/20
# 247/248 [============================>.] - ETA: 0s - loss: 0.5589 - final_output_1_112_loss: 0.0864 - final_output_2_112_loss: 0.0661 - final_output_3_112_loss: 0.0656 - final_output_4_112_loss: 0.0496 - final_output_5_112_loss: 0.0210 - final_output_6_112_loss: 0.0073 - final_output_1_112_binary_accuracy: 0.9662 - final_output_1_112_auc: 0.9943 - final_output_2_112_binary_accuracy: 0.9748 - final_output_2_112_auc: 0.9842 - final_output_3_112_binary_accuracy: 0.9748 - final_output_3_112_auc: 0.9924 - final_output_4_112_binary_accuracy: 0.9842 - final_output_4_112_auc: 0.9628 - final_output_5_112_binary_accuracy: 0.9925 - final_output_5_112_auc: 0.9907 - final_output_6_112_binary_accuracy: 0.9980 - final_output_6_112_auc: 0.9547
# Epoch 10: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 25ms/step - loss: 0.5589 - final_output_1_112_loss: 0.0864 - final_output_2_112_loss: 0.0661 - final_output_3_112_loss: 0.0656 - final_output_4_112_loss: 0.0496 - final_output_5_112_loss: 0.0210 - final_output_6_112_loss: 0.0073 - final_output_1_112_binary_accuracy: 0.9662 - final_output_1_112_auc: 0.9943 - final_output_2_112_binary_accuracy: 0.9748 - final_output_2_112_auc: 0.9842 - final_output_3_112_binary_accuracy: 0.9748 - final_output_3_112_auc: 0.9924 - final_output_4_112_binary_accuracy: 0.9842 - final_output_4_112_auc: 0.9628 - final_output_5_112_binary_accuracy: 0.9925 - final_output_5_112_auc: 0.9907 - final_output_6_112_binary_accuracy: 0.9980 - final_output_6_112_auc: 0.9547 - val_loss: 1.3051 - val_final_output_1_112_loss: 0.2662 - val_final_output_2_112_loss: 0.1719 - val_final_output_3_112_loss: 0.1326 - val_final_output_4_112_loss: 0.0640 - val_final_output_5_112_loss: 0.0376 - val_final_output_6_112_loss: 0.0088 - val_final_output_1_112_binary_accuracy: 0.9118 - val_final_output_1_112_auc: 0.9591 - val_final_output_2_112_binary_accuracy: 0.9469 - val_final_output_2_112_auc: 0.8789 - val_final_output_3_112_binary_accuracy: 0.9547 - val_final_output_3_112_auc: 0.9674 - val_final_output_4_112_binary_accuracy: 0.9806 - val_final_output_4_112_auc: 0.9381 - val_final_output_5_112_binary_accuracy: 0.9882 - val_final_output_5_112_auc: 0.9628 - val_final_output_6_112_binary_accuracy: 0.9978 - val_final_output_6_112_auc: 0.9441 - lr: 1.5000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 11/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.5304 - final_output_1_112_loss: 0.0811 - final_output_2_112_loss: 0.0624 - final_output_3_112_loss: 0.0623 - final_output_4_112_loss: 0.0483 - final_output_5_112_loss: 0.0202 - final_output_6_112_loss: 0.0070 - final_output_1_112_binary_accuracy: 0.9679 - final_output_1_112_auc: 0.9950 - final_output_2_112_binary_accuracy: 0.9759 - final_output_2_112_auc: 0.9862 - final_output_3_112_binary_accuracy: 0.9758 - final_output_3_112_auc: 0.9932 - final_output_4_112_binary_accuracy: 0.9846 - final_output_4_112_auc: 0.9638 - final_output_5_112_binary_accuracy: 0.9927 - final_output_5_112_auc: 0.9914 - final_output_6_112_binary_accuracy: 0.9981 - final_output_6_112_auc: 0.9581
# Epoch 11: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 26ms/step - loss: 0.5304 - final_output_1_112_loss: 0.0811 - final_output_2_112_loss: 0.0624 - final_output_3_112_loss: 0.0623 - final_output_4_112_loss: 0.0483 - final_output_5_112_loss: 0.0202 - final_output_6_112_loss: 0.0070 - final_output_1_112_binary_accuracy: 0.9679 - final_output_1_112_auc: 0.9949 - final_output_2_112_binary_accuracy: 0.9759 - final_output_2_112_auc: 0.9862 - final_output_3_112_binary_accuracy: 0.9758 - final_output_3_112_auc: 0.9932 - final_output_4_112_binary_accuracy: 0.9846 - final_output_4_112_auc: 0.9638 - final_output_5_112_binary_accuracy: 0.9927 - final_output_5_112_auc: 0.9914 - final_output_6_112_binary_accuracy: 0.9981 - final_output_6_112_auc: 0.9581 - val_loss: 1.3235 - val_final_output_1_112_loss: 0.2709 - val_final_output_2_112_loss: 0.1757 - val_final_output_3_112_loss: 0.1343 - val_final_output_4_112_loss: 0.0633 - val_final_output_5_112_loss: 0.0375 - val_final_output_6_112_loss: 0.0086 - val_final_output_1_112_binary_accuracy: 0.9137 - val_final_output_1_112_auc: 0.9587 - val_final_output_2_112_binary_accuracy: 0.9476 - val_final_output_2_112_auc: 0.8727 - val_final_output_3_112_binary_accuracy: 0.9554 - val_final_output_3_112_auc: 0.9670 - val_final_output_4_112_binary_accuracy: 0.9813 - val_final_output_4_112_auc: 0.9356 - val_final_output_5_112_binary_accuracy: 0.9886 - val_final_output_5_112_auc: 0.9589 - val_final_output_6_112_binary_accuracy: 0.9978 - val_final_output_6_112_auc: 0.9428 - lr: 1.5000e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 12/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.5033 - final_output_1_112_loss: 0.0764 - final_output_2_112_loss: 0.0580 - final_output_3_112_loss: 0.0599 - final_output_4_112_loss: 0.0474 - final_output_5_112_loss: 0.0193 - final_output_6_112_loss: 0.0068 - final_output_1_112_binary_accuracy: 0.9703 - final_output_1_112_auc: 0.9955 - final_output_2_112_binary_accuracy: 0.9774 - final_output_2_112_auc: 0.9882 - final_output_3_112_binary_accuracy: 0.9768 - final_output_3_112_auc: 0.9937 - final_output_4_112_binary_accuracy: 0.9848 - final_output_4_112_auc: 0.9655 - final_output_5_112_binary_accuracy: 0.9930 - final_output_5_112_auc: 0.9919 - final_output_6_112_binary_accuracy: 0.9981 - final_output_6_112_auc: 0.9602
# Epoch 12: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 26ms/step - loss: 0.5036 - final_output_1_112_loss: 0.0764 - final_output_2_112_loss: 0.0581 - final_output_3_112_loss: 0.0600 - final_output_4_112_loss: 0.0474 - final_output_5_112_loss: 0.0194 - final_output_6_112_loss: 0.0068 - final_output_1_112_binary_accuracy: 0.9703 - final_output_1_112_auc: 0.9954 - final_output_2_112_binary_accuracy: 0.9774 - final_output_2_112_auc: 0.9882 - final_output_3_112_binary_accuracy: 0.9767 - final_output_3_112_auc: 0.9937 - final_output_4_112_binary_accuracy: 0.9848 - final_output_4_112_auc: 0.9655 - final_output_5_112_binary_accuracy: 0.9930 - final_output_5_112_auc: 0.9919 - final_output_6_112_binary_accuracy: 0.9981 - final_output_6_112_auc: 0.9602 - val_loss: 1.3480 - val_final_output_1_112_loss: 0.2789 - val_final_output_2_112_loss: 0.1783 - val_final_output_3_112_loss: 0.1357 - val_final_output_4_112_loss: 0.0639 - val_final_output_5_112_loss: 0.0382 - val_final_output_6_112_loss: 0.0086 - val_final_output_1_112_binary_accuracy: 0.9129 - val_final_output_1_112_auc: 0.9581 - val_final_output_2_112_binary_accuracy: 0.9480 - val_final_output_2_112_auc: 0.8714 - val_final_output_3_112_binary_accuracy: 0.9548 - val_final_output_3_112_auc: 0.9662 - val_final_output_4_112_binary_accuracy: 0.9812 - val_final_output_4_112_auc: 0.9364 - val_final_output_5_112_binary_accuracy: 0.9884 - val_final_output_5_112_auc: 0.9581 - val_final_output_6_112_binary_accuracy: 0.9978 - val_final_output_6_112_auc: 0.9447 - lr: 1.5000e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 13/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.4768 - final_output_1_112_loss: 0.0710 - final_output_2_112_loss: 0.0545 - final_output_3_112_loss: 0.0571 - final_output_4_112_loss: 0.0465 - final_output_5_112_loss: 0.0186 - final_output_6_112_loss: 0.0066 - final_output_1_112_binary_accuracy: 0.9723 - final_output_1_112_auc: 0.9961 - final_output_2_112_binary_accuracy: 0.9791 - final_output_2_112_auc: 0.9896 - final_output_3_112_binary_accuracy: 0.9780 - final_output_3_112_auc: 0.9942 - final_output_4_112_binary_accuracy: 0.9851 - final_output_4_112_auc: 0.9668 - final_output_5_112_binary_accuracy: 0.9933 - final_output_5_112_auc: 0.9925 - final_output_6_112_binary_accuracy: 0.9981 - final_output_6_112_auc: 0.9628
# Epoch 13: val_loss did not improve from 1.18183
# 248/248 [==============================] - 7s 27ms/step - loss: 0.4770 - final_output_1_112_loss: 0.0711 - final_output_2_112_loss: 0.0546 - final_output_3_112_loss: 0.0571 - final_output_4_112_loss: 0.0465 - final_output_5_112_loss: 0.0186 - final_output_6_112_loss: 0.0066 - final_output_1_112_binary_accuracy: 0.9722 - final_output_1_112_auc: 0.9961 - final_output_2_112_binary_accuracy: 0.9791 - final_output_2_112_auc: 0.9896 - final_output_3_112_binary_accuracy: 0.9779 - final_output_3_112_auc: 0.9942 - final_output_4_112_binary_accuracy: 0.9851 - final_output_4_112_auc: 0.9668 - final_output_5_112_binary_accuracy: 0.9933 - final_output_5_112_auc: 0.9925 - final_output_6_112_binary_accuracy: 0.9981 - final_output_6_112_auc: 0.9628 - val_loss: 1.3747 - val_final_output_1_112_loss: 0.2860 - val_final_output_2_112_loss: 0.1827 - val_final_output_3_112_loss: 0.1380 - val_final_output_4_112_loss: 0.0638 - val_final_output_5_112_loss: 0.0384 - val_final_output_6_112_loss: 0.0085 - val_final_output_1_112_binary_accuracy: 0.9136 - val_final_output_1_112_auc: 0.9573 - val_final_output_2_112_binary_accuracy: 0.9458 - val_final_output_2_112_auc: 0.8719 - val_final_output_3_112_binary_accuracy: 0.9550 - val_final_output_3_112_auc: 0.9656 - val_final_output_4_112_binary_accuracy: 0.9811 - val_final_output_4_112_auc: 0.9363 - val_final_output_5_112_binary_accuracy: 0.9884 - val_final_output_5_112_auc: 0.9589 - val_final_output_6_112_binary_accuracy: 0.9978 - val_final_output_6_112_auc: 0.9463 - lr: 1.5000e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 14/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.4603 - final_output_1_112_loss: 0.0680 - final_output_2_112_loss: 0.0526 - final_output_3_112_loss: 0.0555 - final_output_4_112_loss: 0.0456 - final_output_5_112_loss: 0.0179 - final_output_6_112_loss: 0.0064 - final_output_1_112_binary_accuracy: 0.9733 - final_output_1_112_auc: 0.9964 - final_output_2_112_binary_accuracy: 0.9796 - final_output_2_112_auc: 0.9905 - final_output_3_112_binary_accuracy: 0.9786 - final_output_3_112_auc: 0.9946 - final_output_4_112_binary_accuracy: 0.9853 - final_output_4_112_auc: 0.9681 - final_output_5_112_binary_accuracy: 0.9935 - final_output_5_112_auc: 0.9930 - final_output_6_112_binary_accuracy: 0.9982 - final_output_6_112_auc: 0.9651
# Epoch 14: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 26ms/step - loss: 0.4603 - final_output_1_112_loss: 0.0680 - final_output_2_112_loss: 0.0526 - final_output_3_112_loss: 0.0554 - final_output_4_112_loss: 0.0455 - final_output_5_112_loss: 0.0179 - final_output_6_112_loss: 0.0064 - final_output_1_112_binary_accuracy: 0.9733 - final_output_1_112_auc: 0.9964 - final_output_2_112_binary_accuracy: 0.9796 - final_output_2_112_auc: 0.9904 - final_output_3_112_binary_accuracy: 0.9786 - final_output_3_112_auc: 0.9946 - final_output_4_112_binary_accuracy: 0.9853 - final_output_4_112_auc: 0.9682 - final_output_5_112_binary_accuracy: 0.9935 - final_output_5_112_auc: 0.9930 - final_output_6_112_binary_accuracy: 0.9982 - final_output_6_112_auc: 0.9650 - val_loss: 1.4022 - val_final_output_1_112_loss: 0.2916 - val_final_output_2_112_loss: 0.1889 - val_final_output_3_112_loss: 0.1395 - val_final_output_4_112_loss: 0.0643 - val_final_output_5_112_loss: 0.0389 - val_final_output_6_112_loss: 0.0084 - val_final_output_1_112_binary_accuracy: 0.9121 - val_final_output_1_112_auc: 0.9567 - val_final_output_2_112_binary_accuracy: 0.9458 - val_final_output_2_112_auc: 0.8668 - val_final_output_3_112_binary_accuracy: 0.9550 - val_final_output_3_112_auc: 0.9658 - val_final_output_4_112_binary_accuracy: 0.9808 - val_final_output_4_112_auc: 0.9376 - val_final_output_5_112_binary_accuracy: 0.9883 - val_final_output_5_112_auc: 0.9581 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9445 - lr: 1.5000e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 15/20
# 247/248 [============================>.] - ETA: 0s - loss: 0.4122 - final_output_1_112_loss: 0.0585 - final_output_2_112_loss: 0.0462 - final_output_3_112_loss: 0.0499 - final_output_4_112_loss: 0.0441 - final_output_5_112_loss: 0.0166 - final_output_6_112_loss: 0.0062 - final_output_1_112_binary_accuracy: 0.9772 - final_output_1_112_auc: 0.9975 - final_output_2_112_binary_accuracy: 0.9823 - final_output_2_112_auc: 0.9928 - final_output_3_112_binary_accuracy: 0.9808 - final_output_3_112_auc: 0.9958 - final_output_4_112_binary_accuracy: 0.9858 - final_output_4_112_auc: 0.9695 - final_output_5_112_binary_accuracy: 0.9940 - final_output_5_112_auc: 0.9942 - final_output_6_112_binary_accuracy: 0.9982 - final_output_6_112_auc: 0.9674
# Epoch 15: val_loss did not improve from 1.18183
# 248/248 [==============================] - 7s 26ms/step - loss: 0.4123 - final_output_1_112_loss: 0.0585 - final_output_2_112_loss: 0.0462 - final_output_3_112_loss: 0.0499 - final_output_4_112_loss: 0.0441 - final_output_5_112_loss: 0.0167 - final_output_6_112_loss: 0.0062 - final_output_1_112_binary_accuracy: 0.9772 - final_output_1_112_auc: 0.9975 - final_output_2_112_binary_accuracy: 0.9823 - final_output_2_112_auc: 0.9928 - final_output_3_112_binary_accuracy: 0.9808 - final_output_3_112_auc: 0.9958 - final_output_4_112_binary_accuracy: 0.9858 - final_output_4_112_auc: 0.9695 - final_output_5_112_binary_accuracy: 0.9940 - final_output_5_112_auc: 0.9942 - final_output_6_112_binary_accuracy: 0.9982 - final_output_6_112_auc: 0.9674 - val_loss: 1.4307 - val_final_output_1_112_loss: 0.3015 - val_final_output_2_112_loss: 0.1919 - val_final_output_3_112_loss: 0.1421 - val_final_output_4_112_loss: 0.0638 - val_final_output_5_112_loss: 0.0390 - val_final_output_6_112_loss: 0.0083 - val_final_output_1_112_binary_accuracy: 0.9143 - val_final_output_1_112_auc: 0.9559 - val_final_output_2_112_binary_accuracy: 0.9474 - val_final_output_2_112_auc: 0.8632 - val_final_output_3_112_binary_accuracy: 0.9556 - val_final_output_3_112_auc: 0.9645 - val_final_output_4_112_binary_accuracy: 0.9815 - val_final_output_4_112_auc: 0.9339 - val_final_output_5_112_binary_accuracy: 0.9885 - val_final_output_5_112_auc: 0.9538 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9427 - lr: 7.5000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 16/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.3919 - final_output_1_112_loss: 0.0539 - final_output_2_112_loss: 0.0433 - final_output_3_112_loss: 0.0481 - final_output_4_112_loss: 0.0435 - final_output_5_112_loss: 0.0161 - final_output_6_112_loss: 0.0061 - final_output_1_112_binary_accuracy: 0.9793 - final_output_1_112_auc: 0.9978 - final_output_2_112_binary_accuracy: 0.9833 - final_output_2_112_auc: 0.9936 - final_output_3_112_binary_accuracy: 0.9814 - final_output_3_112_auc: 0.9961 - final_output_4_112_binary_accuracy: 0.9859 - final_output_4_112_auc: 0.9708 - final_output_5_112_binary_accuracy: 0.9941 - final_output_5_112_auc: 0.9944 - final_output_6_112_binary_accuracy: 0.9982 - final_output_6_112_auc: 0.9685
# Epoch 16: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3920 - final_output_1_112_loss: 0.0540 - final_output_2_112_loss: 0.0433 - final_output_3_112_loss: 0.0481 - final_output_4_112_loss: 0.0434 - final_output_5_112_loss: 0.0161 - final_output_6_112_loss: 0.0061 - final_output_1_112_binary_accuracy: 0.9793 - final_output_1_112_auc: 0.9978 - final_output_2_112_binary_accuracy: 0.9833 - final_output_2_112_auc: 0.9936 - final_output_3_112_binary_accuracy: 0.9814 - final_output_3_112_auc: 0.9961 - final_output_4_112_binary_accuracy: 0.9859 - final_output_4_112_auc: 0.9708 - final_output_5_112_binary_accuracy: 0.9941 - final_output_5_112_auc: 0.9944 - final_output_6_112_binary_accuracy: 0.9982 - final_output_6_112_auc: 0.9686 - val_loss: 1.4447 - val_final_output_1_112_loss: 0.3053 - val_final_output_2_112_loss: 0.1952 - val_final_output_3_112_loss: 0.1427 - val_final_output_4_112_loss: 0.0635 - val_final_output_5_112_loss: 0.0390 - val_final_output_6_112_loss: 0.0082 - val_final_output_1_112_binary_accuracy: 0.9143 - val_final_output_1_112_auc: 0.9556 - val_final_output_2_112_binary_accuracy: 0.9479 - val_final_output_2_112_auc: 0.8606 - val_final_output_3_112_binary_accuracy: 0.9558 - val_final_output_3_112_auc: 0.9643 - val_final_output_4_112_binary_accuracy: 0.9816 - val_final_output_4_112_auc: 0.9344 - val_final_output_5_112_binary_accuracy: 0.9886 - val_final_output_5_112_auc: 0.9537 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9414 - lr: 7.5000e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 17/20
# 247/248 [============================>.] - ETA: 0s - loss: 0.3766 - final_output_1_112_loss: 0.0517 - final_output_2_112_loss: 0.0408 - final_output_3_112_loss: 0.0465 - final_output_4_112_loss: 0.0429 - final_output_5_112_loss: 0.0156 - final_output_6_112_loss: 0.0060 - final_output_1_112_binary_accuracy: 0.9803 - final_output_1_112_auc: 0.9980 - final_output_2_112_binary_accuracy: 0.9844 - final_output_2_112_auc: 0.9948 - final_output_3_112_binary_accuracy: 0.9821 - final_output_3_112_auc: 0.9962 - final_output_4_112_binary_accuracy: 0.9862 - final_output_4_112_auc: 0.9714 - final_output_5_112_binary_accuracy: 0.9944 - final_output_5_112_auc: 0.9949 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9697
# Epoch 17: val_loss did not improve from 1.18183
# 248/248 [==============================] - 7s 26ms/step - loss: 0.3767 - final_output_1_112_loss: 0.0517 - final_output_2_112_loss: 0.0408 - final_output_3_112_loss: 0.0465 - final_output_4_112_loss: 0.0429 - final_output_5_112_loss: 0.0156 - final_output_6_112_loss: 0.0060 - final_output_1_112_binary_accuracy: 0.9803 - final_output_1_112_auc: 0.9980 - final_output_2_112_binary_accuracy: 0.9844 - final_output_2_112_auc: 0.9948 - final_output_3_112_binary_accuracy: 0.9821 - final_output_3_112_auc: 0.9962 - final_output_4_112_binary_accuracy: 0.9862 - final_output_4_112_auc: 0.9714 - final_output_5_112_binary_accuracy: 0.9944 - final_output_5_112_auc: 0.9949 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9697 - val_loss: 1.4791 - val_final_output_1_112_loss: 0.3140 - val_final_output_2_112_loss: 0.2007 - val_final_output_3_112_loss: 0.1451 - val_final_output_4_112_loss: 0.0639 - val_final_output_5_112_loss: 0.0397 - val_final_output_6_112_loss: 0.0082 - val_final_output_1_112_binary_accuracy: 0.9147 - val_final_output_1_112_auc: 0.9553 - val_final_output_2_112_binary_accuracy: 0.9484 - val_final_output_2_112_auc: 0.8568 - val_final_output_3_112_binary_accuracy: 0.9556 - val_final_output_3_112_auc: 0.9643 - val_final_output_4_112_binary_accuracy: 0.9815 - val_final_output_4_112_auc: 0.9348 - val_final_output_5_112_binary_accuracy: 0.9886 - val_final_output_5_112_auc: 0.9527 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9408 - lr: 7.5000e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 18/20
# 247/248 [============================>.] - ETA: 0s - loss: 0.3645 - final_output_1_112_loss: 0.0489 - final_output_2_112_loss: 0.0398 - final_output_3_112_loss: 0.0450 - final_output_4_112_loss: 0.0423 - final_output_5_112_loss: 0.0152 - final_output_6_112_loss: 0.0059 - final_output_1_112_binary_accuracy: 0.9815 - final_output_1_112_auc: 0.9982 - final_output_2_112_binary_accuracy: 0.9846 - final_output_2_112_auc: 0.9949 - final_output_3_112_binary_accuracy: 0.9827 - final_output_3_112_auc: 0.9965 - final_output_4_112_binary_accuracy: 0.9864 - final_output_4_112_auc: 0.9723 - final_output_5_112_binary_accuracy: 0.9944 - final_output_5_112_auc: 0.9952 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9710
# Epoch 18: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3644 - final_output_1_112_loss: 0.0489 - final_output_2_112_loss: 0.0398 - final_output_3_112_loss: 0.0450 - final_output_4_112_loss: 0.0423 - final_output_5_112_loss: 0.0152 - final_output_6_112_loss: 0.0059 - final_output_1_112_binary_accuracy: 0.9815 - final_output_1_112_auc: 0.9982 - final_output_2_112_binary_accuracy: 0.9846 - final_output_2_112_auc: 0.9949 - final_output_3_112_binary_accuracy: 0.9827 - final_output_3_112_auc: 0.9965 - final_output_4_112_binary_accuracy: 0.9864 - final_output_4_112_auc: 0.9723 - final_output_5_112_binary_accuracy: 0.9944 - final_output_5_112_auc: 0.9952 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9710 - val_loss: 1.4936 - val_final_output_1_112_loss: 0.3193 - val_final_output_2_112_loss: 0.2019 - val_final_output_3_112_loss: 0.1462 - val_final_output_4_112_loss: 0.0640 - val_final_output_5_112_loss: 0.0399 - val_final_output_6_112_loss: 0.0082 - val_final_output_1_112_binary_accuracy: 0.9144 - val_final_output_1_112_auc: 0.9547 - val_final_output_2_112_binary_accuracy: 0.9474 - val_final_output_2_112_auc: 0.8569 - val_final_output_3_112_binary_accuracy: 0.9560 - val_final_output_3_112_auc: 0.9635 - val_final_output_4_112_binary_accuracy: 0.9817 - val_final_output_4_112_auc: 0.9339 - val_final_output_5_112_binary_accuracy: 0.9886 - val_final_output_5_112_auc: 0.9525 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9421 - lr: 7.5000e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 19/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.3540 - final_output_1_112_loss: 0.0476 - final_output_2_112_loss: 0.0378 - final_output_3_112_loss: 0.0441 - final_output_4_112_loss: 0.0420 - final_output_5_112_loss: 0.0148 - final_output_6_112_loss: 0.0058 - final_output_1_112_binary_accuracy: 0.9820 - final_output_1_112_auc: 0.9983 - final_output_2_112_binary_accuracy: 0.9857 - final_output_2_112_auc: 0.9955 - final_output_3_112_binary_accuracy: 0.9830 - final_output_3_112_auc: 0.9967 - final_output_4_112_binary_accuracy: 0.9864 - final_output_4_112_auc: 0.9728 - final_output_5_112_binary_accuracy: 0.9946 - final_output_5_112_auc: 0.9955 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9720
# Epoch 19: val_loss did not improve from 1.18183
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3544 - final_output_1_112_loss: 0.0477 - final_output_2_112_loss: 0.0379 - final_output_3_112_loss: 0.0441 - final_output_4_112_loss: 0.0420 - final_output_5_112_loss: 0.0149 - final_output_6_112_loss: 0.0058 - final_output_1_112_binary_accuracy: 0.9819 - final_output_1_112_auc: 0.9983 - final_output_2_112_binary_accuracy: 0.9857 - final_output_2_112_auc: 0.9955 - final_output_3_112_binary_accuracy: 0.9829 - final_output_3_112_auc: 0.9967 - final_output_4_112_binary_accuracy: 0.9863 - final_output_4_112_auc: 0.9727 - final_output_5_112_binary_accuracy: 0.9946 - final_output_5_112_auc: 0.9955 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9719 - val_loss: 1.5239 - val_final_output_1_112_loss: 0.3283 - val_final_output_2_112_loss: 0.2057 - val_final_output_3_112_loss: 0.1488 - val_final_output_4_112_loss: 0.0643 - val_final_output_5_112_loss: 0.0403 - val_final_output_6_112_loss: 0.0082 - val_final_output_1_112_binary_accuracy: 0.9147 - val_final_output_1_112_auc: 0.9533 - val_final_output_2_112_binary_accuracy: 0.9471 - val_final_output_2_112_auc: 0.8561 - val_final_output_3_112_binary_accuracy: 0.9561 - val_final_output_3_112_auc: 0.9623 - val_final_output_4_112_binary_accuracy: 0.9816 - val_final_output_4_112_auc: 0.9325 - val_final_output_5_112_binary_accuracy: 0.9886 - val_final_output_5_112_auc: 0.9508 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9413 - lr: 7.5000e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 20/20
# 248/248 [==============================] - ETA: 0s - loss: 0.3434 - final_output_1_112_loss: 0.0451 - final_output_2_112_loss: 0.0370 - final_output_3_112_loss: 0.0426 - final_output_4_112_loss: 0.0416 - final_output_5_112_loss: 0.0146 - final_output_6_112_loss: 0.0057 - final_output_1_112_binary_accuracy: 0.9830 - final_output_1_112_auc: 0.9984 - final_output_2_112_binary_accuracy: 0.9857 - final_output_2_112_auc: 0.9956 - final_output_3_112_binary_accuracy: 0.9837 - final_output_3_112_auc: 0.9969 - final_output_4_112_binary_accuracy: 0.9865 - final_output_4_112_auc: 0.9730 - final_output_5_112_binary_accuracy: 0.9947 - final_output_5_112_auc: 0.9954 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9723
# Epoch 20: val_loss did not improve from 1.18183
# ...
# Epoch 14: val_loss did not improve from 1.17860
# 248/248 [==============================] - 6s 26ms/step - loss: 0.4564 - final_output_1_112_loss: 0.0678 - final_output_2_112_loss: 0.0516 - final_output_3_112_loss: 0.0549 - final_output_4_112_loss: 0.0454 - final_output_5_112_loss: 0.0179 - final_output_6_112_loss: 0.0064 - final_output_1_112_binary_accuracy: 0.9734 - final_output_1_112_auc: 0.9964 - final_output_2_112_binary_accuracy: 0.9801 - final_output_2_112_auc: 0.9905 - final_output_3_112_binary_accuracy: 0.9788 - final_output_3_112_auc: 0.9949 - final_output_4_112_binary_accuracy: 0.9853 - final_output_4_112_auc: 0.9687 - final_output_5_112_binary_accuracy: 0.9935 - final_output_5_112_auc: 0.9933 - final_output_6_112_binary_accuracy: 0.9982 - final_output_6_112_auc: 0.9656 - val_loss: 1.4047 - val_final_output_1_112_loss: 0.2880 - val_final_output_2_112_loss: 0.1922 - val_final_output_3_112_loss: 0.1419 - val_final_output_4_112_loss: 0.0627 - val_final_output_5_112_loss: 0.0381 - val_final_output_6_112_loss: 0.0083 - val_final_output_1_112_binary_accuracy: 0.9145 - val_final_output_1_112_auc: 0.9573 - val_final_output_2_112_binary_accuracy: 0.9442 - val_final_output_2_112_auc: 0.8671 - val_final_output_3_112_binary_accuracy: 0.9549 - val_final_output_3_112_auc: 0.9648 - val_final_output_4_112_binary_accuracy: 0.9813 - val_final_output_4_112_auc: 0.9368 - val_final_output_5_112_binary_accuracy: 0.9887 - val_final_output_5_112_auc: 0.9563 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9434 - lr: 1.5000e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 15/20
# 248/248 [==============================] - ETA: 0s - loss: 0.4129 - final_output_1_112_loss: 0.0586 - final_output_2_112_loss: 0.0459 - final_output_3_112_loss: 0.0501 - final_output_4_112_loss: 0.0442 - final_output_5_112_loss: 0.0167 - final_output_6_112_loss: 0.0062 - final_output_1_112_binary_accuracy: 0.9776 - final_output_1_112_auc: 0.9974 - final_output_2_112_binary_accuracy: 0.9823 - final_output_2_112_auc: 0.9931 - final_output_3_112_binary_accuracy: 0.9807 - final_output_3_112_auc: 0.9957 - final_output_4_112_binary_accuracy: 0.9856 - final_output_4_112_auc: 0.9702 - final_output_5_112_binary_accuracy: 0.9939 - final_output_5_112_auc: 0.9943 - final_output_6_112_binary_accuracy: 0.9982 - final_output_6_112_auc: 0.9679
# Epoch 15: val_loss did not improve from 1.17860
# 248/248 [==============================] - 6s 26ms/step - loss: 0.4129 - final_output_1_112_loss: 0.0586 - final_output_2_112_loss: 0.0459 - final_output_3_112_loss: 0.0501 - final_output_4_112_loss: 0.0442 - final_output_5_112_loss: 0.0167 - final_output_6_112_loss: 0.0062 - final_output_1_112_binary_accuracy: 0.9776 - final_output_1_112_auc: 0.9974 - final_output_2_112_binary_accuracy: 0.9823 - final_output_2_112_auc: 0.9931 - final_output_3_112_binary_accuracy: 0.9807 - final_output_3_112_auc: 0.9957 - final_output_4_112_binary_accuracy: 0.9856 - final_output_4_112_auc: 0.9702 - final_output_5_112_binary_accuracy: 0.9939 - final_output_5_112_auc: 0.9943 - final_output_6_112_binary_accuracy: 0.9982 - final_output_6_112_auc: 0.9679 - val_loss: 1.4220 - val_final_output_1_112_loss: 0.2940 - val_final_output_2_112_loss: 0.1947 - val_final_output_3_112_loss: 0.1434 - val_final_output_4_112_loss: 0.0625 - val_final_output_5_112_loss: 0.0379 - val_final_output_6_112_loss: 0.0082 - val_final_output_1_112_binary_accuracy: 0.9170 - val_final_output_1_112_auc: 0.9573 - val_final_output_2_112_binary_accuracy: 0.9463 - val_final_output_2_112_auc: 0.8655 - val_final_output_3_112_binary_accuracy: 0.9561 - val_final_output_3_112_auc: 0.9645 - val_final_output_4_112_binary_accuracy: 0.9817 - val_final_output_4_112_auc: 0.9361 - val_final_output_5_112_binary_accuracy: 0.9890 - val_final_output_5_112_auc: 0.9539 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9422 - lr: 7.5000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 16/20
# 248/248 [==============================] - ETA: 0s - loss: 0.3950 - final_output_1_112_loss: 0.0555 - final_output_2_112_loss: 0.0432 - final_output_3_112_loss: 0.0483 - final_output_4_112_loss: 0.0436 - final_output_5_112_loss: 0.0162 - final_output_6_112_loss: 0.0061 - final_output_1_112_binary_accuracy: 0.9787 - final_output_1_112_auc: 0.9976 - final_output_2_112_binary_accuracy: 0.9835 - final_output_2_112_auc: 0.9940 - final_output_3_112_binary_accuracy: 0.9815 - final_output_3_112_auc: 0.9959 - final_output_4_112_binary_accuracy: 0.9858 - final_output_4_112_auc: 0.9710 - final_output_5_112_binary_accuracy: 0.9941 - final_output_5_112_auc: 0.9946 - final_output_6_112_binary_accuracy: 0.9982 - final_output_6_112_auc: 0.9687
# Epoch 16: val_loss did not improve from 1.17860
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3950 - final_output_1_112_loss: 0.0555 - final_output_2_112_loss: 0.0432 - final_output_3_112_loss: 0.0483 - final_output_4_112_loss: 0.0436 - final_output_5_112_loss: 0.0162 - final_output_6_112_loss: 0.0061 - final_output_1_112_binary_accuracy: 0.9787 - final_output_1_112_auc: 0.9976 - final_output_2_112_binary_accuracy: 0.9835 - final_output_2_112_auc: 0.9940 - final_output_3_112_binary_accuracy: 0.9815 - final_output_3_112_auc: 0.9959 - final_output_4_112_binary_accuracy: 0.9858 - final_output_4_112_auc: 0.9710 - final_output_5_112_binary_accuracy: 0.9941 - final_output_5_112_auc: 0.9946 - final_output_6_112_binary_accuracy: 0.9982 - final_output_6_112_auc: 0.9687 - val_loss: 1.4430 - val_final_output_1_112_loss: 0.3003 - val_final_output_2_112_loss: 0.1973 - val_final_output_3_112_loss: 0.1449 - val_final_output_4_112_loss: 0.0628 - val_final_output_5_112_loss: 0.0384 - val_final_output_6_112_loss: 0.0082 - val_final_output_1_112_binary_accuracy: 0.9167 - val_final_output_1_112_auc: 0.9567 - val_final_output_2_112_binary_accuracy: 0.9458 - val_final_output_2_112_auc: 0.8621 - val_final_output_3_112_binary_accuracy: 0.9555 - val_final_output_3_112_auc: 0.9645 - val_final_output_4_112_binary_accuracy: 0.9816 - val_final_output_4_112_auc: 0.9365 - val_final_output_5_112_binary_accuracy: 0.9890 - val_final_output_5_112_auc: 0.9525 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9436 - lr: 7.5000e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 17/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.3765 - final_output_1_112_loss: 0.0516 - final_output_2_112_loss: 0.0415 - final_output_3_112_loss: 0.0459 - final_output_4_112_loss: 0.0431 - final_output_5_112_loss: 0.0156 - final_output_6_112_loss: 0.0060 - final_output_1_112_binary_accuracy: 0.9805 - final_output_1_112_auc: 0.9980 - final_output_2_112_binary_accuracy: 0.9842 - final_output_2_112_auc: 0.9947 - final_output_3_112_binary_accuracy: 0.9825 - final_output_3_112_auc: 0.9964 - final_output_4_112_binary_accuracy: 0.9859 - final_output_4_112_auc: 0.9717 - final_output_5_112_binary_accuracy: 0.9943 - final_output_5_112_auc: 0.9951 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9700
# Epoch 17: val_loss did not improve from 1.17860
# 248/248 [==============================] - 6s 25ms/step - loss: 0.3764 - final_output_1_112_loss: 0.0516 - final_output_2_112_loss: 0.0415 - final_output_3_112_loss: 0.0459 - final_output_4_112_loss: 0.0430 - final_output_5_112_loss: 0.0156 - final_output_6_112_loss: 0.0060 - final_output_1_112_binary_accuracy: 0.9806 - final_output_1_112_auc: 0.9980 - final_output_2_112_binary_accuracy: 0.9842 - final_output_2_112_auc: 0.9947 - final_output_3_112_binary_accuracy: 0.9825 - final_output_3_112_auc: 0.9964 - final_output_4_112_binary_accuracy: 0.9859 - final_output_4_112_auc: 0.9717 - final_output_5_112_binary_accuracy: 0.9943 - final_output_5_112_auc: 0.9951 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9700 - val_loss: 1.4622 - val_final_output_1_112_loss: 0.3057 - val_final_output_2_112_loss: 0.1999 - val_final_output_3_112_loss: 0.1467 - val_final_output_4_112_loss: 0.0629 - val_final_output_5_112_loss: 0.0387 - val_final_output_6_112_loss: 0.0081 - val_final_output_1_112_binary_accuracy: 0.9162 - val_final_output_1_112_auc: 0.9562 - val_final_output_2_112_binary_accuracy: 0.9455 - val_final_output_2_112_auc: 0.8614 - val_final_output_3_112_binary_accuracy: 0.9554 - val_final_output_3_112_auc: 0.9635 - val_final_output_4_112_binary_accuracy: 0.9815 - val_final_output_4_112_auc: 0.9363 - val_final_output_5_112_binary_accuracy: 0.9890 - val_final_output_5_112_auc: 0.9523 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9423 - lr: 7.5000e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 18/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.3650 - final_output_1_112_loss: 0.0493 - final_output_2_112_loss: 0.0395 - final_output_3_112_loss: 0.0451 - final_output_4_112_loss: 0.0423 - final_output_5_112_loss: 0.0153 - final_output_6_112_loss: 0.0059 - final_output_1_112_binary_accuracy: 0.9813 - final_output_1_112_auc: 0.9981 - final_output_2_112_binary_accuracy: 0.9849 - final_output_2_112_auc: 0.9951 - final_output_3_112_binary_accuracy: 0.9826 - final_output_3_112_auc: 0.9965 - final_output_4_112_binary_accuracy: 0.9863 - final_output_4_112_auc: 0.9732 - final_output_5_112_binary_accuracy: 0.9944 - final_output_5_112_auc: 0.9952 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9709
# Epoch 18: val_loss did not improve from 1.17860
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3654 - final_output_1_112_loss: 0.0494 - final_output_2_112_loss: 0.0396 - final_output_3_112_loss: 0.0451 - final_output_4_112_loss: 0.0423 - final_output_5_112_loss: 0.0153 - final_output_6_112_loss: 0.0059 - final_output_1_112_binary_accuracy: 0.9813 - final_output_1_112_auc: 0.9981 - final_output_2_112_binary_accuracy: 0.9849 - final_output_2_112_auc: 0.9951 - final_output_3_112_binary_accuracy: 0.9826 - final_output_3_112_auc: 0.9965 - final_output_4_112_binary_accuracy: 0.9863 - final_output_4_112_auc: 0.9731 - final_output_5_112_binary_accuracy: 0.9944 - final_output_5_112_auc: 0.9952 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9709 - val_loss: 1.4995 - val_final_output_1_112_loss: 0.3163 - val_final_output_2_112_loss: 0.2052 - val_final_output_3_112_loss: 0.1492 - val_final_output_4_112_loss: 0.0632 - val_final_output_5_112_loss: 0.0393 - val_final_output_6_112_loss: 0.0081 - val_final_output_1_112_binary_accuracy: 0.9168 - val_final_output_1_112_auc: 0.9555 - val_final_output_2_112_binary_accuracy: 0.9463 - val_final_output_2_112_auc: 0.8566 - val_final_output_3_112_binary_accuracy: 0.9557 - val_final_output_3_112_auc: 0.9632 - val_final_output_4_112_binary_accuracy: 0.9817 - val_final_output_4_112_auc: 0.9355 - val_final_output_5_112_binary_accuracy: 0.9890 - val_final_output_5_112_auc: 0.9499 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9405 - lr: 7.5000e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 19/20
# 246/248 [============================>.] - ETA: 0s - loss: 0.3558 - final_output_1_112_loss: 0.0483 - final_output_2_112_loss: 0.0377 - final_output_3_112_loss: 0.0441 - final_output_4_112_loss: 0.0420 - final_output_5_112_loss: 0.0150 - final_output_6_112_loss: 0.0058 - final_output_1_112_binary_accuracy: 0.9816 - final_output_1_112_auc: 0.9982 - final_output_2_112_binary_accuracy: 0.9856 - final_output_2_112_auc: 0.9956 - final_output_3_112_binary_accuracy: 0.9829 - final_output_3_112_auc: 0.9967 - final_output_4_112_binary_accuracy: 0.9864 - final_output_4_112_auc: 0.9731 - final_output_5_112_binary_accuracy: 0.9945 - final_output_5_112_auc: 0.9955 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9717
# Epoch 19: val_loss did not improve from 1.17860
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3555 - final_output_1_112_loss: 0.0482 - final_output_2_112_loss: 0.0377 - final_output_3_112_loss: 0.0441 - final_output_4_112_loss: 0.0420 - final_output_5_112_loss: 0.0150 - final_output_6_112_loss: 0.0058 - final_output_1_112_binary_accuracy: 0.9816 - final_output_1_112_auc: 0.9982 - final_output_2_112_binary_accuracy: 0.9856 - final_output_2_112_auc: 0.9956 - final_output_3_112_binary_accuracy: 0.9830 - final_output_3_112_auc: 0.9967 - final_output_4_112_binary_accuracy: 0.9864 - final_output_4_112_auc: 0.9731 - final_output_5_112_binary_accuracy: 0.9945 - final_output_5_112_auc: 0.9955 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9717 - val_loss: 1.5080 - val_final_output_1_112_loss: 0.3183 - val_final_output_2_112_loss: 0.2068 - val_final_output_3_112_loss: 0.1499 - val_final_output_4_112_loss: 0.0631 - val_final_output_5_112_loss: 0.0395 - val_final_output_6_112_loss: 0.0081 - val_final_output_1_112_binary_accuracy: 0.9165 - val_final_output_1_112_auc: 0.9557 - val_final_output_2_112_binary_accuracy: 0.9451 - val_final_output_2_112_auc: 0.8585 - val_final_output_3_112_binary_accuracy: 0.9552 - val_final_output_3_112_auc: 0.9630 - val_final_output_4_112_binary_accuracy: 0.9818 - val_final_output_4_112_auc: 0.9363 - val_final_output_5_112_binary_accuracy: 0.9889 - val_final_output_5_112_auc: 0.9513 - val_final_output_6_112_binary_accuracy: 0.9979 - val_final_output_6_112_auc: 0.9425 - lr: 7.5000e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 20/20
# 247/248 [============================>.] - ETA: 0s - loss: 0.3468 - final_output_1_112_loss: 0.0461 - final_output_2_112_loss: 0.0375 - final_output_3_112_loss: 0.0427 - final_output_4_112_loss: 0.0416 - final_output_5_112_loss: 0.0147 - final_output_6_112_loss: 0.0057 - final_output_1_112_binary_accuracy: 0.9823 - final_output_1_112_auc: 0.9983 - final_output_2_112_binary_accuracy: 0.9856 - final_output_2_112_auc: 0.9955 - final_output_3_112_binary_accuracy: 0.9836 - final_output_3_112_auc: 0.9969 - final_output_4_112_binary_accuracy: 0.9865 - final_output_4_112_auc: 0.9733 - final_output_5_112_binary_accuracy: 0.9946 - final_output_5_112_auc: 0.9954 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9726
# Epoch 20: val_loss did not improve from 1.17860
# 248/248 [==============================] - 6s 26ms/step - loss: 0.3468 - final_output_1_112_loss: 0.0461 - final_output_2_112_loss: 0.0375 - final_output_3_112_loss: 0.0427 - final_output_4_112_loss: 0.0416 - final_output_5_112_loss: 0.0147 - final_output_6_112_loss: 0.0057 - final_output_1_112_binary_accuracy: 0.9823 - final_output_1_112_auc: 0.9983 - final_output_2_112_binary_accuracy: 0.9856 - final_output_2_112_auc: 0.9955 - final_output_3_112_binary_accuracy: 0.9836 - final_output_3_112_auc: 0.9969 - final_output_4_112_binary_accuracy: 0.9865 - final_output_4_112_auc: 0.9733 - final_output_5_112_binary_accuracy: 0.9946 - final_output_5_112_auc: 0.9954 - final_output_6_112_binary_accuracy: 0.9983 - final_output_6_112_auc: 0.9726 - val_loss: 1.5389 - val_final_output_1_112_loss: 0.3256 - val_final_output_2_112_loss: 0.2131 - val_final_output_3_112_loss: 0.1520 - val_final_output_4_112_loss: 0.0632 - val_final_output_5_112_loss: 0.0397 - val_final_output_6_112_loss: 0.0080 - val_final_output_1_112_binary_accuracy: 0.9167 - val_final_output_1_112_auc: 0.9550 - val_final_output_2_112_binary_accuracy: 0.9466 - val_final_output_2_112_auc: 0.8515 - val_final_output_3_112_binary_accuracy: 0.9558 - val_final_output_3_112_auc: 0.9626 - val_final_output_4_112_binary_accuracy: 0.9817 - val_final_output_4_112_auc: 0.9350 - val_final_output_5_112_binary_accuracy: 0.9890 - val_final_output_5_112_auc: 0.9488 - val_final_output_6_112_binary_accuracy: 0.9980 - val_final_output_6_112_auc: 0.9405 - lr: 7.5000e-05

# %%
# For submission for CAFA test set
test_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/t5_labels_sorted.npy')
rand_state_nos = [1,2,3,4,5]

predictions = []

for rand_state_no in rand_state_nos:

    for fold_ct in [1,2,3,4,5]:

        model_path = f'/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_fc{str(fold_ct)}_r{rand_state_no}_1.30.1.hdf5'
        #model.load_weights(model_path) #only for 1.24.2
        model = load_model(model_path)

        # Add OOF predictions for this split
        predicted_outputs = model.predict([t5_test, esm1_test, esm2_test, pb_test, ankh_test, taxa_test, txt1_test])
        #output_1, output_2, output_3, output_4, output_5, output_6 = model.predict([x_val_1, x_val_2, x_val_3, x_val_4, x_val_5, x_val_6]) #only for 1.24.3
        #predicted_outputs = np.concatenate([output_1, output_2, output_3, output_4, output_5, output_6], axis=1) #only for 1.24.3

        predictions.append(predicted_outputs)

        K.clear_session()
        gc.collect()

average_predictions = np.mean(predictions, axis=0)
print('average predictions shape:', average_predictions.shape)

prediction_preparation = PredictionPreparation(average_predictions, Y_labels, test_labels)
prediction_preparation.prepare_submission(filename=f"/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_test_submission_1.30.1.tsv", top_percent=0.05)
# Out:
# 4434/4434 [==============================] - 18s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 13s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 15s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 15s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# average predictions shape: (141864, 800)
# zeros dropped for 0 rows
#           Protein Id  GO Term Id  Prediction
# 100647203     Q9FPJ8  GO:0005488         1.0
# 108245603     Q9SX79  GO:0005488         1.0
# 90861603      Q8VXZ9  GO:0005488         1.0
# 106876803     Q9S7N9  GO:0005488         1.0
# 107233603     Q9SG10  GO:0005488         1.0
# count    5.674560e+06
# mean     1.280636e-01
# std      2.524600e-01
# min      6.000000e-03
# 25%      1.000000e-02
# 50%      1.900000e-02
# 75%      7.400000e-02
# max      1.000000e+00
# Name: Prediction, dtype: float64

# %%
# For submission for CAFA test set 130b
test_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/t5_labels_sorted.npy')
model_nos = [2,3]
rand_state_no = 1

predictions = []

for model_no in model_nos:

    for fold_ct in [1,2,3,4,5]:

        model_path = f'/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_fc{str(fold_ct)}_r{rand_state_no}_1.30.{model_no}.hdf5'
        #model.load_weights(model_path) #only for 1.24.2
        model = load_model(model_path)

        # Add OOF predictions for this split
        #predicted_outputs = model.predict([t5_test, esm1_test, esm2_test, pb_test, ankh_test, taxa_test, txt1_test])
        output_1, output_2, output_3, output_4, output_5, output_6 = model.predict([t5_test, esm1_test, esm2_test, pb_test, ankh_test, taxa_test, txt1_test]) #only for 1.24.3
        predicted_outputs = np.concatenate([output_1, output_2, output_3, output_4, output_5, output_6], axis=1) #only for 1.24.3

        predictions.append(predicted_outputs)

        K.clear_session()
        gc.collect()

average_predictions = np.mean(predictions, axis=0)
print('average predictions shape:', average_predictions.shape)

prediction_preparation = PredictionPreparation(average_predictions, Y_labels, test_labels)
prediction_preparation.prepare_submission(filename=f"/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_test_submission_1.30b.tsv", top_percent=0.05)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-5-7c2c877fd77f> in <cell line: 8>()
#      16         # Add OOF predictions for this split
#      17         #predicted_outputs = model.predict([t5_test, esm1_test, esm2_test, pb_test, ankh_test, taxa_test, txt1_test])
# ---> 18         output_1, output_2, output_3, output_4, output_5, output_6 = model.predict([t5_test, esm1_test, esm2_test, pb_test, ankh_test, taxa_test, txt1_test]) #only for 1.24.3
#      19         predicted_outputs = np.concatenate([output_1, output_2, output_3, output_4, output_5, output_6], axis=1) #only for 1.24.3
#      20
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     101       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102   ctx.ensure_initialized()
# --> 103   return ops.EagerTensor(value, ctx.device_name, dtype)
#     104
#     105
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
# Make groundtruth file for evaluating against
np.random.seed(42)  # for reproducibility

train_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Ankh_train_labels_sorted.npy')

# Set the number of proteins to use as testing for ground truth
test_size = 1002

# Create groundtruth data for testing
random_indices = np.random.choice(t5_train.shape[0], size=test_size, replace=False)
random_labels = train_labels[random_indices]
ramdom_Y = Y[random_indices]

print(f'Check random indices match: {random_indices[:5]}')

prediction_preparation = PredictionPreparation(ramdom_Y, Y_labels, random_labels)
prediction_preparation.prepare_submission(filename=f"/content/drive/MyDrive/CAFA5 2023/1.30/Groundtruth_{test_size}_{ontology}_submission.tsv", top_percent=1, dropweights=True)
# Out:
# Check random indices match: [35520 76725 73256 45903 50891]
# zeros dropped for 795517 rows
#         Protein Id  GO Term Id
# 400800      B2RYH7  GO:0003824
# 612800      P0C1T1  GO:0003824
# 640603  A0A5F9ZH03  GO:1902936
# 12801       C9JMY5  GO:0097159
# 12802       C9JMY5  GO:1901363
# matrix shape: (6083, 2)

# %%
# Internal testing for 1.30.2/3/4
train_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Ankh_train_labels_sorted.npy')
test_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/t5_labels_sorted.npy')

# change for each set of models to be evaluated
eval_no = 3

np.random.seed(42)  # for reproducibility
test_size = 1002

model_nos = [2]
rand_state_no = 1

# Initialize array to accumulate OOF predictions across evaluated models
total_oof_predictions = np.zeros_like(Y, dtype=np.float32)

for model_no in model_nos:

    # Define 5-fold cross validation
    n_splits = 5
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=rand_state_no)

    fold_ct = 1
    out_of_fold_predictions = np.zeros_like(Y, dtype=np.float32) # Initialize array with same shape as Y, MUST BE FLOAT32 OR IT FAILS

    # Iterate over each fold and produce prediction on validation data only
    for train_index, val_index in kf.split(t5_train):

        x_tr_1, x_val_1 = t5_train[train_index], t5_train[val_index]
        x_tr_2, x_val_2 = esm1_train[train_index], esm1_train[val_index]
        x_tr_3, x_val_3 = esm2_train[train_index], esm2_train[val_index]
        x_tr_4, x_val_4 = pb_train[train_index], pb_train[val_index]
        x_tr_5, x_val_5 = ankh_train[train_index], ankh_train[val_index]
        x_tr_6, x_val_6 = taxa_train[train_index], taxa_train[val_index]
        x_tr_7, x_val_7 = txt1_train[train_index], txt1_train[val_index]


        model_path = f'/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_fc{str(fold_ct)}_r{rand_state_no}_1.30.{model_no}.hdf5'
        #model.load_weights(model_path) #only for 1.24.2
        model = load_model(model_path)

        # Add OOF predictions for this split
        #predicted_outputs = model.predict([x_val_1, x_val_2, x_val_3, x_val_4, x_val_5, x_val_6, x_val_7])
        output_1, output_2, output_3, output_4, output_5, output_6 = model.predict([x_val_1, x_val_2, x_val_3, x_val_4, x_val_5, x_val_6, x_val_7]) #only for 1.24.3
        predicted_outputs = np.concatenate([output_1, output_2, output_3, output_4, output_5, output_6], axis=1) #only for 1.24.3

        out_of_fold_predictions[val_index, :] = predicted_outputs

        K.clear_session()
        gc.collect()

        fold_ct+=1

    total_oof_predictions += out_of_fold_predictions
averaged_oof_predictions = total_oof_predictions / len(model_nos)


random_indices = np.random.choice(t5_train.shape[0], size=test_size, replace=False)

predicted_output = out_of_fold_predictions[random_indices]
random_labels = train_labels[random_indices]
ramdom_Y = Y[random_indices]

print(f'Check random indices match: {random_indices[:5]}')
print(f'Output predictions shape:{predicted_output.shape}')

prediction_preparation = PredictionPreparation(predicted_output, Y_labels, random_labels)
prediction_preparation.prepare_submission(filename=f"/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_testing_1.30b.{eval_no}.tsv", top_percent=0.05)

# Code helth
K.clear_session()
gc.collect()


#1.30b.5 = 2,3,4 models ensemble
#1.30b.6 = 2,3 ensemble
#1.30b.7 = just 2
# Out:
# 495/495 [==============================] - 2s 3ms/step
# 495/495 [==============================] - 2s 3ms/step
# 495/495 [==============================] - 2s 3ms/step
# 495/495 [==============================] - 2s 3ms/step
# 495/495 [==============================] - 2s 3ms/step
# Check random indices match: [35520 76725 73256 45903 50891]
# Output predictions shape:(1002, 800)
# zeros dropped for 0 rows
#        Protein Id  GO Term Id  Prediction
# 402403     O66874  GO:0005488         1.0
# 700803     P36152  GO:0005488         1.0
# 571203     P76010  GO:0005488         1.0
# 608803     P07334  GO:0005488         1.0
# 772800     G3V2W0  GO:0003824         1.0
# count    40080.000000
# mean         0.152165
# std          0.256974
# min          0.016000
# 25%          0.023000
# 50%          0.040000
# 75%          0.112000
# max          1.000000
# Name: Prediction, dtype: float64
# 110
