# %%
import numpy as np
import pandas as pd
import gc
import time
import csv
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU, Concatenate, Input, ReLU, MultiHeadAttention, Layer
import keras

from tensorflow.keras.losses import Loss
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from keras import backend as K

import matplotlib.pyplot as plt
import keras.backend as K

from sklearn.model_selection import KFold
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
import joblib
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import re
from scipy.stats import rankdata, norm
from scipy.sparse import load_npz
import gc
import csv
import pickle
import glob
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import roc_auc_score
import numpy as np
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#utility code

# Prepares a tsv file for submission from model output
class PredictionPreparation:
    def __init__(self, test_pred, Y_labels, protein_labels):
        self.test_pred = test_pred
        self.Y_labels = Y_labels
        self.protein_labels = protein_labels

    def prepare_submission(self, filename="submission.tsv", top_percent=1, dropweights=False, dropzeros=True):
        # prepare dataframe for submission
        df_finalSubmission_MF = pd.DataFrame(columns = ['Protein Id', 'GO Term Id','Prediction'])
        l = []
        for k in list(self.protein_labels):
            l += [k] * self.test_pred.shape[1]
        df_finalSubmission_MF['Protein Id'] = l
        df_finalSubmission_MF['GO Term Id'] = list(self.Y_labels) * self.test_pred.shape[0]
        df_finalSubmission_MF['Prediction'] = self.test_pred.ravel()

        # Calculate the number of rows that represent the top n%
        top_rows = int(top_percent * df_finalSubmission_MF.shape[0])

        # Select the top 5% rows based on 'Prediction'
        df_finalSubmission_MF = df_finalSubmission_MF.nlargest(top_rows, 'Prediction')

        if dropzeros:
            # Drop rows where 'Prediction' is equal or less than zero
            print('zeros dropped for', len(df_finalSubmission_MF[df_finalSubmission_MF['Prediction'] <= 0.0001]), 'rows')
            df_finalSubmission_MF = df_finalSubmission_MF[df_finalSubmission_MF['Prediction'] > 0.0001]


        # round to 3 decimals
        df_finalSubmission_MF['Prediction'] = df_finalSubmission_MF['Prediction'].round(3)

        if dropweights:
            # Drop the right most column (weights)
            df_finalSubmission_MF = df_finalSubmission_MF.iloc[:, :-1]
            print(df_finalSubmission_MF.head())
            print('matrix shape:', df_finalSubmission_MF.shape)

        else:
            # take a quick look at the data
            summary_stats = df_finalSubmission_MF['Prediction'].describe()
            print(df_finalSubmission_MF.head())
            print(summary_stats)

        # Save to file
        df_finalSubmission_MF.to_csv(filename, header=False, index=False, sep="\t")

# prepares training data depending on which ontology is being looked at
class TrainingDataPreparation:
    def __init__(self, ontology):
        self.ontology = ontology

    def load_Y_data(self):
        if self.ontology == 'BPO':
            Y = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_BP_1500.npy', allow_pickle=True)
            Y_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_BP_labels_1500.npy', allow_pickle=True)
            df = pd.read_csv('/content/drive/MyDrive/CAFA5 2023/Train_data/BPO_1500_freq_weights.csv')
            weights_raw = df['IA_weight'].values.tolist()
            weights = {i: weights_raw[i] for i in range(len(weights_raw))}

        elif self.ontology == 'CCO':
            Y = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_CC_800.npy', allow_pickle=True)
            Y_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_CC_labels_800.npy', allow_pickle=True)
            df = pd.read_csv('/content/drive/MyDrive/CAFA5 2023/Train_data/CCO_800_freq_weights.csv')
            weights_raw = df['IA_weight'].values.tolist()
            weights = {i: weights_raw[i] for i in range(len(weights_raw))}

        elif self.ontology == 'MFO':
            Y = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_MF_800.npy', allow_pickle=True)
            Y_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Y_MF_labels_800.npy', allow_pickle=True)
            df = pd.read_csv('/content/drive/MyDrive/CAFA5 2023/Train_data/MFO_800_freq_weights.csv')
            weights_raw = df['IA_weight'].values.tolist()
            weights = {i: weights_raw[i] for i in range(len(weights_raw))}

        else:
            print('Error: ontology not recognized')
            return None, None, None
        print(f'Loaded {self.ontology} ontology')

        return Y, Y_labels, weights, df

    def load_t5_data(self):
        train_data1 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/t5_data_sorted_f32.npy', mmap_mode='r')
        test_data1 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/t5_data_sorted.npy', mmap_mode='r')

        print(f'T5 train data shape: {train_data1.shape}')
        print(f'T5 test data shape: {test_data1.shape}')

        return train_data1, test_data1

    def load_esm2_s_data(self):
        train_data2 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/ems_data_sorted.npy', mmap_mode='r')
        test_data2 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/ems_data_sorted.npy', mmap_mode='r')

        print(f'ESM2 small train data shape: {train_data2.shape}')
        print(f'ESM2 small test data shape: {test_data2.shape}')

        return train_data2, test_data2

    def load_esm2_l_data(self):
        train_data3 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/ESM2_3B_train_embeddings_sorted.npy', mmap_mode='r')
        test_data3 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/ESM2_3B_test_embeddings_sorted.npy', mmap_mode='r')

        print(f'ESM2 3B train data shape: {train_data3.shape}')
        print(f'ESM2 3B data shape: {test_data3.shape}')

        return train_data3, test_data3

    def load_pb_data(self):
        train_data4 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/pb_data_sorted_f32.npy', mmap_mode='r')
        test_data4 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/pb_data_sorted.npy', mmap_mode='r')

        print(f'PB train data shape: {train_data4.shape}')
        print(f'PB data shape: {test_data4.shape}')

        return train_data4, test_data4

    def load_ankh_data(self):
        train_data5 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Ankh_train_embeddings_sorted.npy', mmap_mode='r')
        test_data5 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/Ankh_test_embeddings_sorted.npy', mmap_mode='r')

        print(f'Ankh train data shape: {train_data5.shape}')
        print(f'Ankh data shape: {test_data5.shape}')

        return train_data5, test_data5

    def load_taxa_data(self):
        train_data6 = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/protein_taxa_matrix_train.npy', mmap_mode='r')
        test_data6 = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/protein_taxa_matrix_test.npy', mmap_mode='r')

        print(f'Taxa train data shape: {train_data6.shape}')
        print(f'Taxa data shape: {test_data6.shape}')

        return train_data6, test_data6

    def load_text_embed(self):

        train_data7 = np.load('/content/drive/MyDrive/CAFA5 2023/Absrtract_embeds_modified/abstract_embeds_train_sorted_all.npy', mmap_mode='r')
        test_data7 = np.load('/content/drive/MyDrive/CAFA5 2023/Absrtract_embeds_modified/abstract_embeds_test_sorted_all.npy', mmap_mode='r')

        print(f'Text abstract data shape: {train_data7.shape}')
        print(f'Text abstract shape: {test_data7.shape}')

        return train_data7, test_data7

class PredictionPreparation:
    def __init__(self, test_pred, Y_labels, protein_labels):
        self.test_pred = test_pred
        self.Y_labels = Y_labels
        self.protein_labels = protein_labels

    def prepare_submission(self, filename="submission.tsv", top_percent=1, dropweights=False, dropzeros=True):
        # prepare dataframe for submission
        df_finalSubmission_MF = pd.DataFrame(columns = ['Protein Id', 'GO Term Id','Prediction'])
        l = []
        for k in list(self.protein_labels):
            l += [k] * self.test_pred.shape[1]
        df_finalSubmission_MF['Protein Id'] = l
        df_finalSubmission_MF['GO Term Id'] = list(self.Y_labels) * self.test_pred.shape[0]
        df_finalSubmission_MF['Prediction'] = self.test_pred.ravel()

        # Calculate the number of rows that represent the top n%
        top_rows = int(top_percent * df_finalSubmission_MF.shape[0])

        # Select the top 5% rows based on 'Prediction'
        df_finalSubmission_MF = df_finalSubmission_MF.nlargest(top_rows, 'Prediction')

        if dropzeros:
            # Drop rows where 'Prediction' is equal or less than zero
            print('zeros dropped for', len(df_finalSubmission_MF[df_finalSubmission_MF['Prediction'] <= 0.0001]), 'rows')
            df_finalSubmission_MF = df_finalSubmission_MF[df_finalSubmission_MF['Prediction'] > 0.0001]


        # round to 3 decimals
        df_finalSubmission_MF['Prediction'] = df_finalSubmission_MF['Prediction'].round(3)

        if dropweights:
            # Drop the right most column (weights)
            df_finalSubmission_MF = df_finalSubmission_MF.iloc[:, :-1]
            print(df_finalSubmission_MF.head())
            print('matrix shape:', df_finalSubmission_MF.shape)

        else:
            # take a quick look at the data
            summary_stats = df_finalSubmission_MF['Prediction'].describe()
            print(df_finalSubmission_MF.head())
            print(summary_stats)

        # Save to file
        df_finalSubmission_MF.to_csv(filename, header=False, index=False, sep="\t")

class ProteinPredictions:
    # Initialize an empty dictionary to store the predictions
    def __init__(self):
        self.predictions = {}

    # Add a prediction to the storage, with optional bonus
    # Arguments:
    #   - protein: Identifier for the protein
    #   - go_term: GO term that is being predicted
    #   - score: Confidence score of the prediction
    #   - branch: Branch of the Gene Ontology (e.g., 'CCO', 'MFO', 'BPO')
    #   - bonus: Optional bonus to be added to the score
    def add_prediction(self, protein, go_term, score, branch, bonus=1, adjustment=1):
        # If the protein is not already in the storage, initialize its structure
        if protein not in self.predictions:
            self.predictions[protein] = {'CCO': {}, 'MFO': {}, 'BPO': {}}

        # Convert the score to a float for comparison and calculation
        score = float(score)

        # If this GO term has already been predicted for this protein and branch,
        # add the bonus to the score. Keep the highest score.
        if go_term in self.predictions[protein][branch]:
            self.predictions[protein][branch][go_term] *= 1+(score**3)*bonus
            self.predictions[protein][branch][go_term] += score*adjustment

        # If this GO term has not been predicted yet, store it with the score
        else:
            self.predictions[protein][branch][go_term] = max(score*adjustment, 0)

        # Ensure that the score does not exceed 1
        if self.predictions[protein][branch][go_term] > 1:
            self.predictions[protein][branch][go_term] = 1

    # Get a list of all scores in the predictions
    def get_scores(self):
        scores = []
        for protein, branches in self.predictions.items():
            for branch, go_terms in branches.items():
                scores.extend(go_terms.values())
        return scores

    def plot_predictions(self):
        scores = self.get_scores()
        plt.hist(scores, bins=30, edgecolor='black')
        plt.title('Distribution of Prediction Scores')
        plt.xlabel('Score')
        plt.ylabel('Frequency')
        plt.show()

    # Export the stored predictions to a file
    # Arguments:
    #   - output_file: File name for the exported predictions
    #   - top: Number of top predictions to export for each protein and branch
    def get_predictions(self, output_file='submission.tsv', top=60):
        # Open the output file
        with open(output_file, 'w') as f:
            # Iterate through each protein and its branches
            for protein, branches in self.predictions.items():
                # For each branch, sort the GO terms by score in descending order and select the top ones
                for branch, go_terms in branches.items():
                    # Sort go_terms by score in descending order and take the top ones
                    top_go_terms = sorted(go_terms.items(), key=lambda x: x[1], reverse=True)[:top]
                    # Write each of the top predictions to the file
                    for go_term, score in top_go_terms:
                        f.write(f"{protein}\t{go_term}\t{score:.3f}\n")


def extract_go_terms_and_branches(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
        # Match each stanza with [Term] in the OBO file
        stanzas = re.findall(r'\[Term\][\s\S]*?(?=\n\[|$)', content)

    go_terms_dict = {}
    for stanza in stanzas:
        # Extract the GO term ID
        go_id = re.search(r'^id: (GO:\d+)', stanza, re.MULTILINE)
        if go_id:
            go_id = go_id.group(1)

        # Extract the namespace (branch)
        namespace = re.search(r'^namespace: (\w+)', stanza, re.MULTILINE)
        if namespace:
            namespace = namespace.group(1)

        if go_id and namespace:
            # Map the branch abbreviation to the corresponding BPO, CCO, or MFO
            branch_abbr = {'biological_process': 'BPO', 'cellular_component': 'CCO', 'molecular_function': 'MFO'}
            go_terms_dict[go_id] = branch_abbr[namespace]

    return go_terms_dict

def get_constr_out(x, R):
    """ Given the output of the neural network x returns the output of MCM given the hierarchy constraint expressed in the matrix R """
    c_out = tf.cast(x, tf.float32)
    print('c_out1', c_out.shape)
    c_out = tf.expand_dims(c_out, 1)
    print('c_out2', c_out.shape)
    c_out = tf.tile(c_out, [1, tf.shape(R)[1], 1])
    print('c_out3', c_out.shape)
    # c_out = tf.expand_dims(c_out, -2)  # Expand the last dimension of c_out
    # print('c_out2', c_out.shape)
    # c_out = tf.tile(c_out, [1, tf.shape(R)[1]], 1)  # Make c_out match the shape of R
    # print('c_out3', c_out.shape)
    R = tf.cast(R, tf.float32)
    print('R', R.shape)
    R = tf.expand_dims(R, axis=0)  # make R 3D by adding an extra dimension
    print('R', R.shape)
    R_batch = tf.tile(R, [tf.shape(x)[0], 1, 1])  # replicate R along the batch dimension
    print('R_batch', R_batch.shape)
    print(R_batch[0][50][0:50])
    print(c_out[0][0][:50])
    final_out = tf.reduce_max(R_batch * c_out, axis=2)
    print('final_out', final_out.shape)
    return final_out

class CustomMCM(Loss):
    def __init__(self, R, name="custom_mcm"):
        super().__init__(name=name)
        self.R = tf.cast(R, tf.float32)

    def call(self, y_true, y_pred):
        constr_output = get_constr_out(y_pred, self.R)
        y_true = tf.cast(y_true, tf.float32)
        print('yt, yp, c_out', y_true.shape, y_pred.shape, constr_output.shape)
        train_output = y_true*y_pred
        print('train_output1', train_output.shape)
        train_output = get_constr_out(train_output, self.R)
        print('train_output2', train_output.shape)
        train_output = (1-y_true)*constr_output + y_true*train_output
        print('train_output3', train_output.shape)
        # return binary cross entropy loss
        #return K.mean(K.binary_crossentropy(y_true, train_output), axis=-1) #this does not make things better -1 -> -2
        return tf.keras.losses.binary_crossentropy(y_true, train_output)


file_path = '/content/drive/MyDrive/CAFA5 2023/Train_data/go-basic.obo'
go_terms_dict = extract_go_terms_and_branches(file_path)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer

df1 = pd.read_csv('/content/drive/MyDrive/CAFA5 2023/merged_interpro_train.csv')
df2 = pd.read_csv('/content/drive/MyDrive/CAFA5 2023/merged_interpro_test.csv')


 # Concatenate the DataFrames along the rows axis
df_concatenated = pd.concat([df1, df2], ignore_index=True)

def process_column(column):
    # Split the strings into lists of labels
    labels = column.dropna().apply(lambda x: x.split(','))

    # Create a MultiLabelBinarizer and fit it to the labels in the column
    mlb = MultiLabelBinarizer()
    mlb.fit(labels)

    # Transform the labels into a binary matrix
    binary_labels = mlb.transform(labels)

    # Convert the binary matrix to a numpy array
    binary_labels = np.array(binary_labels)

    # Filter the columns with a sum of less than 10
    column_sum = np.sum(binary_labels, axis=0)
    binary_labels_filtered = binary_labels[:, column_sum >= 20]

    return binary_labels_filtered

# Process each of the three columns separately
binary_labels_1 = process_column(df_concatenated.iloc[:, 1])
binary_labels_2 = process_column(df_concatenated.iloc[:, 2])
binary_labels_3 = process_column(df_concatenated.iloc[:, 3])

# Get the row index of the previous merger
row_index = len(df1)

# Split the numpy arrays based on the row index of the previous merger
binary_labels_1_1 = binary_labels_1[:row_index]
binary_labels_1_2 = binary_labels_1[row_index:]

binary_labels_2_1 = binary_labels_2[:row_index]
binary_labels_2_2 = binary_labels_2[row_index:]

binary_labels_3_1 = binary_labels_3[:row_index]
binary_labels_3_2 = binary_labels_3[row_index:]

# Save the filtered numpy arrays as .npy files
np.save('binary_labels_1_1.npy', binary_labels_1_1)
np.save('binary_labels_1_2.npy', binary_labels_1_2)
np.save('binary_labels_2_1.npy', binary_labels_2_1)
np.save('binary_labels_2_2.npy', binary_labels_2_2)
np.save('binary_labels_3_1.npy', binary_labels_3_1)
np.save('binary_labels_3_2.npy', binary_labels_3_2)

# %%
# Filter the columns with a sum of less than 3
print(binary_labels.shape)
column_sum = np.sum(binary_labels, axis=0)
binary_labels_filtered = binary_labels[:, column_sum >= 10]
print(binary_labels_filtered.shape)
# Out:
# (142246, 26313)
# (142246, 7445)

# %%
np.save('/content/drive/MyDrive/CAFA5 2023/itps_train_binary_labels.npy', binary_labels_filtered)

# %%
# Out:
# (142246, 26313)

# %%
ontology = 'BPO'
data_prep = TrainingDataPreparation(ontology)
Y, Y_labels, weights, df = data_prep.load_Y_data()
t5_train, t5_test = data_prep.load_t5_data()
esm1_train, esm1_test = data_prep.load_esm2_s_data()
esm2_train, esm2_test = data_prep.load_esm2_l_data()
pb_train, pb_test = data_prep.load_pb_data()
ankh_train, ankh_test = data_prep.load_ankh_data()
taxa_train, taxa_test = data_prep.load_taxa_data()
txt1_train, txt1_test = data_prep.load_text_embed()

if ontology == 'CCO':
    R = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/CCO_800_DAG_matrix.npy')
    output_split = [4, 11, 24, 59, 199]

elif ontology == 'MFO':
    R = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/MFO_800_DAG_matrix.npy')
    output_split = [4,14,28,69,176]

elif ontology == 'BPO':
    R = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/BPO_1500_DAG_matrix.npy')
    output_split = [13,45,102,213,465]


print (f'R shape is {R.shape}')
print('datasets loaded')
# Out:
# Loaded BPO ontology
# T5 train data shape: (142246, 1024)
# T5 test data shape: (141864, 1024)
# ESM2 small train data shape: (142246, 1280)
# ESM2 small test data shape: (141864, 1280)
# ESM2 3B train data shape: (142246, 2560)
# ESM2 3B data shape: (141864, 2560)
# PB train data shape: (142246, 1024)
# PB data shape: (141864, 1024)
# Ankh train data shape: (142246, 1536)
# Ankh data shape: (141864, 1536)
# Taxa train data shape: (142246, 70)
# Taxa data shape: (141864, 70)
# Text abstract data shape: (142246, 10279)
# Text abstract shape: (141864, 10279)
# R shape is (1500, 1500)
# datasets loaded

# %%
print(f'Number of proteins with no {ontology} terms = {np.sum(np.all(Y == 0, axis=1))} out of {Y.shape[0]}')

valid_rows = ~np.all(Y == 0, axis=1)   #~ inverts np all
# Filter out rows in Y
Y = Y[valid_rows]

# Filter out rows in other input arrays
t5_train = t5_train[valid_rows]
esm1_train = esm1_train[valid_rows]
esm2_train = esm2_train[valid_rows]
pb_train = pb_train[valid_rows]
ankh_train = ankh_train[valid_rows]
taxa_train = taxa_train[valid_rows]
txt1_train = txt1_train[valid_rows]

print(f'we retained {np.sum(valid_rows)} proteins from training set where {ontology} terms are present')
# Out:
# Number of proteins with no BPO terms = 48629 out of 142246
# we retained 93617 proteins from training set where BPO terms are present

# %%
# Setup vars
n_epochs = 20
n_epochs_ft = 10
dropout_rate = 0.5
l1_dim = 600
l2_dim = 300
final_dim = 800

txt_dim1 = 200
txt_dim2 = 200

#loss without removing any training data (proteins with no BPO...) = 0.0310

#txt dim tests with BPO loss numbers
#no text input = 0.04613
#600/300 = 0.04313
#400/200 = 0.04302
#300/150 = 0.04295
#200/200 = 0.04280
  #final_dim 800 -> 400 = 0.04343
  #final dense layer removed completely -> 0.04286
#200/100 = 0.04302
#140/140 = 0.04306

#modifying the l1_dim 600 -> 300 = 0.04297
#l2_dim 300->450 = 0.04281
#longer training txt dim 100/100 = 0.04309

# %%
K.clear_session()
gc.collect()
# Out:
# 0

# %%
rand_state_no = 1
#output_split = [10,20,30,40,50]
output_split = [5,10,20,40,80]

# Define 5-fold cross validation
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=rand_state_no)

fold_ct = 1
# Iterate over each fold
for train_index, val_index in kf.split(t5_train):

    # Skip other folds for testing
    # if fold_ct>1:
    #   continue

    # Define save name
    save_name = '/content/drive/MyDrive/CAFA5 2023/1.30/'+f"{ontology}_fc{fold_ct}_r{rand_state_no}_1.30.4"

    x_tr_1, x_val_1 = t5_train[train_index], t5_train[val_index]
    x_tr_2, x_val_2 = esm1_train[train_index], esm1_train[val_index]
    x_tr_3, x_val_3 = esm2_train[train_index], esm2_train[val_index]
    x_tr_4, x_val_4 = pb_train[train_index], pb_train[val_index]
    x_tr_5, x_val_5 = ankh_train[train_index], ankh_train[val_index]
    x_tr_6, x_val_6 = taxa_train[train_index], taxa_train[val_index]
    x_tr_7, x_val_7 = txt1_train[train_index], txt1_train[val_index]
    # x_tr_8, x_val_8 = txt2_train[train_index], txt2_train[val_index]
    # x_tr_9, x_val_9 = txt3_train[train_index], txt3_train[val_index]

    y_tr_1, y_val_1 = Y[train_index,:output_split[0]], Y[val_index,:output_split[0]]
    y_tr_2, y_val_2 = Y[train_index,output_split[0]:output_split[1]], Y[val_index,output_split[0]:output_split[1]]
    y_tr_3, y_val_3 = Y[train_index,output_split[1]:output_split[2]], Y[val_index,output_split[1]:output_split[2]]
    y_tr_4, y_val_4 = Y[train_index,output_split[2]:output_split[3]], Y[val_index,output_split[2]:output_split[3]]
    y_tr_5, y_val_5 = Y[train_index,output_split[3]:output_split[4]], Y[val_index,output_split[3]:output_split[4]]
    y_tr_6, y_val_6 = Y[train_index,output_split[4]:], Y[val_index,output_split[4]:]

    # Define the inputs
    t5_in = Input(shape=(t5_train.shape[1],))
    esm1_in = Input(shape=(esm1_train.shape[1],))
    mlpr_in = Input(shape=(esm2_train.shape[1],))
    knn_in = Input(shape=(pb_train.shape[1],))
    lr_in = Input(shape=(ankh_train.shape[1],))
    taxa_in = Input(shape=(taxa_train.shape[1],))
    txt1_in = Input(shape=(txt1_train.shape[1],))
    # txt2_in = Input(shape=(txt2_train.shape[1],))
    # txt3_in = Input(shape=(txt3_train.shape[1],))

    network_1 = Dense(l1_dim, name='t5_dense_1')(t5_in)
    network_1 = BatchNormalization(name='t5_batchnorm_1')(network_1)
    network_1 = LeakyReLU(alpha=0.1, name='t5_leakyrelu_1')(network_1)
    network_1 = Dropout(dropout_rate, name='t5_dropout_1')(network_1)
    network_1 = Dense(l2_dim, name='t5_dense_2')(network_1)

    network_2 = Dense(l1_dim, name='esm1_dense_1')(esm1_in)
    network_2 = BatchNormalization(name='esm1_batchnorm_1')(network_2)
    network_2 = LeakyReLU(alpha=0.1, name='esm1_leakyrelu_1')(network_2)
    network_2 = Dropout(dropout_rate, name='esm1_dropout_1')(network_2)
    network_2 = Dense(l2_dim, name='esm1_dense_2')(network_2)

    network_3 = Dense(l1_dim, name='mlpr_dense_1')(mlpr_in)
    network_3 = BatchNormalization(name='mlpr_batchnorm_1')(network_3)
    network_3 = LeakyReLU(alpha=0.1, name='mlpr_leakyrelu_1')(network_3)
    network_3 = Dropout(dropout_rate, name='mlpr_dropout_1')(network_3)
    network_3 = Dense(l2_dim, name='mlpr_dense_2')(network_3)

    network_4 = Dense(l1_dim, name='knn_dense_1')(knn_in)
    network_4 = BatchNormalization(name='knn_batchnorm_1')(network_4)
    network_4 = LeakyReLU(alpha=0.1, name='knn_leakyrelu_1')(network_4)
    network_4 = Dropout(dropout_rate, name='knn_dropout_1')(network_4)
    network_4 = Dense(l2_dim, name='knn_dense_2')(network_4)

    network_5 = Dense(l1_dim, name='lr_dense_1')(lr_in)
    network_5 = BatchNormalization(name='lr_batchnorm_1')(network_5)
    network_5 = LeakyReLU(alpha=0.1, name='lr_leakyrelu_1')(network_5)
    network_5 = Dropout(dropout_rate, name='lr_dropout_1')(network_5)
    network_5 = Dense(l2_dim, name='lr_dense_2')(network_5)

    network_6 = Dense(128, name='taxa_dense_1')(taxa_in)
    network_6 = BatchNormalization(name='taxa_batchnorm_1')(network_6)
    network_6 = LeakyReLU(alpha=0.1, name='taxa_leakyrelu_1')(network_6)
    network_6 = Dropout(dropout_rate, name='taxa_dropout_1')(network_6)
    network_6 = Dense(64, name='taxa_dense_2')(network_6)

    network_7 = Dense(txt_dim1, name='txt1_dense_1')(txt1_in)
    network_7 = BatchNormalization(name='txt1_batchnorm_1')(network_7)
    network_7 = LeakyReLU(alpha=0.1, name='txt1_leakyrelu_1')(network_7)
    network_7 = Dropout(dropout_rate, name='txt1_dropout_1')(network_7)
    network_7 = Dense(txt_dim2, name='txt1_dense_2')(network_7)

    # Concatenate the networks
    combined = Concatenate()([network_1, network_2, network_3, network_4, network_5, network_6, network_7])
    #combined = LeakyReLU(alpha=0.1, name='combined_leakyrelu_1')(combined)
    combined = BatchNormalization(name = 'combined_batchnorm_1')(combined)
    combined = Dense(final_dim, name='combined_dense_1', activation='relu')(combined)

    # First level output
    output_1 = Dense(output_split[0], activation='sigmoid', name='final_output_1_112')(combined)

    # Second level output, connected to first level
    combined_2 = Concatenate()([combined, output_1])
    output_2 = Dense(output_split[1]-output_split[0], activation='sigmoid', name='final_output_2_112')(combined_2)

    # Third level output, connected to second level
    combined_3 = Concatenate()([combined, output_1, output_2])
    output_3 = Dense(output_split[2]-output_split[1], activation='sigmoid', name='final_output_3_112')(combined_3)

    # Fourth level output, connected to third level
    combined_4 = Concatenate()([combined, output_1, output_2, output_3])
    output_4 = Dense(output_split[3]-output_split[2], activation='sigmoid', name='final_output_4_112')(combined_4)

    # Fifth level output, connected to fourth level
    combined_5 = Concatenate()([combined, output_1, output_2, output_3, output_4])
    output_5 = Dense(output_split[4]-output_split[3], activation='sigmoid', name='final_output_5_112')(combined_5)

    combined_6 = Concatenate()([combined, output_1, output_2, output_3, output_4, output_5])
    output_6 = Dense(Y.shape[1]-output_split[4], activation='sigmoid', name='final_output_6_112')(combined_6)

    # Create the model
    model = Model(inputs=[t5_in, esm1_in, mlpr_in, knn_in, lr_in, taxa_in, txt1_in],
                  outputs=[output_1, output_2, output_3, output_4, output_5, output_6])

    #lr scheduling
    def lr_schedule(epoch, lr):
        if epoch > 0 and epoch % 7 == 0:
            lr = lr * 0.5
        return lr

    # Define callbacks
    checkpoint_loss = ModelCheckpoint(f'{save_name}.hdf5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='min')
    csv_logger = CSVLogger(f'{save_name}.csv')
    lr_callback = LearningRateScheduler(lr_schedule, verbose=1)
    weights_list = df['IA_weight'].values.tolist()

    #Add weights from IA
    weights_1 = weights_list[:output_split[0]]
    weights_2 = weights_list[output_split[0]:output_split[1]]
    weights_3 = weights_list[output_split[1]:output_split[2]]
    weights_4 = weights_list[output_split[2]:output_split[3]]
    weights_5 = weights_list[output_split[3]:output_split[4]]
    weights_6 = weights_list[output_split[4]:]

    # Compile model
    model.compile(optimizer=Adam(learning_rate=0.0003),
    loss={'final_output_1_112': 'binary_crossentropy',
          'final_output_2_112': 'binary_crossentropy',
          'final_output_3_112': 'binary_crossentropy',
          'final_output_4_112': 'binary_crossentropy',
          'final_output_5_112': 'binary_crossentropy',
          'final_output_6_112': 'binary_crossentropy'},
    loss_weights={'final_output_1_112': weights_1,
          'final_output_2_112': weights_2,
          'final_output_3_112': weights_3,
          'final_output_4_112': weights_4,
          'final_output_5_112': weights_5,
          'final_output_6_112': weights_6},
    metrics=['binary_accuracy', tf.keras.metrics.AUC()])

    # Train model
    history = model.fit([x_tr_1, x_tr_2, x_tr_3, x_tr_4, x_tr_5, x_tr_6, x_tr_7], [y_tr_1, y_tr_2, y_tr_3, y_tr_4, y_tr_5, y_tr_6],
              validation_data=([x_val_1, x_val_2, x_val_3, x_val_4, x_val_5, x_val_6, x_val_7], [y_val_1, y_val_2, y_val_3, y_val_4, y_val_5, y_val_6]),
              epochs=n_epochs, batch_size=256,
              callbacks=[lr_callback, checkpoint_loss, csv_logger])

    # Code helth
    K.clear_session()
    gc.collect()

    fold_ct +=1
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 1/20
# 291/293 [============================>.] - ETA: 0s - loss: 2.9233 - final_output_1_112_loss: 0.5138 - final_output_2_112_loss: 0.3913 - final_output_3_112_loss: 0.3120 - final_output_4_112_loss: 0.2861 - final_output_5_112_loss: 0.2400 - final_output_6_112_loss: 0.0789 - final_output_1_112_binary_accuracy: 0.7455 - final_output_1_112_auc: 0.8140 - final_output_2_112_binary_accuracy: 0.8273 - final_output_2_112_auc: 0.8742 - final_output_3_112_binary_accuracy: 0.8779 - final_output_3_112_auc: 0.7954 - final_output_4_112_binary_accuracy: 0.8926 - final_output_4_112_auc: 0.7850 - final_output_5_112_binary_accuracy: 0.9126 - final_output_5_112_auc: 0.8073 - final_output_6_112_binary_accuracy: 0.9788 - final_output_6_112_auc: 0.8082
# Epoch 1: val_loss improved from inf to 3.08047, saving model to /content/drive/MyDrive/CAFA5 2023/1.30/BPO_fc1_r1_1.30.4.hdf5
# 293/293 [==============================] - 31s 46ms/step - loss: 2.9207 - final_output_1_112_loss: 0.5134 - final_output_2_112_loss: 0.3910 - final_output_3_112_loss: 0.3118 - final_output_4_112_loss: 0.2859 - final_output_5_112_loss: 0.2397 - final_output_6_112_loss: 0.0787 - final_output_1_112_binary_accuracy: 0.7457 - final_output_1_112_auc: 0.8143 - final_output_2_112_binary_accuracy: 0.8274 - final_output_2_112_auc: 0.8744 - final_output_3_112_binary_accuracy: 0.8779 - final_output_3_112_auc: 0.7957 - final_output_4_112_binary_accuracy: 0.8927 - final_output_4_112_auc: 0.7854 - final_output_5_112_binary_accuracy: 0.9127 - final_output_5_112_auc: 0.8077 - final_output_6_112_binary_accuracy: 0.9789 - final_output_6_112_auc: 0.8087 - val_loss: 3.0805 - val_final_output_1_112_loss: 0.5824 - val_final_output_2_112_loss: 0.4141 - val_final_output_3_112_loss: 0.3210 - val_final_output_4_112_loss: 0.2861 - val_final_output_5_112_loss: 0.2426 - val_final_output_6_112_loss: 0.0772 - val_final_output_1_112_binary_accuracy: 0.7062 - val_final_output_1_112_auc: 0.7537 - val_final_output_2_112_binary_accuracy: 0.8207 - val_final_output_2_112_auc: 0.8772 - val_final_output_3_112_binary_accuracy: 0.8786 - val_final_output_3_112_auc: 0.7920 - val_final_output_4_112_binary_accuracy: 0.8991 - val_final_output_4_112_auc: 0.7874 - val_final_output_5_112_binary_accuracy: 0.9192 - val_final_output_5_112_auc: 0.8350 - val_final_output_6_112_binary_accuracy: 0.9872 - val_final_output_6_112_auc: 0.8856 - lr: 3.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 2/20
# 291/293 [============================>.] - ETA: 0s - loss: 2.3691 - final_output_1_112_loss: 0.4347 - final_output_2_112_loss: 0.3223 - final_output_3_112_loss: 0.2645 - final_output_4_112_loss: 0.2341 - final_output_5_112_loss: 0.1892 - final_output_6_112_loss: 0.0444 - final_output_1_112_binary_accuracy: 0.7956 - final_output_1_112_auc: 0.8711 - final_output_2_112_binary_accuracy: 0.8619 - final_output_2_112_auc: 0.9158 - final_output_3_112_binary_accuracy: 0.8943 - final_output_3_112_auc: 0.8621 - final_output_4_112_binary_accuracy: 0.9117 - final_output_4_112_auc: 0.8629 - final_output_5_112_binary_accuracy: 0.9308 - final_output_5_112_auc: 0.8866 - final_output_6_112_binary_accuracy: 0.9882 - final_output_6_112_auc: 0.9085
# Epoch 2: val_loss improved from 3.08047 to 2.42014, saving model to /content/drive/MyDrive/CAFA5 2023/1.30/BPO_fc1_r1_1.30.4.hdf5
# 293/293 [==============================] - 8s 28ms/step - loss: 2.3690 - final_output_1_112_loss: 0.4347 - final_output_2_112_loss: 0.3224 - final_output_3_112_loss: 0.2644 - final_output_4_112_loss: 0.2340 - final_output_5_112_loss: 0.1892 - final_output_6_112_loss: 0.0443 - final_output_1_112_binary_accuracy: 0.7956 - final_output_1_112_auc: 0.8710 - final_output_2_112_binary_accuracy: 0.8618 - final_output_2_112_auc: 0.9158 - final_output_3_112_binary_accuracy: 0.8943 - final_output_3_112_auc: 0.8622 - final_output_4_112_binary_accuracy: 0.9117 - final_output_4_112_auc: 0.8628 - final_output_5_112_binary_accuracy: 0.9309 - final_output_5_112_auc: 0.8865 - final_output_6_112_binary_accuracy: 0.9882 - final_output_6_112_auc: 0.9085 - val_loss: 2.4201 - val_final_output_1_112_loss: 0.4534 - val_final_output_2_112_loss: 0.3266 - val_final_output_3_112_loss: 0.2665 - val_final_output_4_112_loss: 0.2344 - val_final_output_5_112_loss: 0.1898 - val_final_output_6_112_loss: 0.0480 - val_final_output_1_112_binary_accuracy: 0.7843 - val_final_output_1_112_auc: 0.8620 - val_final_output_2_112_binary_accuracy: 0.8626 - val_final_output_2_112_auc: 0.9160 - val_final_output_3_112_binary_accuracy: 0.8952 - val_final_output_3_112_auc: 0.8639 - val_final_output_4_112_binary_accuracy: 0.9136 - val_final_output_4_112_auc: 0.8685 - val_final_output_5_112_binary_accuracy: 0.9320 - val_final_output_5_112_auc: 0.8961 - val_final_output_6_112_binary_accuracy: 0.9883 - val_final_output_6_112_auc: 0.9290 - lr: 3.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 3/20
# 293/293 [==============================] - ETA: 0s - loss: 2.1946 - final_output_1_112_loss: 0.4010 - final_output_2_112_loss: 0.2955 - final_output_3_112_loss: 0.2462 - final_output_4_112_loss: 0.2192 - final_output_5_112_loss: 0.1770 - final_output_6_112_loss: 0.0409 - final_output_1_112_binary_accuracy: 0.8142 - final_output_1_112_auc: 0.8915 - final_output_2_112_binary_accuracy: 0.8737 - final_output_2_112_auc: 0.9299 - final_output_3_112_binary_accuracy: 0.9004 - final_output_3_112_auc: 0.8846 - final_output_4_112_binary_accuracy: 0.9162 - final_output_4_112_auc: 0.8834 - final_output_5_112_binary_accuracy: 0.9343 - final_output_5_112_auc: 0.9041 - final_output_6_112_binary_accuracy: 0.9886 - final_output_6_112_auc: 0.9276
# Epoch 3: val_loss improved from 2.42014 to 2.24600, saving model to /content/drive/MyDrive/CAFA5 2023/1.30/BPO_fc1_r1_1.30.4.hdf5
# 293/293 [==============================] - 8s 28ms/step - loss: 2.1946 - final_output_1_112_loss: 0.4010 - final_output_2_112_loss: 0.2955 - final_output_3_112_loss: 0.2462 - final_output_4_112_loss: 0.2192 - final_output_5_112_loss: 0.1770 - final_output_6_112_loss: 0.0409 - final_output_1_112_binary_accuracy: 0.8142 - final_output_1_112_auc: 0.8915 - final_output_2_112_binary_accuracy: 0.8737 - final_output_2_112_auc: 0.9299 - final_output_3_112_binary_accuracy: 0.9004 - final_output_3_112_auc: 0.8846 - final_output_4_112_binary_accuracy: 0.9162 - final_output_4_112_auc: 0.8834 - final_output_5_112_binary_accuracy: 0.9343 - final_output_5_112_auc: 0.9041 - final_output_6_112_binary_accuracy: 0.9886 - final_output_6_112_auc: 0.9276 - val_loss: 2.2460 - val_final_output_1_112_loss: 0.4147 - val_final_output_2_112_loss: 0.3073 - val_final_output_3_112_loss: 0.2536 - val_final_output_4_112_loss: 0.2185 - val_final_output_5_112_loss: 0.1753 - val_final_output_6_112_loss: 0.0416 - val_final_output_1_112_binary_accuracy: 0.8094 - val_final_output_1_112_auc: 0.8839 - val_final_output_2_112_binary_accuracy: 0.8684 - val_final_output_2_112_auc: 0.9235 - val_final_output_3_112_binary_accuracy: 0.8980 - val_final_output_3_112_auc: 0.8776 - val_final_output_4_112_binary_accuracy: 0.9177 - val_final_output_4_112_auc: 0.8850 - val_final_output_5_112_binary_accuracy: 0.9352 - val_final_output_5_112_auc: 0.9093 - val_final_output_6_112_binary_accuracy: 0.9886 - val_final_output_6_112_auc: 0.9391 - lr: 3.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 4/20
# 291/293 [============================>.] - ETA: 0s - loss: 2.0671 - final_output_1_112_loss: 0.3752 - final_output_2_112_loss: 0.2753 - final_output_3_112_loss: 0.2336 - final_output_4_112_loss: 0.2086 - final_output_5_112_loss: 0.1685 - final_output_6_112_loss: 0.0387 - final_output_1_112_binary_accuracy: 0.8289 - final_output_1_112_auc: 0.9060 - final_output_2_112_binary_accuracy: 0.8825 - final_output_2_112_auc: 0.9396 - final_output_3_112_binary_accuracy: 0.9049 - final_output_3_112_auc: 0.8983 - final_output_4_112_binary_accuracy: 0.9195 - final_output_4_112_auc: 0.8966 - final_output_5_112_binary_accuracy: 0.9368 - final_output_5_112_auc: 0.9147 - final_output_6_112_binary_accuracy: 0.9889 - final_output_6_112_auc: 0.9384
# Epoch 4: val_loss improved from 2.24600 to 2.20100, saving model to /content/drive/MyDrive/CAFA5 2023/1.30/BPO_fc1_r1_1.30.4.hdf5
# 293/293 [==============================] - 8s 28ms/step - loss: 2.0684 - final_output_1_112_loss: 0.3753 - final_output_2_112_loss: 0.2754 - final_output_3_112_loss: 0.2339 - final_output_4_112_loss: 0.2088 - final_output_5_112_loss: 0.1686 - final_output_6_112_loss: 0.0387 - final_output_1_112_binary_accuracy: 0.8288 - final_output_1_112_auc: 0.9059 - final_output_2_112_binary_accuracy: 0.8824 - final_output_2_112_auc: 0.9396 - final_output_3_112_binary_accuracy: 0.9048 - final_output_3_112_auc: 0.8980 - final_output_4_112_binary_accuracy: 0.9194 - final_output_4_112_auc: 0.8965 - final_output_5_112_binary_accuracy: 0.9368 - final_output_5_112_auc: 0.9147 - final_output_6_112_binary_accuracy: 0.9888 - final_output_6_112_auc: 0.9384 - val_loss: 2.2010 - val_final_output_1_112_loss: 0.4097 - val_final_output_2_112_loss: 0.2995 - val_final_output_3_112_loss: 0.2484 - val_final_output_4_112_loss: 0.2141 - val_final_output_5_112_loss: 0.1717 - val_final_output_6_112_loss: 0.0400 - val_final_output_1_112_binary_accuracy: 0.8114 - val_final_output_1_112_auc: 0.8880 - val_final_output_2_112_binary_accuracy: 0.8741 - val_final_output_2_112_auc: 0.9274 - val_final_output_3_112_binary_accuracy: 0.9003 - val_final_output_3_112_auc: 0.8815 - val_final_output_4_112_binary_accuracy: 0.9196 - val_final_output_4_112_auc: 0.8893 - val_final_output_5_112_binary_accuracy: 0.9363 - val_final_output_5_112_auc: 0.9134 - val_final_output_6_112_binary_accuracy: 0.9887 - val_final_output_6_112_auc: 0.9449 - lr: 3.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 5/20
# 292/293 [============================>.] - ETA: 0s - loss: 1.9643 - final_output_1_112_loss: 0.3535 - final_output_2_112_loss: 0.2593 - final_output_3_112_loss: 0.2226 - final_output_4_112_loss: 0.2007 - final_output_5_112_loss: 0.1623 - final_output_6_112_loss: 0.0370 - final_output_1_112_binary_accuracy: 0.8410 - final_output_1_112_auc: 0.9171 - final_output_2_112_binary_accuracy: 0.8902 - final_output_2_112_auc: 0.9467 - final_output_3_112_binary_accuracy: 0.9091 - final_output_3_112_auc: 0.9093 - final_output_4_112_binary_accuracy: 0.9221 - final_output_4_112_auc: 0.9060 - final_output_5_112_binary_accuracy: 0.9387 - final_output_5_112_auc: 0.9222 - final_output_6_112_binary_accuracy: 0.9891 - final_output_6_112_auc: 0.9455
# Epoch 5: val_loss improved from 2.20100 to 2.19485, saving model to /content/drive/MyDrive/CAFA5 2023/1.30/BPO_fc1_r1_1.30.4.hdf5
# 293/293 [==============================] - 8s 28ms/step - loss: 1.9643 - final_output_1_112_loss: 0.3535 - final_output_2_112_loss: 0.2594 - final_output_3_112_loss: 0.2226 - final_output_4_112_loss: 0.2006 - final_output_5_112_loss: 0.1623 - final_output_6_112_loss: 0.0370 - final_output_1_112_binary_accuracy: 0.8410 - final_output_1_112_auc: 0.9171 - final_output_2_112_binary_accuracy: 0.8901 - final_output_2_112_auc: 0.9467 - final_output_3_112_binary_accuracy: 0.9091 - final_output_3_112_auc: 0.9093 - final_output_4_112_binary_accuracy: 0.9221 - final_output_4_112_auc: 0.9060 - final_output_5_112_binary_accuracy: 0.9387 - final_output_5_112_auc: 0.9222 - final_output_6_112_binary_accuracy: 0.9891 - final_output_6_112_auc: 0.9455 - val_loss: 2.1949 - val_final_output_1_112_loss: 0.4127 - val_final_output_2_112_loss: 0.2988 - val_final_output_3_112_loss: 0.2468 - val_final_output_4_112_loss: 0.2123 - val_final_output_5_112_loss: 0.1703 - val_final_output_6_112_loss: 0.0391 - val_final_output_1_112_binary_accuracy: 0.8124 - val_final_output_1_112_auc: 0.8888 - val_final_output_2_112_binary_accuracy: 0.8738 - val_final_output_2_112_auc: 0.9287 - val_final_output_3_112_binary_accuracy: 0.9012 - val_final_output_3_112_auc: 0.8840 - val_final_output_4_112_binary_accuracy: 0.9201 - val_final_output_4_112_auc: 0.8918 - val_final_output_5_112_binary_accuracy: 0.9367 - val_final_output_5_112_auc: 0.9148 - val_final_output_6_112_binary_accuracy: 0.9888 - val_final_output_6_112_auc: 0.9479 - lr: 3.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 6/20
# 291/293 [============================>.] - ETA: 0s - loss: 1.8706 - final_output_1_112_loss: 0.3339 - final_output_2_112_loss: 0.2442 - final_output_3_112_loss: 0.2127 - final_output_4_112_loss: 0.1931 - final_output_5_112_loss: 0.1571 - final_output_6_112_loss: 0.0357 - final_output_1_112_binary_accuracy: 0.8514 - final_output_1_112_auc: 0.9264 - final_output_2_112_binary_accuracy: 0.8968 - final_output_2_112_auc: 0.9529 - final_output_3_112_binary_accuracy: 0.9127 - final_output_3_112_auc: 0.9187 - final_output_4_112_binary_accuracy: 0.9246 - final_output_4_112_auc: 0.9143 - final_output_5_112_binary_accuracy: 0.9405 - final_output_5_112_auc: 0.9279 - final_output_6_112_binary_accuracy: 0.9893 - final_output_6_112_auc: 0.9506
# Epoch 6: val_loss improved from 2.19485 to 2.18832, saving model to /content/drive/MyDrive/CAFA5 2023/1.30/BPO_fc1_r1_1.30.4.hdf5
# 293/293 [==============================] - 8s 28ms/step - loss: 1.8711 - final_output_1_112_loss: 0.3341 - final_output_2_112_loss: 0.2443 - final_output_3_112_loss: 0.2127 - final_output_4_112_loss: 0.1932 - final_output_5_112_loss: 0.1571 - final_output_6_112_loss: 0.0357 - final_output_1_112_binary_accuracy: 0.8513 - final_output_1_112_auc: 0.9264 - final_output_2_112_binary_accuracy: 0.8968 - final_output_2_112_auc: 0.9529 - final_output_3_112_binary_accuracy: 0.9127 - final_output_3_112_auc: 0.9187 - final_output_4_112_binary_accuracy: 0.9246 - final_output_4_112_auc: 0.9142 - final_output_5_112_binary_accuracy: 0.9405 - final_output_5_112_auc: 0.9279 - final_output_6_112_binary_accuracy: 0.9893 - final_output_6_112_auc: 0.9506 - val_loss: 2.1883 - val_final_output_1_112_loss: 0.4126 - val_final_output_2_112_loss: 0.3005 - val_final_output_3_112_loss: 0.2454 - val_final_output_4_112_loss: 0.2111 - val_final_output_5_112_loss: 0.1679 - val_final_output_6_112_loss: 0.0384 - val_final_output_1_112_binary_accuracy: 0.8149 - val_final_output_1_112_auc: 0.8911 - val_final_output_2_112_binary_accuracy: 0.8760 - val_final_output_2_112_auc: 0.9287 - val_final_output_3_112_binary_accuracy: 0.9018 - val_final_output_3_112_auc: 0.8870 - val_final_output_4_112_binary_accuracy: 0.9203 - val_final_output_4_112_auc: 0.8940 - val_final_output_5_112_binary_accuracy: 0.9373 - val_final_output_5_112_auc: 0.9184 - val_final_output_6_112_binary_accuracy: 0.9888 - val_final_output_6_112_auc: 0.9502 - lr: 3.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0003000000142492354.
# Epoch 7/20
# 291/293 [============================>.] - ETA: 0s - loss: 1.7931 - final_output_1_112_loss: 0.3172 - final_output_2_112_loss: 0.2319 - final_output_3_112_loss: 0.2045 - final_output_4_112_loss: 0.1873 - final_output_5_112_loss: 0.1526 - final_output_6_112_loss: 0.0346 - final_output_1_112_binary_accuracy: 0.8595 - final_output_1_112_auc: 0.9338 - final_output_2_112_binary_accuracy: 0.9017 - final_output_2_112_auc: 0.9578 - final_output_3_112_binary_accuracy: 0.9160 - final_output_3_112_auc: 0.9259 - final_output_4_112_binary_accuracy: 0.9266 - final_output_4_112_auc: 0.9203 - final_output_5_112_binary_accuracy: 0.9418 - final_output_5_112_auc: 0.9328 - final_output_6_112_binary_accuracy: 0.9895 - final_output_6_112_auc: 0.9543
# Epoch 7: val_loss improved from 2.18832 to 2.17957, saving model to /content/drive/MyDrive/CAFA5 2023/1.30/BPO_fc1_r1_1.30.4.hdf5
# 293/293 [==============================] - 8s 28ms/step - loss: 1.7926 - final_output_1_112_loss: 0.3172 - final_output_2_112_loss: 0.2318 - final_output_3_112_loss: 0.2044 - final_output_4_112_loss: 0.1873 - final_output_5_112_loss: 0.1525 - final_output_6_112_loss: 0.0346 - final_output_1_112_binary_accuracy: 0.8595 - final_output_1_112_auc: 0.9339 - final_output_2_112_binary_accuracy: 0.9017 - final_output_2_112_auc: 0.9578 - final_output_3_112_binary_accuracy: 0.9161 - final_output_3_112_auc: 0.9259 - final_output_4_112_binary_accuracy: 0.9267 - final_output_4_112_auc: 0.9203 - final_output_5_112_binary_accuracy: 0.9418 - final_output_5_112_auc: 0.9328 - final_output_6_112_binary_accuracy: 0.9895 - final_output_6_112_auc: 0.9544 - val_loss: 2.1796 - val_final_output_1_112_loss: 0.4098 - val_final_output_2_112_loss: 0.2995 - val_final_output_3_112_loss: 0.2478 - val_final_output_4_112_loss: 0.2091 - val_final_output_5_112_loss: 0.1665 - val_final_output_6_112_loss: 0.0378 - val_final_output_1_112_binary_accuracy: 0.8177 - val_final_output_1_112_auc: 0.8940 - val_final_output_2_112_binary_accuracy: 0.8760 - val_final_output_2_112_auc: 0.9294 - val_final_output_3_112_binary_accuracy: 0.9007 - val_final_output_3_112_auc: 0.8872 - val_final_output_4_112_binary_accuracy: 0.9208 - val_final_output_4_112_auc: 0.8963 - val_final_output_5_112_binary_accuracy: 0.9379 - val_final_output_5_112_auc: 0.9194 - val_final_output_6_112_binary_accuracy: 0.9889 - val_final_output_6_112_auc: 0.9515 - lr: 3.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 8/20
# 292/293 [============================>.] - ETA: 0s - loss: 1.6510 - final_output_1_112_loss: 0.2849 - final_output_2_112_loss: 0.2087 - final_output_3_112_loss: 0.1891 - final_output_4_112_loss: 0.1774 - final_output_5_112_loss: 0.1454 - final_output_6_112_loss: 0.0331 - final_output_1_112_binary_accuracy: 0.8762 - final_output_1_112_auc: 0.9472 - final_output_2_112_binary_accuracy: 0.9125 - final_output_2_112_auc: 0.9661 - final_output_3_112_binary_accuracy: 0.9223 - final_output_3_112_auc: 0.9383 - final_output_4_112_binary_accuracy: 0.9299 - final_output_4_112_auc: 0.9301 - final_output_5_112_binary_accuracy: 0.9441 - final_output_5_112_auc: 0.9400 - final_output_6_112_binary_accuracy: 0.9897 - final_output_6_112_auc: 0.9591
# Epoch 8: val_loss improved from 2.17957 to 2.16737, saving model to /content/drive/MyDrive/CAFA5 2023/1.30/BPO_fc1_r1_1.30.4.hdf5
# 293/293 [==============================] - 9s 29ms/step - loss: 1.6511 - final_output_1_112_loss: 0.2849 - final_output_2_112_loss: 0.2088 - final_output_3_112_loss: 0.1891 - final_output_4_112_loss: 0.1774 - final_output_5_112_loss: 0.1454 - final_output_6_112_loss: 0.0331 - final_output_1_112_binary_accuracy: 0.8762 - final_output_1_112_auc: 0.9472 - final_output_2_112_binary_accuracy: 0.9125 - final_output_2_112_auc: 0.9661 - final_output_3_112_binary_accuracy: 0.9223 - final_output_3_112_auc: 0.9383 - final_output_4_112_binary_accuracy: 0.9299 - final_output_4_112_auc: 0.9301 - final_output_5_112_binary_accuracy: 0.9441 - final_output_5_112_auc: 0.9400 - final_output_6_112_binary_accuracy: 0.9897 - final_output_6_112_auc: 0.9591 - val_loss: 2.1674 - val_final_output_1_112_loss: 0.4092 - val_final_output_2_112_loss: 0.2981 - val_final_output_3_112_loss: 0.2455 - val_final_output_4_112_loss: 0.2079 - val_final_output_5_112_loss: 0.1648 - val_final_output_6_112_loss: 0.0373 - val_final_output_1_112_binary_accuracy: 0.8250 - val_final_output_1_112_auc: 0.8974 - val_final_output_2_112_binary_accuracy: 0.8787 - val_final_output_2_112_auc: 0.9315 - val_final_output_3_112_binary_accuracy: 0.9027 - val_final_output_3_112_auc: 0.8903 - val_final_output_4_112_binary_accuracy: 0.9217 - val_final_output_4_112_auc: 0.8983 - val_final_output_5_112_binary_accuracy: 0.9385 - val_final_output_5_112_auc: 0.9221 - val_final_output_6_112_binary_accuracy: 0.9890 - val_final_output_6_112_auc: 0.9525 - lr: 1.5000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 9/20
# 292/293 [============================>.] - ETA: 0s - loss: 1.5887 - final_output_1_112_loss: 0.2715 - final_output_2_112_loss: 0.1987 - final_output_3_112_loss: 0.1821 - final_output_4_112_loss: 0.1725 - final_output_5_112_loss: 0.1423 - final_output_6_112_loss: 0.0324 - final_output_1_112_binary_accuracy: 0.8831 - final_output_1_112_auc: 0.9522 - final_output_2_112_binary_accuracy: 0.9173 - final_output_2_112_auc: 0.9693 - final_output_3_112_binary_accuracy: 0.9251 - final_output_3_112_auc: 0.9430 - final_output_4_112_binary_accuracy: 0.9314 - final_output_4_112_auc: 0.9346 - final_output_5_112_binary_accuracy: 0.9451 - final_output_5_112_auc: 0.9429 - final_output_6_112_binary_accuracy: 0.9899 - final_output_6_112_auc: 0.9610
# Epoch 9: val_loss did not improve from 2.16737
# 293/293 [==============================] - 8s 27ms/step - loss: 1.5887 - final_output_1_112_loss: 0.2715 - final_output_2_112_loss: 0.1987 - final_output_3_112_loss: 0.1821 - final_output_4_112_loss: 0.1725 - final_output_5_112_loss: 0.1423 - final_output_6_112_loss: 0.0324 - final_output_1_112_binary_accuracy: 0.8831 - final_output_1_112_auc: 0.9522 - final_output_2_112_binary_accuracy: 0.9173 - final_output_2_112_auc: 0.9693 - final_output_3_112_binary_accuracy: 0.9251 - final_output_3_112_auc: 0.9430 - final_output_4_112_binary_accuracy: 0.9314 - final_output_4_112_auc: 0.9346 - final_output_5_112_binary_accuracy: 0.9451 - final_output_5_112_auc: 0.9429 - final_output_6_112_binary_accuracy: 0.9899 - final_output_6_112_auc: 0.9610 - val_loss: 2.1795 - val_final_output_1_112_loss: 0.4118 - val_final_output_2_112_loss: 0.3012 - val_final_output_3_112_loss: 0.2470 - val_final_output_4_112_loss: 0.2085 - val_final_output_5_112_loss: 0.1648 - val_final_output_6_112_loss: 0.0372 - val_final_output_1_112_binary_accuracy: 0.8238 - val_final_output_1_112_auc: 0.8979 - val_final_output_2_112_binary_accuracy: 0.8792 - val_final_output_2_112_auc: 0.9317 - val_final_output_3_112_binary_accuracy: 0.9023 - val_final_output_3_112_auc: 0.8900 - val_final_output_4_112_binary_accuracy: 0.9211 - val_final_output_4_112_auc: 0.8986 - val_final_output_5_112_binary_accuracy: 0.9386 - val_final_output_5_112_auc: 0.9216 - val_final_output_6_112_binary_accuracy: 0.9890 - val_final_output_6_112_auc: 0.9527 - lr: 1.5000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 10/20
# 291/293 [============================>.] - ETA: 0s - loss: 1.5399 - final_output_1_112_loss: 0.2600 - final_output_2_112_loss: 0.1913 - final_output_3_112_loss: 0.1771 - final_output_4_112_loss: 0.1689 - final_output_5_112_loss: 0.1399 - final_output_6_112_loss: 0.0318 - final_output_1_112_binary_accuracy: 0.8885 - final_output_1_112_auc: 0.9562 - final_output_2_112_binary_accuracy: 0.9205 - final_output_2_112_auc: 0.9716 - final_output_3_112_binary_accuracy: 0.9272 - final_output_3_112_auc: 0.9467 - final_output_4_112_binary_accuracy: 0.9327 - final_output_4_112_auc: 0.9379 - final_output_5_112_binary_accuracy: 0.9460 - final_output_5_112_auc: 0.9452 - final_output_6_112_binary_accuracy: 0.9900 - final_output_6_112_auc: 0.9629
# Epoch 10: val_loss did not improve from 2.16737
# 293/293 [==============================] - 8s 27ms/step - loss: 1.5398 - final_output_1_112_loss: 0.2600 - final_output_2_112_loss: 0.1913 - final_output_3_112_loss: 0.1771 - final_output_4_112_loss: 0.1688 - final_output_5_112_loss: 0.1398 - final_output_6_112_loss: 0.0318 - final_output_1_112_binary_accuracy: 0.8885 - final_output_1_112_auc: 0.9562 - final_output_2_112_binary_accuracy: 0.9205 - final_output_2_112_auc: 0.9716 - final_output_3_112_binary_accuracy: 0.9271 - final_output_3_112_auc: 0.9467 - final_output_4_112_binary_accuracy: 0.9327 - final_output_4_112_auc: 0.9379 - final_output_5_112_binary_accuracy: 0.9460 - final_output_5_112_auc: 0.9453 - final_output_6_112_binary_accuracy: 0.9900 - final_output_6_112_auc: 0.9629 - val_loss: 2.1851 - val_final_output_1_112_loss: 0.4161 - val_final_output_2_112_loss: 0.3030 - val_final_output_3_112_loss: 0.2473 - val_final_output_4_112_loss: 0.2076 - val_final_output_5_112_loss: 0.1633 - val_final_output_6_112_loss: 0.0367 - val_final_output_1_112_binary_accuracy: 0.8244 - val_final_output_1_112_auc: 0.8977 - val_final_output_2_112_binary_accuracy: 0.8800 - val_final_output_2_112_auc: 0.9314 - val_final_output_3_112_binary_accuracy: 0.9039 - val_final_output_3_112_auc: 0.8895 - val_final_output_4_112_binary_accuracy: 0.9223 - val_final_output_4_112_auc: 0.8985 - val_final_output_5_112_binary_accuracy: 0.9394 - val_final_output_5_112_auc: 0.9223 - val_final_output_6_112_binary_accuracy: 0.9891 - val_final_output_6_112_auc: 0.9521 - lr: 1.5000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 11/20
# 292/293 [============================>.] - ETA: 0s - loss: 1.4949 - final_output_1_112_loss: 0.2513 - final_output_2_112_loss: 0.1840 - final_output_3_112_loss: 0.1717 - final_output_4_112_loss: 0.1652 - final_output_5_112_loss: 0.1373 - final_output_6_112_loss: 0.0312 - final_output_1_112_binary_accuracy: 0.8924 - final_output_1_112_auc: 0.9591 - final_output_2_112_binary_accuracy: 0.9233 - final_output_2_112_auc: 0.9738 - final_output_3_112_binary_accuracy: 0.9294 - final_output_3_112_auc: 0.9501 - final_output_4_112_binary_accuracy: 0.9342 - final_output_4_112_auc: 0.9408 - final_output_5_112_binary_accuracy: 0.9470 - final_output_5_112_auc: 0.9474 - final_output_6_112_binary_accuracy: 0.9901 - final_output_6_112_auc: 0.9645
# Epoch 11: val_loss did not improve from 2.16737
# 293/293 [==============================] - 8s 27ms/step - loss: 1.4950 - final_output_1_112_loss: 0.2513 - final_output_2_112_loss: 0.1840 - final_output_3_112_loss: 0.1717 - final_output_4_112_loss: 0.1652 - final_output_5_112_loss: 0.1373 - final_output_6_112_loss: 0.0313 - final_output_1_112_binary_accuracy: 0.8924 - final_output_1_112_auc: 0.9591 - final_output_2_112_binary_accuracy: 0.9233 - final_output_2_112_auc: 0.9738 - final_output_3_112_binary_accuracy: 0.9294 - final_output_3_112_auc: 0.9501 - final_output_4_112_binary_accuracy: 0.9342 - final_output_4_112_auc: 0.9408 - final_output_5_112_binary_accuracy: 0.9470 - final_output_5_112_auc: 0.9474 - final_output_6_112_binary_accuracy: 0.9901 - final_output_6_112_auc: 0.9645 - val_loss: 2.2058 - val_final_output_1_112_loss: 0.4213 - val_final_output_2_112_loss: 0.3074 - val_final_output_3_112_loss: 0.2491 - val_final_output_4_112_loss: 0.2082 - val_final_output_5_112_loss: 0.1644 - val_final_output_6_112_loss: 0.0368 - val_final_output_1_112_binary_accuracy: 0.8241 - val_final_output_1_112_auc: 0.8978 - val_final_output_2_112_binary_accuracy: 0.8800 - val_final_output_2_112_auc: 0.9311 - val_final_output_3_112_binary_accuracy: 0.9030 - val_final_output_3_112_auc: 0.8898 - val_final_output_4_112_binary_accuracy: 0.9224 - val_final_output_4_112_auc: 0.8982 - val_final_output_5_112_binary_accuracy: 0.9390 - val_final_output_5_112_auc: 0.9215 - val_final_output_6_112_binary_accuracy: 0.9890 - val_final_output_6_112_auc: 0.9524 - lr: 1.5000e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 12/20
# 293/293 [==============================] - ETA: 0s - loss: 1.4544 - final_output_1_112_loss: 0.2419 - final_output_2_112_loss: 0.1774 - final_output_3_112_loss: 0.1677 - final_output_4_112_loss: 0.1622 - final_output_5_112_loss: 0.1354 - final_output_6_112_loss: 0.0308 - final_output_1_112_binary_accuracy: 0.8972 - final_output_1_112_auc: 0.9622 - final_output_2_112_binary_accuracy: 0.9265 - final_output_2_112_auc: 0.9757 - final_output_3_112_binary_accuracy: 0.9310 - final_output_3_112_auc: 0.9528 - final_output_4_112_binary_accuracy: 0.9352 - final_output_4_112_auc: 0.9433 - final_output_5_112_binary_accuracy: 0.9475 - final_output_5_112_auc: 0.9492 - final_output_6_112_binary_accuracy: 0.9902 - final_output_6_112_auc: 0.9660
# Epoch 12: val_loss did not improve from 2.16737
# 293/293 [==============================] - 8s 26ms/step - loss: 1.4544 - final_output_1_112_loss: 0.2419 - final_output_2_112_loss: 0.1774 - final_output_3_112_loss: 0.1677 - final_output_4_112_loss: 0.1622 - final_output_5_112_loss: 0.1354 - final_output_6_112_loss: 0.0308 - final_output_1_112_binary_accuracy: 0.8972 - final_output_1_112_auc: 0.9622 - final_output_2_112_binary_accuracy: 0.9265 - final_output_2_112_auc: 0.9757 - final_output_3_112_binary_accuracy: 0.9310 - final_output_3_112_auc: 0.9528 - final_output_4_112_binary_accuracy: 0.9352 - final_output_4_112_auc: 0.9433 - final_output_5_112_binary_accuracy: 0.9475 - final_output_5_112_auc: 0.9492 - final_output_6_112_binary_accuracy: 0.9902 - final_output_6_112_auc: 0.9660 - val_loss: 2.2289 - val_final_output_1_112_loss: 0.4278 - val_final_output_2_112_loss: 0.3122 - val_final_output_3_112_loss: 0.2515 - val_final_output_4_112_loss: 0.2096 - val_final_output_5_112_loss: 0.1642 - val_final_output_6_112_loss: 0.0365 - val_final_output_1_112_binary_accuracy: 0.8255 - val_final_output_1_112_auc: 0.8976 - val_final_output_2_112_binary_accuracy: 0.8788 - val_final_output_2_112_auc: 0.9307 - val_final_output_3_112_binary_accuracy: 0.9036 - val_final_output_3_112_auc: 0.8881 - val_final_output_4_112_binary_accuracy: 0.9221 - val_final_output_4_112_auc: 0.8980 - val_final_output_5_112_binary_accuracy: 0.9392 - val_final_output_5_112_auc: 0.9218 - val_final_output_6_112_binary_accuracy: 0.9891 - val_final_output_6_112_auc: 0.9517 - lr: 1.5000e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 13/20
# 293/293 [==============================] - ETA: 0s - loss: 1.4149 - final_output_1_112_loss: 0.2338 - final_output_2_112_loss: 0.1699 - final_output_3_112_loss: 0.1630 - final_output_4_112_loss: 0.1600 - final_output_5_112_loss: 0.1337 - final_output_6_112_loss: 0.0303 - final_output_1_112_binary_accuracy: 0.9011 - final_output_1_112_auc: 0.9647 - final_output_2_112_binary_accuracy: 0.9296 - final_output_2_112_auc: 0.9777 - final_output_3_112_binary_accuracy: 0.9328 - final_output_3_112_auc: 0.9555 - final_output_4_112_binary_accuracy: 0.9359 - final_output_4_112_auc: 0.9454 - final_output_5_112_binary_accuracy: 0.9480 - final_output_5_112_auc: 0.9508 - final_output_6_112_binary_accuracy: 0.9903 - final_output_6_112_auc: 0.9674
# Epoch 13: val_loss did not improve from 2.16737
# 293/293 [==============================] - 7s 25ms/step - loss: 1.4149 - final_output_1_112_loss: 0.2338 - final_output_2_112_loss: 0.1699 - final_output_3_112_loss: 0.1630 - final_output_4_112_loss: 0.1600 - final_output_5_112_loss: 0.1337 - final_output_6_112_loss: 0.0303 - final_output_1_112_binary_accuracy: 0.9011 - final_output_1_112_auc: 0.9647 - final_output_2_112_binary_accuracy: 0.9296 - final_output_2_112_auc: 0.9777 - final_output_3_112_binary_accuracy: 0.9328 - final_output_3_112_auc: 0.9555 - final_output_4_112_binary_accuracy: 0.9359 - final_output_4_112_auc: 0.9454 - final_output_5_112_binary_accuracy: 0.9480 - final_output_5_112_auc: 0.9508 - final_output_6_112_binary_accuracy: 0.9903 - final_output_6_112_auc: 0.9674 - val_loss: 2.2300 - val_final_output_1_112_loss: 0.4281 - val_final_output_2_112_loss: 0.3127 - val_final_output_3_112_loss: 0.2528 - val_final_output_4_112_loss: 0.2086 - val_final_output_5_112_loss: 0.1638 - val_final_output_6_112_loss: 0.0364 - val_final_output_1_112_binary_accuracy: 0.8259 - val_final_output_1_112_auc: 0.8986 - val_final_output_2_112_binary_accuracy: 0.8804 - val_final_output_2_112_auc: 0.9308 - val_final_output_3_112_binary_accuracy: 0.9031 - val_final_output_3_112_auc: 0.8896 - val_final_output_4_112_binary_accuracy: 0.9224 - val_final_output_4_112_auc: 0.8988 - val_final_output_5_112_binary_accuracy: 0.9391 - val_final_output_5_112_auc: 0.9226 - val_final_output_6_112_binary_accuracy: 0.9891 - val_final_output_6_112_auc: 0.9525 - lr: 1.5000e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0001500000071246177.
# Epoch 14/20
# 292/293 [============================>.] - ETA: 0s - loss: 1.3818 - final_output_1_112_loss: 0.2261 - final_output_2_112_loss: 0.1654 - final_output_3_112_loss: 0.1595 - final_output_4_112_loss: 0.1571 - final_output_5_112_loss: 0.1319 - final_output_6_112_loss: 0.0299 - final_output_1_112_binary_accuracy: 0.9043 - final_output_1_112_auc: 0.9670 - final_output_2_112_binary_accuracy: 0.9313 - final_output_2_112_auc: 0.9789 - final_output_3_112_binary_accuracy: 0.9344 - final_output_3_112_auc: 0.9576 - final_output_4_112_binary_accuracy: 0.9369 - final_output_4_112_auc: 0.9474 - final_output_5_112_binary_accuracy: 0.9487 - final_output_5_112_auc: 0.9523 - final_output_6_112_binary_accuracy: 0.9904 - final_output_6_112_auc: 0.9685
# Epoch 14: val_loss did not improve from 2.16737
# 293/293 [==============================] - 8s 26ms/step - loss: 1.3816 - final_output_1_112_loss: 0.2261 - final_output_2_112_loss: 0.1654 - final_output_3_112_loss: 0.1594 - final_output_4_112_loss: 0.1570 - final_output_5_112_loss: 0.1319 - final_output_6_112_loss: 0.0299 - final_output_1_112_binary_accuracy: 0.9043 - final_output_1_112_auc: 0.9670 - final_output_2_112_binary_accuracy: 0.9313 - final_output_2_112_auc: 0.9789 - final_output_3_112_binary_accuracy: 0.9344 - final_output_3_112_auc: 0.9576 - final_output_4_112_binary_accuracy: 0.9370 - final_output_4_112_auc: 0.9474 - final_output_5_112_binary_accuracy: 0.9487 - final_output_5_112_auc: 0.9523 - final_output_6_112_binary_accuracy: 0.9904 - final_output_6_112_auc: 0.9685 - val_loss: 2.2390 - val_final_output_1_112_loss: 0.4312 - val_final_output_2_112_loss: 0.3165 - val_final_output_3_112_loss: 0.2523 - val_final_output_4_112_loss: 0.2084 - val_final_output_5_112_loss: 0.1636 - val_final_output_6_112_loss: 0.0362 - val_final_output_1_112_binary_accuracy: 0.8271 - val_final_output_1_112_auc: 0.8986 - val_final_output_2_112_binary_accuracy: 0.8814 - val_final_output_2_112_auc: 0.9314 - val_final_output_3_112_binary_accuracy: 0.9040 - val_final_output_3_112_auc: 0.8893 - val_final_output_4_112_binary_accuracy: 0.9228 - val_final_output_4_112_auc: 0.8990 - val_final_output_5_112_binary_accuracy: 0.9394 - val_final_output_5_112_auc: 0.9227 - val_final_output_6_112_binary_accuracy: 0.9891 - val_final_output_6_112_auc: 0.9523 - lr: 1.5000e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 15/20
# 292/293 [============================>.] - ETA: 0s - loss: 1.3084 - final_output_1_112_loss: 0.2091 - final_output_2_112_loss: 0.1538 - final_output_3_112_loss: 0.1516 - final_output_4_112_loss: 0.1520 - final_output_5_112_loss: 0.1282 - final_output_6_112_loss: 0.0291 - final_output_1_112_binary_accuracy: 0.9129 - final_output_1_112_auc: 0.9721 - final_output_2_112_binary_accuracy: 0.9364 - final_output_2_112_auc: 0.9819 - final_output_3_112_binary_accuracy: 0.9374 - final_output_3_112_auc: 0.9624 - final_output_4_112_binary_accuracy: 0.9390 - final_output_4_112_auc: 0.9513 - final_output_5_112_binary_accuracy: 0.9500 - final_output_5_112_auc: 0.9553 - final_output_6_112_binary_accuracy: 0.9905 - final_output_6_112_auc: 0.9705
# Epoch 15: val_loss did not improve from 2.16737
# 293/293 [==============================] - 8s 26ms/step - loss: 1.3085 - final_output_1_112_loss: 0.2091 - final_output_2_112_loss: 0.1537 - final_output_3_112_loss: 0.1516 - final_output_4_112_loss: 0.1520 - final_output_5_112_loss: 0.1282 - final_output_6_112_loss: 0.0291 - final_output_1_112_binary_accuracy: 0.9129 - final_output_1_112_auc: 0.9721 - final_output_2_112_binary_accuracy: 0.9364 - final_output_2_112_auc: 0.9819 - final_output_3_112_binary_accuracy: 0.9374 - final_output_3_112_auc: 0.9624 - final_output_4_112_binary_accuracy: 0.9390 - final_output_4_112_auc: 0.9513 - final_output_5_112_binary_accuracy: 0.9500 - final_output_5_112_auc: 0.9553 - final_output_6_112_binary_accuracy: 0.9905 - final_output_6_112_auc: 0.9705 - val_loss: 2.2548 - val_final_output_1_112_loss: 0.4365 - val_final_output_2_112_loss: 0.3176 - val_final_output_3_112_loss: 0.2542 - val_final_output_4_112_loss: 0.2094 - val_final_output_5_112_loss: 0.1641 - val_final_output_6_112_loss: 0.0363 - val_final_output_1_112_binary_accuracy: 0.8276 - val_final_output_1_112_auc: 0.8999 - val_final_output_2_112_binary_accuracy: 0.8817 - val_final_output_2_112_auc: 0.9318 - val_final_output_3_112_binary_accuracy: 0.9034 - val_final_output_3_112_auc: 0.8909 - val_final_output_4_112_binary_accuracy: 0.9219 - val_final_output_4_112_auc: 0.9000 - val_final_output_5_112_binary_accuracy: 0.9391 - val_final_output_5_112_auc: 0.9232 - val_final_output_6_112_binary_accuracy: 0.9891 - val_final_output_6_112_auc: 0.9527 - lr: 7.5000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 16/20
# 291/293 [============================>.] - ETA: 0s - loss: 1.2746 - final_output_1_112_loss: 0.2007 - final_output_2_112_loss: 0.1488 - final_output_3_112_loss: 0.1478 - final_output_4_112_loss: 0.1496 - final_output_5_112_loss: 0.1266 - final_output_6_112_loss: 0.0288 - final_output_1_112_binary_accuracy: 0.9165 - final_output_1_112_auc: 0.9743 - final_output_2_112_binary_accuracy: 0.9393 - final_output_2_112_auc: 0.9831 - final_output_3_112_binary_accuracy: 0.9393 - final_output_3_112_auc: 0.9643 - final_output_4_112_binary_accuracy: 0.9398 - final_output_4_112_auc: 0.9532 - final_output_5_112_binary_accuracy: 0.9506 - final_output_5_112_auc: 0.9565 - final_output_6_112_binary_accuracy: 0.9906 - final_output_6_112_auc: 0.9713
# Epoch 16: val_loss did not improve from 2.16737
# 293/293 [==============================] - 8s 27ms/step - loss: 1.2751 - final_output_1_112_loss: 0.2008 - final_output_2_112_loss: 0.1488 - final_output_3_112_loss: 0.1479 - final_output_4_112_loss: 0.1496 - final_output_5_112_loss: 0.1267 - final_output_6_112_loss: 0.0288 - final_output_1_112_binary_accuracy: 0.9164 - final_output_1_112_auc: 0.9742 - final_output_2_112_binary_accuracy: 0.9394 - final_output_2_112_auc: 0.9831 - final_output_3_112_binary_accuracy: 0.9393 - final_output_3_112_auc: 0.9643 - final_output_4_112_binary_accuracy: 0.9398 - final_output_4_112_auc: 0.9532 - final_output_5_112_binary_accuracy: 0.9506 - final_output_5_112_auc: 0.9565 - final_output_6_112_binary_accuracy: 0.9906 - final_output_6_112_auc: 0.9713 - val_loss: 2.2689 - val_final_output_1_112_loss: 0.4411 - val_final_output_2_112_loss: 0.3212 - val_final_output_3_112_loss: 0.2557 - val_final_output_4_112_loss: 0.2090 - val_final_output_5_112_loss: 0.1640 - val_final_output_6_112_loss: 0.0361 - val_final_output_1_112_binary_accuracy: 0.8296 - val_final_output_1_112_auc: 0.9001 - val_final_output_2_112_binary_accuracy: 0.8817 - val_final_output_2_112_auc: 0.9314 - val_final_output_3_112_binary_accuracy: 0.9048 - val_final_output_3_112_auc: 0.8888 - val_final_output_4_112_binary_accuracy: 0.9229 - val_final_output_4_112_auc: 0.8995 - val_final_output_5_112_binary_accuracy: 0.9396 - val_final_output_5_112_auc: 0.9227 - val_final_output_6_112_binary_accuracy: 0.9891 - val_final_output_6_112_auc: 0.9519 - lr: 7.5000e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 17/20
# 291/293 [============================>.] - ETA: 0s - loss: 1.2498 - final_output_1_112_loss: 0.1950 - final_output_2_112_loss: 0.1451 - final_output_3_112_loss: 0.1452 - final_output_4_112_loss: 0.1477 - final_output_5_112_loss: 0.1253 - final_output_6_112_loss: 0.0285 - final_output_1_112_binary_accuracy: 0.9188 - final_output_1_112_auc: 0.9757 - final_output_2_112_binary_accuracy: 0.9408 - final_output_2_112_auc: 0.9839 - final_output_3_112_binary_accuracy: 0.9403 - final_output_3_112_auc: 0.9656 - final_output_4_112_binary_accuracy: 0.9408 - final_output_4_112_auc: 0.9544 - final_output_5_112_binary_accuracy: 0.9509 - final_output_5_112_auc: 0.9576 - final_output_6_112_binary_accuracy: 0.9907 - final_output_6_112_auc: 0.9720
# Epoch 17: val_loss did not improve from 2.16737
# 293/293 [==============================] - 8s 27ms/step - loss: 1.2499 - final_output_1_112_loss: 0.1950 - final_output_2_112_loss: 0.1451 - final_output_3_112_loss: 0.1452 - final_output_4_112_loss: 0.1477 - final_output_5_112_loss: 0.1253 - final_output_6_112_loss: 0.0285 - final_output_1_112_binary_accuracy: 0.9188 - final_output_1_112_auc: 0.9757 - final_output_2_112_binary_accuracy: 0.9407 - final_output_2_112_auc: 0.9839 - final_output_3_112_binary_accuracy: 0.9403 - final_output_3_112_auc: 0.9655 - final_output_4_112_binary_accuracy: 0.9408 - final_output_4_112_auc: 0.9545 - final_output_5_112_binary_accuracy: 0.9509 - final_output_5_112_auc: 0.9576 - final_output_6_112_binary_accuracy: 0.9907 - final_output_6_112_auc: 0.9720 - val_loss: 2.2889 - val_final_output_1_112_loss: 0.4468 - val_final_output_2_112_loss: 0.3254 - val_final_output_3_112_loss: 0.2577 - val_final_output_4_112_loss: 0.2096 - val_final_output_5_112_loss: 0.1641 - val_final_output_6_112_loss: 0.0361 - val_final_output_1_112_binary_accuracy: 0.8301 - val_final_output_1_112_auc: 0.8998 - val_final_output_2_112_binary_accuracy: 0.8817 - val_final_output_2_112_auc: 0.9312 - val_final_output_3_112_binary_accuracy: 0.9045 - val_final_output_3_112_auc: 0.8896 - val_final_output_4_112_binary_accuracy: 0.9228 - val_final_output_4_112_auc: 0.8996 - val_final_output_5_112_binary_accuracy: 0.9396 - val_final_output_5_112_auc: 0.9228 - val_final_output_6_112_binary_accuracy: 0.9891 - val_final_output_6_112_auc: 0.9513 - lr: 7.5000e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 18/20
# 293/293 [==============================] - ETA: 0s - loss: 1.2344 - final_output_1_112_loss: 0.1919 - final_output_2_112_loss: 0.1424 - final_output_3_112_loss: 0.1434 - final_output_4_112_loss: 0.1464 - final_output_5_112_loss: 0.1248 - final_output_6_112_loss: 0.0283 - final_output_1_112_binary_accuracy: 0.9201 - final_output_1_112_auc: 0.9765 - final_output_2_112_binary_accuracy: 0.9412 - final_output_2_112_auc: 0.9846 - final_output_3_112_binary_accuracy: 0.9412 - final_output_3_112_auc: 0.9666 - final_output_4_112_binary_accuracy: 0.9411 - final_output_4_112_auc: 0.9553 - final_output_5_112_binary_accuracy: 0.9513 - final_output_5_112_auc: 0.9579 - final_output_6_112_binary_accuracy: 0.9907 - final_output_6_112_auc: 0.9725
# Epoch 18: val_loss did not improve from 2.16737
# 293/293 [==============================] - 8s 26ms/step - loss: 1.2344 - final_output_1_112_loss: 0.1919 - final_output_2_112_loss: 0.1424 - final_output_3_112_loss: 0.1434 - final_output_4_112_loss: 0.1464 - final_output_5_112_loss: 0.1248 - final_output_6_112_loss: 0.0283 - final_output_1_112_binary_accuracy: 0.9201 - final_output_1_112_auc: 0.9765 - final_output_2_112_binary_accuracy: 0.9412 - final_output_2_112_auc: 0.9846 - final_output_3_112_binary_accuracy: 0.9412 - final_output_3_112_auc: 0.9666 - final_output_4_112_binary_accuracy: 0.9411 - final_output_4_112_auc: 0.9553 - final_output_5_112_binary_accuracy: 0.9513 - final_output_5_112_auc: 0.9579 - final_output_6_112_binary_accuracy: 0.9907 - final_output_6_112_auc: 0.9725 - val_loss: 2.2896 - val_final_output_1_112_loss: 0.4488 - val_final_output_2_112_loss: 0.3266 - val_final_output_3_112_loss: 0.2570 - val_final_output_4_112_loss: 0.2090 - val_final_output_5_112_loss: 0.1631 - val_final_output_6_112_loss: 0.0358 - val_final_output_1_112_binary_accuracy: 0.8293 - val_final_output_1_112_auc: 0.8997 - val_final_output_2_112_binary_accuracy: 0.8824 - val_final_output_2_112_auc: 0.9308 - val_final_output_3_112_binary_accuracy: 0.9051 - val_final_output_3_112_auc: 0.8891 - val_final_output_4_112_binary_accuracy: 0.9235 - val_final_output_4_112_auc: 0.8995 - val_final_output_5_112_binary_accuracy: 0.9404 - val_final_output_5_112_auc: 0.9222 - val_final_output_6_112_binary_accuracy: 0.9892 - val_final_output_6_112_auc: 0.9507 - lr: 7.5000e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 19/20
# 293/293 [==============================] - ETA: 0s - loss: 1.2105 - final_output_1_112_loss: 0.1868 - final_output_2_112_loss: 0.1381 - final_output_3_112_loss: 0.1411 - final_output_4_112_loss: 0.1447 - final_output_5_112_loss: 0.1235 - final_output_6_112_loss: 0.0281 - final_output_1_112_binary_accuracy: 0.9230 - final_output_1_112_auc: 0.9778 - final_output_2_112_binary_accuracy: 0.9434 - final_output_2_112_auc: 0.9855 - final_output_3_112_binary_accuracy: 0.9419 - final_output_3_112_auc: 0.9678 - final_output_4_112_binary_accuracy: 0.9415 - final_output_4_112_auc: 0.9567 - final_output_5_112_binary_accuracy: 0.9515 - final_output_5_112_auc: 0.9592 - final_output_6_112_binary_accuracy: 0.9908 - final_output_6_112_auc: 0.9733
# Epoch 19: val_loss did not improve from 2.16737
# 293/293 [==============================] - 8s 27ms/step - loss: 1.2105 - final_output_1_112_loss: 0.1868 - final_output_2_112_loss: 0.1381 - final_output_3_112_loss: 0.1411 - final_output_4_112_loss: 0.1447 - final_output_5_112_loss: 0.1235 - final_output_6_112_loss: 0.0281 - final_output_1_112_binary_accuracy: 0.9230 - final_output_1_112_auc: 0.9778 - final_output_2_112_binary_accuracy: 0.9434 - final_output_2_112_auc: 0.9855 - final_output_3_112_binary_accuracy: 0.9419 - final_output_3_112_auc: 0.9678 - final_output_4_112_binary_accuracy: 0.9415 - final_output_4_112_auc: 0.9567 - final_output_5_112_binary_accuracy: 0.9515 - final_output_5_112_auc: 0.9592 - final_output_6_112_binary_accuracy: 0.9908 - final_output_6_112_auc: 0.9733 - val_loss: 2.3105 - val_final_output_1_112_loss: 0.4548 - val_final_output_2_112_loss: 0.3299 - val_final_output_3_112_loss: 0.2584 - val_final_output_4_112_loss: 0.2102 - val_final_output_5_112_loss: 0.1644 - val_final_output_6_112_loss: 0.0359 - val_final_output_1_112_binary_accuracy: 0.8287 - val_final_output_1_112_auc: 0.9000 - val_final_output_2_112_binary_accuracy: 0.8828 - val_final_output_2_112_auc: 0.9308 - val_final_output_3_112_binary_accuracy: 0.9047 - val_final_output_3_112_auc: 0.8896 - val_final_output_4_112_binary_accuracy: 0.9231 - val_final_output_4_112_auc: 0.8997 - val_final_output_5_112_binary_accuracy: 0.9397 - val_final_output_5_112_auc: 0.9223 - val_final_output_6_112_binary_accuracy: 0.9892 - val_final_output_6_112_auc: 0.9507 - lr: 7.5000e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 20/20
# 291/293 [============================>.] - ETA: 0s - loss: 1.1938 - final_output_1_112_loss: 0.1838 - final_output_2_112_loss: 0.1353 - final_output_3_112_loss: 0.1386 - final_output_4_112_loss: 0.1436 - final_output_5_112_loss: 0.1227 - final_output_6_112_loss: 0.0279 - final_output_1_112_binary_accuracy: 0.9242 - final_output_1_112_auc: 0.9784 - final_output_2_112_binary_accuracy: 0.9447 - final_output_2_112_auc: 0.9861 - final_output_3_112_binary_accuracy: 0.9430 - final_output_3_112_auc: 0.9690 - final_output_4_112_binary_accuracy: 0.9421 - final_output_4_112_auc: 0.9573 - final_output_5_112_binary_accuracy: 0.9520 - final_output_5_112_auc: 0.9596 - final_output_6_112_binary_accuracy: 0.9908 - final_output_6_112_auc: 0.9737
# Epoch 20: val_loss did not improve from 2.16737
# ...
# Epoch 14: val_loss did not improve from 2.16058
# 293/293 [==============================] - 8s 28ms/step - loss: 1.3834 - final_output_1_112_loss: 0.2248 - final_output_2_112_loss: 0.1664 - final_output_3_112_loss: 0.1605 - final_output_4_112_loss: 0.1573 - final_output_5_112_loss: 0.1317 - final_output_6_112_loss: 0.0299 - final_output_1_112_binary_accuracy: 0.9048 - final_output_1_112_auc: 0.9674 - final_output_2_112_binary_accuracy: 0.9314 - final_output_2_112_auc: 0.9786 - final_output_3_112_binary_accuracy: 0.9336 - final_output_3_112_auc: 0.9572 - final_output_4_112_binary_accuracy: 0.9369 - final_output_4_112_auc: 0.9474 - final_output_5_112_binary_accuracy: 0.9486 - final_output_5_112_auc: 0.9526 - final_output_6_112_binary_accuracy: 0.9903 - final_output_6_112_auc: 0.9685 - val_loss: 2.2356 - val_final_output_1_112_loss: 0.4315 - val_final_output_2_112_loss: 0.3183 - val_final_output_3_112_loss: 0.2503 - val_final_output_4_112_loss: 0.2078 - val_final_output_5_112_loss: 0.1620 - val_final_output_6_112_loss: 0.0360 - val_final_output_1_112_binary_accuracy: 0.8272 - val_final_output_1_112_auc: 0.8991 - val_final_output_2_112_binary_accuracy: 0.8804 - val_final_output_2_112_auc: 0.9306 - val_final_output_3_112_binary_accuracy: 0.9046 - val_final_output_3_112_auc: 0.8906 - val_final_output_4_112_binary_accuracy: 0.9230 - val_final_output_4_112_auc: 0.8995 - val_final_output_5_112_binary_accuracy: 0.9404 - val_final_output_5_112_auc: 0.9228 - val_final_output_6_112_binary_accuracy: 0.9892 - val_final_output_6_112_auc: 0.9522 - lr: 1.5000e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 15/20
# 291/293 [============================>.] - ETA: 0s - loss: 1.3082 - final_output_1_112_loss: 0.2080 - final_output_2_112_loss: 0.1538 - final_output_3_112_loss: 0.1524 - final_output_4_112_loss: 0.1518 - final_output_5_112_loss: 0.1284 - final_output_6_112_loss: 0.0292 - final_output_1_112_binary_accuracy: 0.9137 - final_output_1_112_auc: 0.9724 - final_output_2_112_binary_accuracy: 0.9372 - final_output_2_112_auc: 0.9819 - final_output_3_112_binary_accuracy: 0.9373 - final_output_3_112_auc: 0.9619 - final_output_4_112_binary_accuracy: 0.9391 - final_output_4_112_auc: 0.9515 - final_output_5_112_binary_accuracy: 0.9498 - final_output_5_112_auc: 0.9551 - final_output_6_112_binary_accuracy: 0.9905 - final_output_6_112_auc: 0.9706
# Epoch 15: val_loss did not improve from 2.16058
# 293/293 [==============================] - 8s 27ms/step - loss: 1.3082 - final_output_1_112_loss: 0.2081 - final_output_2_112_loss: 0.1538 - final_output_3_112_loss: 0.1523 - final_output_4_112_loss: 0.1518 - final_output_5_112_loss: 0.1285 - final_output_6_112_loss: 0.0292 - final_output_1_112_binary_accuracy: 0.9137 - final_output_1_112_auc: 0.9724 - final_output_2_112_binary_accuracy: 0.9372 - final_output_2_112_auc: 0.9819 - final_output_3_112_binary_accuracy: 0.9373 - final_output_3_112_auc: 0.9619 - final_output_4_112_binary_accuracy: 0.9391 - final_output_4_112_auc: 0.9515 - final_output_5_112_binary_accuracy: 0.9498 - final_output_5_112_auc: 0.9551 - final_output_6_112_binary_accuracy: 0.9905 - final_output_6_112_auc: 0.9705 - val_loss: 2.2393 - val_final_output_1_112_loss: 0.4330 - val_final_output_2_112_loss: 0.3190 - val_final_output_3_112_loss: 0.2508 - val_final_output_4_112_loss: 0.2079 - val_final_output_5_112_loss: 0.1616 - val_final_output_6_112_loss: 0.0359 - val_final_output_1_112_binary_accuracy: 0.8268 - val_final_output_1_112_auc: 0.9000 - val_final_output_2_112_binary_accuracy: 0.8801 - val_final_output_2_112_auc: 0.9318 - val_final_output_3_112_binary_accuracy: 0.9044 - val_final_output_3_112_auc: 0.8923 - val_final_output_4_112_binary_accuracy: 0.9227 - val_final_output_4_112_auc: 0.9006 - val_final_output_5_112_binary_accuracy: 0.9403 - val_final_output_5_112_auc: 0.9246 - val_final_output_6_112_binary_accuracy: 0.9892 - val_final_output_6_112_auc: 0.9533 - lr: 7.5000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 16/20
# 293/293 [==============================] - ETA: 0s - loss: 1.2789 - final_output_1_112_loss: 0.2011 - final_output_2_112_loss: 0.1493 - final_output_3_112_loss: 0.1493 - final_output_4_112_loss: 0.1496 - final_output_5_112_loss: 0.1268 - final_output_6_112_loss: 0.0289 - final_output_1_112_binary_accuracy: 0.9165 - final_output_1_112_auc: 0.9742 - final_output_2_112_binary_accuracy: 0.9391 - final_output_2_112_auc: 0.9830 - final_output_3_112_binary_accuracy: 0.9384 - final_output_3_112_auc: 0.9637 - final_output_4_112_binary_accuracy: 0.9396 - final_output_4_112_auc: 0.9533 - final_output_5_112_binary_accuracy: 0.9505 - final_output_5_112_auc: 0.9565 - final_output_6_112_binary_accuracy: 0.9906 - final_output_6_112_auc: 0.9714
# Epoch 16: val_loss did not improve from 2.16058
# 293/293 [==============================] - 8s 27ms/step - loss: 1.2789 - final_output_1_112_loss: 0.2011 - final_output_2_112_loss: 0.1493 - final_output_3_112_loss: 0.1493 - final_output_4_112_loss: 0.1496 - final_output_5_112_loss: 0.1268 - final_output_6_112_loss: 0.0289 - final_output_1_112_binary_accuracy: 0.9165 - final_output_1_112_auc: 0.9742 - final_output_2_112_binary_accuracy: 0.9391 - final_output_2_112_auc: 0.9830 - final_output_3_112_binary_accuracy: 0.9384 - final_output_3_112_auc: 0.9637 - final_output_4_112_binary_accuracy: 0.9396 - final_output_4_112_auc: 0.9533 - final_output_5_112_binary_accuracy: 0.9505 - final_output_5_112_auc: 0.9565 - final_output_6_112_binary_accuracy: 0.9906 - final_output_6_112_auc: 0.9714 - val_loss: 2.2539 - val_final_output_1_112_loss: 0.4383 - val_final_output_2_112_loss: 0.3223 - val_final_output_3_112_loss: 0.2522 - val_final_output_4_112_loss: 0.2077 - val_final_output_5_112_loss: 0.1611 - val_final_output_6_112_loss: 0.0357 - val_final_output_1_112_binary_accuracy: 0.8267 - val_final_output_1_112_auc: 0.9001 - val_final_output_2_112_binary_accuracy: 0.8814 - val_final_output_2_112_auc: 0.9315 - val_final_output_3_112_binary_accuracy: 0.9041 - val_final_output_3_112_auc: 0.8921 - val_final_output_4_112_binary_accuracy: 0.9230 - val_final_output_4_112_auc: 0.9005 - val_final_output_5_112_binary_accuracy: 0.9410 - val_final_output_5_112_auc: 0.9238 - val_final_output_6_112_binary_accuracy: 0.9892 - val_final_output_6_112_auc: 0.9525 - lr: 7.5000e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 17/20
# 293/293 [==============================] - ETA: 0s - loss: 1.2548 - final_output_1_112_loss: 0.1964 - final_output_2_112_loss: 0.1453 - final_output_3_112_loss: 0.1465 - final_output_4_112_loss: 0.1476 - final_output_5_112_loss: 0.1256 - final_output_6_112_loss: 0.0286 - final_output_1_112_binary_accuracy: 0.9187 - final_output_1_112_auc: 0.9754 - final_output_2_112_binary_accuracy: 0.9407 - final_output_2_112_auc: 0.9839 - final_output_3_112_binary_accuracy: 0.9398 - final_output_3_112_auc: 0.9651 - final_output_4_112_binary_accuracy: 0.9404 - final_output_4_112_auc: 0.9547 - final_output_5_112_binary_accuracy: 0.9509 - final_output_5_112_auc: 0.9574 - final_output_6_112_binary_accuracy: 0.9906 - final_output_6_112_auc: 0.9719
# Epoch 17: val_loss did not improve from 2.16058
# 293/293 [==============================] - 8s 27ms/step - loss: 1.2548 - final_output_1_112_loss: 0.1964 - final_output_2_112_loss: 0.1453 - final_output_3_112_loss: 0.1465 - final_output_4_112_loss: 0.1476 - final_output_5_112_loss: 0.1256 - final_output_6_112_loss: 0.0286 - final_output_1_112_binary_accuracy: 0.9187 - final_output_1_112_auc: 0.9754 - final_output_2_112_binary_accuracy: 0.9407 - final_output_2_112_auc: 0.9839 - final_output_3_112_binary_accuracy: 0.9398 - final_output_3_112_auc: 0.9651 - final_output_4_112_binary_accuracy: 0.9404 - final_output_4_112_auc: 0.9547 - final_output_5_112_binary_accuracy: 0.9509 - final_output_5_112_auc: 0.9574 - final_output_6_112_binary_accuracy: 0.9906 - final_output_6_112_auc: 0.9719 - val_loss: 2.2720 - val_final_output_1_112_loss: 0.4435 - val_final_output_2_112_loss: 0.3259 - val_final_output_3_112_loss: 0.2539 - val_final_output_4_112_loss: 0.2083 - val_final_output_5_112_loss: 0.1615 - val_final_output_6_112_loss: 0.0358 - val_final_output_1_112_binary_accuracy: 0.8282 - val_final_output_1_112_auc: 0.8998 - val_final_output_2_112_binary_accuracy: 0.8817 - val_final_output_2_112_auc: 0.9312 - val_final_output_3_112_binary_accuracy: 0.9045 - val_final_output_3_112_auc: 0.8918 - val_final_output_4_112_binary_accuracy: 0.9230 - val_final_output_4_112_auc: 0.9003 - val_final_output_5_112_binary_accuracy: 0.9407 - val_final_output_5_112_auc: 0.9240 - val_final_output_6_112_binary_accuracy: 0.9892 - val_final_output_6_112_auc: 0.9523 - lr: 7.5000e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 18/20
# 292/293 [============================>.] - ETA: 0s - loss: 1.2313 - final_output_1_112_loss: 0.1908 - final_output_2_112_loss: 0.1422 - final_output_3_112_loss: 0.1436 - final_output_4_112_loss: 0.1456 - final_output_5_112_loss: 0.1247 - final_output_6_112_loss: 0.0283 - final_output_1_112_binary_accuracy: 0.9212 - final_output_1_112_auc: 0.9768 - final_output_2_112_binary_accuracy: 0.9418 - final_output_2_112_auc: 0.9845 - final_output_3_112_binary_accuracy: 0.9409 - final_output_3_112_auc: 0.9665 - final_output_4_112_binary_accuracy: 0.9413 - final_output_4_112_auc: 0.9560 - final_output_5_112_binary_accuracy: 0.9511 - final_output_5_112_auc: 0.9580 - final_output_6_112_binary_accuracy: 0.9907 - final_output_6_112_auc: 0.9725
# Epoch 18: val_loss did not improve from 2.16058
# 293/293 [==============================] - 8s 27ms/step - loss: 1.2315 - final_output_1_112_loss: 0.1909 - final_output_2_112_loss: 0.1421 - final_output_3_112_loss: 0.1437 - final_output_4_112_loss: 0.1457 - final_output_5_112_loss: 0.1247 - final_output_6_112_loss: 0.0283 - final_output_1_112_binary_accuracy: 0.9212 - final_output_1_112_auc: 0.9768 - final_output_2_112_binary_accuracy: 0.9418 - final_output_2_112_auc: 0.9845 - final_output_3_112_binary_accuracy: 0.9409 - final_output_3_112_auc: 0.9665 - final_output_4_112_binary_accuracy: 0.9413 - final_output_4_112_auc: 0.9560 - final_output_5_112_binary_accuracy: 0.9511 - final_output_5_112_auc: 0.9580 - final_output_6_112_binary_accuracy: 0.9907 - final_output_6_112_auc: 0.9725 - val_loss: 2.2849 - val_final_output_1_112_loss: 0.4462 - val_final_output_2_112_loss: 0.3293 - val_final_output_3_112_loss: 0.2550 - val_final_output_4_112_loss: 0.2089 - val_final_output_5_112_loss: 0.1617 - val_final_output_6_112_loss: 0.0358 - val_final_output_1_112_binary_accuracy: 0.8273 - val_final_output_1_112_auc: 0.9000 - val_final_output_2_112_binary_accuracy: 0.8808 - val_final_output_2_112_auc: 0.9309 - val_final_output_3_112_binary_accuracy: 0.9041 - val_final_output_3_112_auc: 0.8912 - val_final_output_4_112_binary_accuracy: 0.9228 - val_final_output_4_112_auc: 0.9000 - val_final_output_5_112_binary_accuracy: 0.9406 - val_final_output_5_112_auc: 0.9241 - val_final_output_6_112_binary_accuracy: 0.9892 - val_final_output_6_112_auc: 0.9521 - lr: 7.5000e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 19/20
# 293/293 [==============================] - ETA: 0s - loss: 1.2135 - final_output_1_112_loss: 0.1867 - final_output_2_112_loss: 0.1387 - final_output_3_112_loss: 0.1420 - final_output_4_112_loss: 0.1447 - final_output_5_112_loss: 0.1238 - final_output_6_112_loss: 0.0281 - final_output_1_112_binary_accuracy: 0.9228 - final_output_1_112_auc: 0.9778 - final_output_2_112_binary_accuracy: 0.9432 - final_output_2_112_auc: 0.9853 - final_output_3_112_binary_accuracy: 0.9413 - final_output_3_112_auc: 0.9673 - final_output_4_112_binary_accuracy: 0.9417 - final_output_4_112_auc: 0.9565 - final_output_5_112_binary_accuracy: 0.9515 - final_output_5_112_auc: 0.9588 - final_output_6_112_binary_accuracy: 0.9907 - final_output_6_112_auc: 0.9730
# Epoch 19: val_loss did not improve from 2.16058
# 293/293 [==============================] - 8s 27ms/step - loss: 1.2135 - final_output_1_112_loss: 0.1867 - final_output_2_112_loss: 0.1387 - final_output_3_112_loss: 0.1420 - final_output_4_112_loss: 0.1447 - final_output_5_112_loss: 0.1238 - final_output_6_112_loss: 0.0281 - final_output_1_112_binary_accuracy: 0.9228 - final_output_1_112_auc: 0.9778 - final_output_2_112_binary_accuracy: 0.9432 - final_output_2_112_auc: 0.9853 - final_output_3_112_binary_accuracy: 0.9413 - final_output_3_112_auc: 0.9673 - final_output_4_112_binary_accuracy: 0.9417 - final_output_4_112_auc: 0.9565 - final_output_5_112_binary_accuracy: 0.9515 - final_output_5_112_auc: 0.9588 - final_output_6_112_binary_accuracy: 0.9907 - final_output_6_112_auc: 0.9730 - val_loss: 2.2958 - val_final_output_1_112_loss: 0.4495 - val_final_output_2_112_loss: 0.3318 - val_final_output_3_112_loss: 0.2557 - val_final_output_4_112_loss: 0.2090 - val_final_output_5_112_loss: 0.1620 - val_final_output_6_112_loss: 0.0358 - val_final_output_1_112_binary_accuracy: 0.8284 - val_final_output_1_112_auc: 0.9004 - val_final_output_2_112_binary_accuracy: 0.8818 - val_final_output_2_112_auc: 0.9312 - val_final_output_3_112_binary_accuracy: 0.9052 - val_final_output_3_112_auc: 0.8910 - val_final_output_4_112_binary_accuracy: 0.9230 - val_final_output_4_112_auc: 0.9001 - val_final_output_5_112_binary_accuracy: 0.9408 - val_final_output_5_112_auc: 0.9240 - val_final_output_6_112_binary_accuracy: 0.9892 - val_final_output_6_112_auc: 0.9518 - lr: 7.5000e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 7.500000356230885e-05.
# Epoch 20/20
# 291/293 [============================>.] - ETA: 0s - loss: 1.1962 - final_output_1_112_loss: 0.1834 - final_output_2_112_loss: 0.1361 - final_output_3_112_loss: 0.1399 - final_output_4_112_loss: 0.1432 - final_output_5_112_loss: 0.1226 - final_output_6_112_loss: 0.0279 - final_output_1_112_binary_accuracy: 0.9246 - final_output_1_112_auc: 0.9785 - final_output_2_112_binary_accuracy: 0.9443 - final_output_2_112_auc: 0.9858 - final_output_3_112_binary_accuracy: 0.9425 - final_output_3_112_auc: 0.9683 - final_output_4_112_binary_accuracy: 0.9421 - final_output_4_112_auc: 0.9576 - final_output_5_112_binary_accuracy: 0.9519 - final_output_5_112_auc: 0.9597 - final_output_6_112_binary_accuracy: 0.9908 - final_output_6_112_auc: 0.9736
# Epoch 20: val_loss did not improve from 2.16058
# 293/293 [==============================] - 8s 27ms/step - loss: 1.1965 - final_output_1_112_loss: 0.1835 - final_output_2_112_loss: 0.1361 - final_output_3_112_loss: 0.1399 - final_output_4_112_loss: 0.1433 - final_output_5_112_loss: 0.1227 - final_output_6_112_loss: 0.0279 - final_output_1_112_binary_accuracy: 0.9245 - final_output_1_112_auc: 0.9785 - final_output_2_112_binary_accuracy: 0.9443 - final_output_2_112_auc: 0.9858 - final_output_3_112_binary_accuracy: 0.9425 - final_output_3_112_auc: 0.9684 - final_output_4_112_binary_accuracy: 0.9421 - final_output_4_112_auc: 0.9576 - final_output_5_112_binary_accuracy: 0.9518 - final_output_5_112_auc: 0.9596 - final_output_6_112_binary_accuracy: 0.9908 - final_output_6_112_auc: 0.9736 - val_loss: 2.3093 - val_final_output_1_112_loss: 0.4542 - val_final_output_2_112_loss: 0.3349 - val_final_output_3_112_loss: 0.2569 - val_final_output_4_112_loss: 0.2092 - val_final_output_5_112_loss: 0.1614 - val_final_output_6_112_loss: 0.0356 - val_final_output_1_112_binary_accuracy: 0.8285 - val_final_output_1_112_auc: 0.8997 - val_final_output_2_112_binary_accuracy: 0.8810 - val_final_output_2_112_auc: 0.9307 - val_final_output_3_112_binary_accuracy: 0.9062 - val_final_output_3_112_auc: 0.8902 - val_final_output_4_112_binary_accuracy: 0.9237 - val_final_output_4_112_auc: 0.8992 - val_final_output_5_112_binary_accuracy: 0.9413 - val_final_output_5_112_auc: 0.9238 - val_final_output_6_112_binary_accuracy: 0.9893 - val_final_output_6_112_auc: 0.9512 - lr: 7.5000e-05

# %%
# Internal testing
train_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Ankh_train_labels_sorted.npy')

# change for each set of models to be evaluated
eval_no = 5

np.random.seed(42)  # for reproducibility
test_size = 1002

rand_state_nos = [1,2,3,4,5]

# Initialize array to accumulate OOF predictions across evaluated models
total_oof_predictions = np.zeros_like(Y, dtype=np.float32)

for rand_state_no in rand_state_nos:

    # Define 5-fold cross validation
    n_splits = 5
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=rand_state_no)

    fold_ct = 1
    out_of_fold_predictions = np.zeros_like(Y, dtype=np.float32) # Initialize array with same shape as Y, MUST BE FLOAT32 OR IT FAILS

    # Iterate over each fold and produce prediction on validation data only
    for train_index, val_index in kf.split(t5_train):

        x_tr_1, x_val_1 = t5_train[train_index], t5_train[val_index]
        x_tr_2, x_val_2 = esm1_train[train_index], esm1_train[val_index]
        x_tr_3, x_val_3 = esm2_train[train_index], esm2_train[val_index]
        x_tr_4, x_val_4 = pb_train[train_index], pb_train[val_index]
        x_tr_5, x_val_5 = ankh_train[train_index], ankh_train[val_index]
        x_tr_6, x_val_6 = taxa_train[train_index], taxa_train[val_index]
        x_tr_7, x_val_7 = txt1_train[train_index], txt1_train[val_index]


        model_path = f'/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_fc{str(fold_ct)}_r{rand_state_no}_1.30.1.hdf5'
        #model.load_weights(model_path) #only for 1.24.2
        model = load_model(model_path)

        # Add OOF predictions for this split
        predicted_outputs = model.predict([x_val_1, x_val_2, x_val_3, x_val_4, x_val_5, x_val_6, x_val_7])
        #output_1, output_2, output_3, output_4, output_5, output_6 = model.predict([x_val_1, x_val_2, x_val_3, x_val_4, x_val_5, x_val_6]) #only for 1.24.3
        #predicted_outputs = np.concatenate([output_1, output_2, output_3, output_4, output_5, output_6], axis=1) #only for 1.24.3

        out_of_fold_predictions[val_index, :] = predicted_outputs

        K.clear_session()
        gc.collect()

        fold_ct+=1

    total_oof_predictions += out_of_fold_predictions
averaged_oof_predictions = total_oof_predictions / len(rand_state_nos)


random_indices = np.random.choice(t5_train.shape[0], size=test_size, replace=False)

predicted_output = out_of_fold_predictions[random_indices]
random_labels = train_labels[random_indices]
ramdom_Y = Y[random_indices]

print(f'Check random indices match: {random_indices[:5]}')
print(f'Output predictions shape:{predicted_output.shape}')

prediction_preparation = PredictionPreparation(predicted_output, Y_labels, random_labels)
prediction_preparation.prepare_submission(filename=f"/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_testing_1.30.{eval_no}.tsv", top_percent=0.05)

# Code helth
K.clear_session()
gc.collect()
# Out:
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# 586/586 [==============================] - 2s 3ms/step
# Check random indices match: [22100 40419 92539 74089 41468]
# Output predictions shape:(1002, 1500)
# zeros dropped for 0 rows
#         Protein Id  GO Term Id  Prediction
# 1266568     Q0E8G1  GO:0006518         1.0
# 1267266     Q0E8G1  GO:0009059         1.0
# 1266830     Q0E8G1  GO:1901566         1.0
# 1447501     P06710  GO:0008152         1.0
# 1023105     A5HUN3  GO:0044260         1.0
# count    75150.000000
# mean         0.355990
# std          0.286728
# min          0.077000
# 25%          0.124000
# 50%          0.231000
# 75%          0.533000
# max          1.000000
# Name: Prediction, dtype: float64
# 111

# %%
# Make groundtruth file for evaluating against
np.random.seed(42)  # for reproducibility

train_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Ankh_train_labels_sorted.npy')

# Set the number of proteins to use as testing for ground truth
test_size = 1002

# Create groundtruth data for testing
random_indices = np.random.choice(t5_train.shape[0], size=test_size, replace=False)
random_labels = train_labels[random_indices]
ramdom_Y = Y[random_indices]

print(f'Check random indices match: {random_indices[:5]}')

prediction_preparation = PredictionPreparation(ramdom_Y, Y_labels, random_labels)
prediction_preparation.prepare_submission(filename=f"/content/drive/MyDrive/CAFA5 2023/1.30/Groundtruth_{test_size}_{ontology}_submission.tsv", top_percent=1, dropweights=True)
# Out:
# Check random indices match: [22100 40419 92539 74089 41468]
# zeros dropped for 1473729 rows
#        Protein Id  GO Term Id
# 751500     P01602  GO:0050896
# 462012     O00192  GO:0048519
# 462015     O00192  GO:0019222
# 462016     O00192  GO:0042592
# 309024     O94409  GO:0009058
# matrix shape: (29271, 2)

# %%
# For submission for CAFA test set
test_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/t5_labels_sorted.npy')
rand_state_nos = [1,2,3,4,5]

predictions = []

for rand_state_no in rand_state_nos:

    for fold_ct in [1,2,3,4,5]:

        model_path = f'/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_fc{str(fold_ct)}_r{rand_state_no}_1.30.1.hdf5'
        #model.load_weights(model_path) #only for 1.24.2
        model = load_model(model_path)

        # Add OOF predictions for this split
        predicted_outputs = model.predict([t5_test, esm1_test, esm2_test, pb_test, ankh_test, taxa_test, txt1_test])
        #output_1, output_2, output_3, output_4, output_5, output_6 = model.predict([x_val_1, x_val_2, x_val_3, x_val_4, x_val_5, x_val_6]) #only for 1.24.3
        #predicted_outputs = np.concatenate([output_1, output_2, output_3, output_4, output_5, output_6], axis=1) #only for 1.24.3

        predictions.append(predicted_outputs)

        K.clear_session()
        gc.collect()

average_predictions = np.mean(predictions, axis=0)
print('average predictions shape:', average_predictions.shape)

prediction_preparation = PredictionPreparation(average_predictions, Y_labels, test_labels)
prediction_preparation.prepare_submission(filename=f"/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_test_submission_1.30.1.tsv", top_percent=0.05)
# Out:
# 4434/4434 [==============================] - 15s 3ms/step
# 4434/4434 [==============================] - 15s 3ms/step
# 4434/4434 [==============================] - 15s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# 4434/4434 [==============================] - 15s 3ms/step
# 4434/4434 [==============================] - 15s 3ms/step
# 4434/4434 [==============================] - 14s 3ms/step
# average predictions shape: (141864, 1500)
# zeros dropped for 0 rows
#         Protein Id  GO Term Id  Prediction
# 2763223     A2AWT3  GO:0071704         1.0
# 2763001     A2AWT3  GO:0008152         1.0
# 2763045     A2AWT3  GO:0043170         1.0
# 2763081     A2AWT3  GO:0044238         1.0
# 2763054     A2AWT3  GO:0006807         1.0
# count    1.063980e+07
# mean     2.618248e-01
# std      2.567380e-01
# min      5.100000e-02
# 25%      7.900000e-02
# 50%      1.440000e-01
# 75%      3.480000e-01
# max      1.000000e+00
# Name: Prediction, dtype: float64

# %%
# Internal testing for 1.30.2/3/4
train_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Train_data/Ankh_train_labels_sorted.npy')
test_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/t5_labels_sorted.npy')

# change for each set of models to be evaluated
eval_no = 3

np.random.seed(42)  # for reproducibility
test_size = 1002

model_nos = [2]
rand_state_no = 1

# Initialize array to accumulate OOF predictions across evaluated models
total_oof_predictions = np.zeros_like(Y, dtype=np.float32)

for model_no in model_nos:

    # Define 5-fold cross validation
    n_splits = 5
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=rand_state_no)

    fold_ct = 1
    out_of_fold_predictions = np.zeros_like(Y, dtype=np.float32) # Initialize array with same shape as Y, MUST BE FLOAT32 OR IT FAILS

    # Iterate over each fold and produce prediction on validation data only
    for train_index, val_index in kf.split(t5_train):

        x_tr_1, x_val_1 = t5_train[train_index], t5_train[val_index]
        x_tr_2, x_val_2 = esm1_train[train_index], esm1_train[val_index]
        x_tr_3, x_val_3 = esm2_train[train_index], esm2_train[val_index]
        x_tr_4, x_val_4 = pb_train[train_index], pb_train[val_index]
        x_tr_5, x_val_5 = ankh_train[train_index], ankh_train[val_index]
        x_tr_6, x_val_6 = taxa_train[train_index], taxa_train[val_index]
        x_tr_7, x_val_7 = txt1_train[train_index], txt1_train[val_index]


        model_path = f'/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_fc{str(fold_ct)}_r{rand_state_no}_1.30.{model_no}.hdf5'
        #model.load_weights(model_path) #only for 1.24.2
        model = load_model(model_path)

        # Add OOF predictions for this split
        #predicted_outputs = model.predict([x_val_1, x_val_2, x_val_3, x_val_4, x_val_5, x_val_6, x_val_7])
        output_1, output_2, output_3, output_4, output_5, output_6 = model.predict([x_val_1, x_val_2, x_val_3, x_val_4, x_val_5, x_val_6, x_val_7]) #only for 1.24.3
        predicted_outputs = np.concatenate([output_1, output_2, output_3, output_4, output_5, output_6], axis=1) #only for 1.24.3

        out_of_fold_predictions[val_index, :] = predicted_outputs

        K.clear_session()
        gc.collect()

        fold_ct+=1

    total_oof_predictions += out_of_fold_predictions
averaged_oof_predictions = total_oof_predictions / len(model_nos)


random_indices = np.random.choice(t5_train.shape[0], size=test_size, replace=False)

predicted_output = out_of_fold_predictions[random_indices]
random_labels = train_labels[random_indices]
ramdom_Y = Y[random_indices]

print(f'Check random indices match: {random_indices[:5]}')
print(f'Output predictions shape:{predicted_output.shape}')

prediction_preparation = PredictionPreparation(predicted_output, Y_labels, random_labels)
prediction_preparation.prepare_submission(filename=f"/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_testing_1.30b.{eval_no}.tsv", top_percent=0.05)

# Code helth
K.clear_session()
gc.collect()


#1.30b.5 = 2,3,4 models ensemble
#1.30b.6 = 2,3 ensemble
#1.30b.7 = just 2
# Out:
# 890/890 [==============================] - 7s 3ms/step
# 890/890 [==============================] - 4s 4ms/step
# 890/890 [==============================] - 4s 4ms/step
# 890/890 [==============================] - 4s 4ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-01b6048bdd43> in <cell line: 17>()
#      33         x_tr_5, x_val_5 = ankh_train[train_index], ankh_train[val_index]
#      34         x_tr_6, x_val_6 = taxa_train[train_index], taxa_train[val_index]
# ---> 35         x_tr_7, x_val_7 = txt1_train[train_index], txt1_train[val_index]
#      36
#      37
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/memmap.py in __getitem__(self, index)
#     332
#     333     def __getitem__(self, index):
# --> 334         res = super().__getitem__(index)
#     335         if type(res) is memmap and res._mmap is None:
#     336             return res.view(type=ndarray)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/memmap.py in __array_finalize__(self, obj)
#     286         return self
#     287
# --> 288     def __array_finalize__(self, obj):
#     289         if hasattr(obj, '_mmap') and np.may_share_memory(self, obj):
#     290             self._mmap = obj._mmap
#
# KeyboardInterrupt:

# %%
# For submission for CAFA test set 130b
test_labels = np.load('/content/drive/MyDrive/CAFA5 2023/Test_data/t5_labels_sorted.npy')
model_nos = [2]
rand_state_no = 1

predictions = []

for model_no in model_nos:

    for fold_ct in [1,2,3,4,5]:

        model_path = f'/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_fc{str(fold_ct)}_r{rand_state_no}_1.30.{model_no}.hdf5'
        #model.load_weights(model_path) #only for 1.24.2
        model = load_model(model_path)

        # Add OOF predictions for this split
        #predicted_outputs = model.predict([t5_test, esm1_test, esm2_test, pb_test, ankh_test, taxa_test, txt1_test])
        output_1, output_2, output_3, output_4, output_5, output_6 = model.predict([t5_test, esm1_test, esm2_test, pb_test, ankh_test, taxa_test, txt1_test]) #only for 1.24.3
        predicted_outputs = np.concatenate([output_1, output_2, output_3, output_4, output_5, output_6], axis=1) #only for 1.24.3

        predictions.append(predicted_outputs)

        K.clear_session()
        gc.collect()

average_predictions = np.mean(predictions, axis=0)
print('average predictions shape:', average_predictions.shape)

prediction_preparation = PredictionPreparation(average_predictions, Y_labels, test_labels)
prediction_preparation.prepare_submission(filename=f"/content/drive/MyDrive/CAFA5 2023/1.30/{ontology}_test_submission_1.30b.tsv", top_percent=0.05)
# Out:
# 4434/4434 [==============================] - 16s 4ms/step
# 4434/4434 [==============================] - 16s 4ms/step
# 4434/4434 [==============================] - 16s 4ms/step
# 4434/4434 [==============================] - 16s 4ms/step
# 4434/4434 [==============================] - 17s 4ms/step
# average predictions shape: (141864, 1500)
# zeros dropped for 0 rows
#           Protein Id  GO Term Id  Prediction
# 192271501     Q9JMA2  GO:0008152         1.0
# 83650501      Q06408  GO:0008152         1.0
# 109717501     Q53H54  GO:0008152         1.0
# 50385001      P30136  GO:0008152         1.0
# 82497001      Q04235  GO:0008152         1.0
# count    1.063980e+07
# mean     2.666028e-01
# std      2.476246e-01
# min      6.200000e-02
# 25%      9.200000e-02
# 50%      1.560000e-01
# 75%      3.450000e-01
# max      1.000000e+00
# Name: Prediction, dtype: float64

# %%
#merge ontololgy tsv subs

import pandas as pd

# Specify the file paths of the TSV files you want to concatenate
file_paths = ['/content/drive/MyDrive/CAFA5 2023/1.30/MFO_test_submission_1.30b.tsv', '/content/drive/MyDrive/CAFA5 2023/1.30/CCO_test_submission_1.30b.tsv', '/content/drive/MyDrive/CAFA5 2023/1.30/BPO_test_submission_1.30b.tsv']

# Read the first TSV file with header, as it contains the column names
dfs = [pd.read_csv(file_paths[0], sep='\t', header=None)]

# Read the remaining TSV files without header, as they are already in the first file
for file_path in file_paths[1:]:
    dfs.append(pd.read_csv(file_path, sep='\t', header=None))

# Concatenate the DataFrames
concatenated_df = pd.concat(dfs, ignore_index=True)

# Save the concatenated DataFrame to a new TSV file
concatenated_df.to_csv('/content/drive/MyDrive/CAFA5 2023/1.30/All_test_submission_1.30b.tsv', sep='\t', index=False, header=False)

# %%
concatenated_df.to_csv('/content/drive/MyDrive/CAFA5 2023/1.30/All_test_submission_1.30.1.tsv', sep='\t', index=False, header=False)

#please note that this is the final kaggle submission,
#used in version 95 here https://www.kaggle.com/code/zmcxjt/merge-datasets/notebook
